# %%
# PTD-VRP-D End-to-End Simulation Notebook
# ========================================

# =========================
# Imports
# =========================
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from scipy.spatial.distance import cdist
from sklearn.cluster import KMeans
from scipy.interpolate import interp1d
from pyswarm import pso

import gurobipy as gp
from gurobipy import GRB

# =========================
# Constants & Parameters
# =========================
AREA_SIZE        = 10.0      # km
N_DELIVERY_LOC   = 10
DEPOT            = (0.0, 0.0)
DRONE_ENDURANCE  = 20.0      # minutes
N_DRONES         = 10
DRONE_SPEED      = 40.0      # km/h
SERVICE_TIME     = 5.0       # minutes per cluster visit
PENALTY          = 1e3       # penalty for endurance violation

# PSO / solver settings
MAX_PSO_ITERS    = 10
PSO_SWARMSIZE    = 30
# coarse solve (used by baseline & PSO objective)
TIME_LIMIT_COARSE = 5        # seconds
MIP_GAP_COARSE    = 0.05     # 5%
# fine “polish” solve
TIME_LIMIT_FINE   = 60       # seconds
MIP_GAP_FINE      = 1e-4     # 0.01%

# PWL breakpoints for 24h speed profile (15-min)
DT    = 0.25
TIMES = np.arange(0, 24 + DT, DT)

# =========================
# Utility Functions
# =========================
def generate_random_locations(n, depot, range_km=AREA_SIZE):
    """Generate n random delivery points around depot."""
    pts = np.random.uniform(-range_km, range_km, size=(n,2))
    return np.vstack([depot, pts])

def load_speed_model(csv_path='Predicted_Speeds.csv'):
    """Load or synthesize a 15-min truck-speed profile over 24h."""
    if not os.path.exists(csv_path):
        # synthetic “rush‐hour” pattern
        speeds = 60 + 10*np.sin((TIMES-12)/24*2*np.pi)
        speeds -= 20*(np.exp(-((TIMES-8)/1.5)**2) + np.exp(-((TIMES-17)/1.5)**2))
        speeds = np.clip(speeds, 20, 80)
        pd.DataFrame({'Time of Day': TIMES, 'Predicted Speed': speeds})\
          .to_csv(csv_path, index=False)
    df = pd.read_csv(csv_path).sort_values('Time of Day')
    return interp1d(df['Time of Day'], df['Predicted Speed'],
                    kind='linear', fill_value='extrapolate')

def is_within_endurance(center, pts):
    """Check drone round-trip feasibility for all pts in one cluster."""
    d     = np.linalg.norm(pts - center, axis=1)
    T_rt  = 2*(d/DRONE_SPEED) + (SERVICE_TIME/60.0)
    return np.all(T_rt <= (DRONE_ENDURANCE/60.0))

# =========================
# Adaptive K-Means Clustering
# =========================
def adaptive_kmeans(locs):
    """Find smallest K so each cluster is drone-feasible."""
    N = len(locs) - 1
    for K in range(1, N+1):
        km      = KMeans(n_clusters=K, n_init=10, random_state=0).fit(locs[1:])
        centers = km.cluster_centers_
        labels  = km.labels_
        if all(is_within_endurance(centers[i], locs[1:][labels==i])
               for i in range(K)):
            return labels, centers
    raise RuntimeError("No valid clustering found")

# =========================
# MILP Core (time‐dependent PWL + truck–drone sync)
# =========================
env = gp.Env(empty=True)
env.setParam('WLSACCESSID','95c3994f-513d-4b8c-a42c-0194dad8ec5c')
env.setParam('WLSSECRET',  '3dc0e444-1f74-49f3-96cc-e9abaabb8ce4')
env.setParam('LICENSEID',   2551395)
env.start()
def solve_time_dependent_milp(alpha, centers, labels, speed_func, locs,
                              time_limit, mip_gap):
    """
    alpha: (K,1) scaling of cluster centers
    centers: (K,2) original centers
    labels:   length N labels
    speed_func: interpolation speed(t)
    locs: full array including depot
    """
    # 1) adjust centers, build coords + Manhattan distances
    adj      = centers * alpha
    K        = len(centers)
    coords   = np.vstack([DEPOT, adj])
    dM       = np.abs(coords[:,None,0] - coords[None,:,0]) + \
               np.abs(coords[:,None,1] - coords[None,:,1])

    # 2) Gurobi env & model


    m = gp.Model(env=env)
    m.Params.OutputFlag = 0
    m.Params.TimeLimit  = time_limit
    m.Params.MIPGap     = mip_gap

    # 3) decision vars
    r      = m.addVars(K+1,K+1, vtype=GRB.BINARY,      name='r')
    u      = m.addVars(K+1,    vtype=GRB.CONTINUOUS, lb=0, ub=K, name='u')
    Tdep   = m.addVars(K+1,    vtype=GRB.CONTINUOUS,      name='Tdep')
    Tarr   = m.addVars(K+1,    vtype=GRB.CONTINUOUS,      name='Tarr')
    Tdrone = m.addVars(K+1,    vtype=GRB.CONTINUOUS,      name='Tdrone')
    τ      = m.addVars(K+1,K+1, vtype=GRB.CONTINUOUS,      name='tau') 

    # drone-assignment y[i,ℓ,k]
    y = {}
    for i in range(1,K+1):
        pts = locs[1:][labels==i-1]
        for ℓ in range(len(pts)):
            for k in range(N_DRONES):
                y[i,ℓ,k] = m.addVar(vtype=GRB.BINARY, name=f"y_{i}_{ℓ}_{k}")

    # 4) PWL inv-speed breakpoints
    inv_speeds = (1.0/speed_func(TIMES)).tolist()
    t_breaks   = TIMES.tolist()

    # 5) objective = truck + drone + service
    truck_cost = gp.quicksum( τ[i,j] * r[i,j]
                              for i in range(K+1) for j in range(K+1) if i!=j )
    drone_cost = gp.quicksum(Tdrone[i] for i in range(1,K+1))
    service    = SERVICE_TIME/60.0 * K
    m.setObjective(truck_cost + drone_cost + service, GRB.MINIMIZE)

    # 6) PWL constraints: τ[i,j] = dM[i,j]*inv_speed(Tdep[i])
    for i in range(K+1):
        for j in range(K+1):
            if i==j: continue
            ys = (dM[i,j] * np.array(inv_speeds)).tolist()
            m.addGenConstrPWL(τ[i,j], Tdep[i], t_breaks, ys,
                              name=f"pwl_{i}_{j}")

    # 7) routing & subtours (MTZ)
    for i in range(K+1):
        m.addConstr(r.sum(i,'*') == 1)
        m.addConstr(r.sum('*',i) == 1)
    m.addConstr(u[0]==0)
    for i in range(1,K+1):
        for j in range(1,K+1):
            if i!=j:
                m.addConstr(u[i] - u[j] + (K+1)*r[i,j] <= K)

    # 8) timing chain: Tarr[j] ≥ Tdep[i] + τ[i,j]  if arc used
    M = 1e3
    for i in range(K+1):
        for j in range(K+1):
            if i!=j:
                m.addConstr( Tarr[j] >= Tdep[i] + τ[i,j] - M*(1-r[i,j]) )
    for i in range(K+1):
        m.addConstr(Tdep[i] >= Tarr[i] + SERVICE_TIME/60.0)
    for i in range(1,K+1):
        m.addConstr(Tdep[i] >= Tarr[i] + Tdrone[i])

    # 9) drone schedule + endurance
    for i in range(1,K+1):
        pts = locs[1:][labels==i-1]
        if pts.size>0:
            dE = [float(np.linalg.norm(pt - adj[i-1])) for pt in pts]
            # each ℓ assigned exactly once
            for ℓ in range(len(dE)):
                m.addConstr( gp.quicksum(y[i,ℓ,k] for k in range(N_DRONES)) == 1 )
            # workloads & Tdrone
            for k in range(N_DRONES):
                m.addConstr( Tdrone[i] >= 
                    gp.quicksum( 2*dE[ℓ]/DRONE_SPEED * y[i,ℓ,k]
                                 for ℓ in range(len(dE))) )
            # endurance
            for d in dE:
                m.addConstr(2*d/DRONE_SPEED <= DRONE_ENDURANCE/60.0)
        else:
            m.addConstr(Tdrone[i]==0)

    m.optimize()
    return m.ObjVal if m.status==GRB.OPTIMAL else 1e6

# =========================
# PSO Objective (no caching)
# =========================
def objective(w, centers, labels, locs, speed_func):
    alpha   = np.array(w).reshape(-1,1)
    # penalty for any cluster violation
    pen = 0.0
    for i,C in enumerate(centers):
        if not is_within_endurance(C*alpha[i], locs[1:][labels==i]):
            pen += PENALTY
    val = solve_time_dependent_milp(alpha, centers, labels,
                                    speed_func, locs,
                                    time_limit=TIME_LIMIT_COARSE,
                                    mip_gap=MIP_GAP_COARSE)
    return val + pen

# =========================
# Greedy TSP for plotting
# =========================
def greedy_tsp(coords):
    route, cur = [0], 0
    unvis = set(range(1,len(coords)))
    while unvis:
        nxt = min(unvis, key=lambda j: np.linalg.norm(coords[cur]-coords[j]))
        unvis.remove(nxt)
        route.append(nxt); cur = nxt
    route.append(0)
    return route

# =========================
# Plot static vs optimized
# =========================
def plot_comparison(locs, labels, centers, alpha_opt, static_t, opt_t):
    K       = len(centers)
    depot   = np.array([DEPOT])
    static_c= centers
    opt_c   = centers * alpha_opt

    coords_s= np.vstack([depot, static_c])
    coords_o= np.vstack([depot, opt_c])
    route_s = greedy_tsp(coords_s)
    route_o = greedy_tsp(coords_o)

    plt.figure(figsize=(8,8))
    for i in range(K):
        pts = locs[1:][labels==i]
        plt.scatter(pts[:,0], pts[:,1], s=25, label=f"Cluster {i+1}")
    plt.scatter(static_c[:,0], static_c[:,1],
                c='k', marker='X', s=100, label='Static centers')
    plt.scatter(opt_c[:,0], opt_c[:,1],
                c='m', marker='^', s=100, label='Optimized centers')
    sc = coords_s[route_s]; plt.plot(sc[:,0], sc[:,1], '-b', lw=2,
                                     label=f'Static ({static_t:.2f}h)')
    oc = coords_o[route_o]; plt.plot(oc[:,0], oc[:,1], '--r', lw=2,
                                     label=f'Optimized ({opt_t:.2f}h)')
    plt.scatter(0,0, c='g', marker='s', s=120, label='Depot')
    plt.axis('equal'); plt.grid(); plt.legend(ncol=2, fontsize='small')
    plt.xlabel('X (km)'); plt.ylabel('Y (km)')
    plt.title('Static vs Optimized PTD-VRP-D')
    plt.show()

# =========================
# Main Experiment
# =========================
def main():
    np.random.seed()

    # generate & cluster
    locs   = generate_random_locations(N_DELIVERY_LOC, DEPOT)
    labels, centers = adaptive_kmeans(locs)
    speed_func      = load_speed_model()

    # 1) static baseline (coarse)
    alpha_base = np.ones((len(centers),1))
    static_t   = solve_time_dependent_milp(alpha_base, centers, labels,
                                           speed_func, locs,
                                           time_limit=TIME_LIMIT_COARSE,
                                           mip_gap=MIP_GAP_COARSE)
    print(f"[RESULT] static baseline (coarse) = {static_t:.4f} h")

    # 2) PSO
    lb = [0.5]*len(centers)
    ub = [1.5]*len(centers)
    opt_w, fopt = pso(lambda w: objective(w, centers, labels, locs, speed_func),
                      lb, ub,
                      swarmsize=PSO_SWARMSIZE,
                      maxiter=MAX_PSO_ITERS,
                      debug=True)
    alpha_opt = np.array(opt_w).reshape(-1,1)
    print(f"[RESULT] PSO α* = {alpha_opt.flatten()}, coarse obj ≈ {fopt:.4f}h")

    # 3) polished optimized (fine)
    opt_t = solve_time_dependent_milp(alpha_opt, centers, labels,
                                      speed_func, locs,
                                      time_limit=TIME_LIMIT_FINE,
                                      mip_gap=MIP_GAP_FINE)
    print(f"[RESULT] optimized (polish)    = {opt_t:.4f} h")

    # 4) improvement (coarse comparison)
    improvement = (static_t - fopt)/static_t * 100
    print(f"[COMPARISON] coarse improvement = {improvement:.2f}%")

    # 5) plot
    plot_comparison(locs, labels, centers, alpha_opt, static_t, opt_t)
    
if __name__ == '__main__':
    main()
# Out:
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2551395
# Academic license 2551395 - for non-commercial use only - registered to g2___@kfupm.edu.sa
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/Users/shihab/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3398, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/gf/pkyzqdcn0_5021ggl3gj4sxw0000gn/T/ipykernel_30329/3738657255.py", line 304, in <cell line: 303>
#     main()
#   File "/var/folders/gf/pkyzqdcn0_5021ggl3gj4sxw0000gn/T/ipykernel_30329/3738657255.py", line 268, in main
#     speed_func      = load_speed_model()
#   File "/var/folders/gf/pkyzqdcn0_5021ggl3gj4sxw0000gn/T/ipykernel_30329/3738657255.py", line 63, in load_speed_model
#     df = pd.read_csv(csv_path).sort_values('Time of Day')
#   File "/Users/shihab/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py", line 7189, in sort_values
#     k = self._get_label_or_level_values(by[0], axis=axis)
#   File "/Users/shihab/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py", line 1911, in _get_label_or_level_values
#     raise KeyError(key)
# KeyError: 'Time of Day'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/shihab/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 1993, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/Users/shihab/opt/anaconda3/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1118, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/Users/shihab/opt/anaconda3/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1012, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/Users/shihab/opt/anaconda3/lib/python3.9/site-packages/IPython/core/ultratb.py", line 865, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/Users/shihab/opt/anaconda3/lib/python3.9/site-packages/IPython/core/ultratb.py", line 818, in format_exception_as_a_whole
#     frames.append(self.format_record(r))
#   File "/Users/shihab/opt/anaconda3/lib/python3.9/site-packages/IPython/core/ultratb.py", line 736, in format_record
#     result += ''.join(_format_traceback_lines(frame_info.lines, Colors, self.has_colors, lvals))
#   File "/Users/shihab/opt/anaconda3/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/Users/shihab/opt/anaconda3/lib/python3.9/site-packages/stack_data/core.py", line 698, in lines
#     pieces = self.included_pieces
#   File "/Users/shihab/opt/anaconda3/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/Users/shihab/opt/anaconda3/lib/python3.9/site-packages/stack_data/core.py", line 645, in included_pieces
#     scope_pieces = self.scope_pieces
#   File "/Users/shihab/opt/anaconda3/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/Users/shihab/opt/anaconda3/lib/python3.9/site-packages/stack_data/core.py", line 585, in scope_pieces
#     for piece in self.source.pieces
#   File "/Users/shihab/opt/anaconda3/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/Users/shihab/opt/anaconda3/lib/python3.9/site-packages/stack_data/core.py", line 90, in pieces
#     return list(self._clean_pieces())
#   File "/Users/shihab/opt/anaconda3/lib/python3.9/site-packages/stack_data/core.py", line 114, in _clean_pieces
#     raise AssertionError("Pieces mismatches: %s" % mismatches)
# AssertionError: Pieces mismatches: [{249, 250}, {251, 252}]

# %%
# =============================================================
#  PTD-VRPD  – static speed profile, cloud-licence Gurobi
#            depot arrival time is now *free* (feasible)
# =============================================================

#  pip install gurobipy pyswarm ortools pandas numpy scikit-learn

import numpy as np, pandas as pd, itertools
from   sklearn.cluster       import KMeans
from   pyswarm               import pso
import gurobipy as gp
from   gurobipy              import GRB
from   scipy.interpolate      import interp1d
from   scipy.spatial.distance import cdist


# -------------------------------------------------------------
# Cloud licence credentials  –-- EDIT YOUR OWN IDS if needed
# -------------------------------------------------------------
WLS_ID     = "95c3994f-513d-4b8c-a42c-0194dad8ec5c"
WLS_SECRET = "3dc0e444-1f74-49f3-96cc-e9abaabb8ce4"
LICENSE_ID = 2551395
def make_env():
    env = gp.Env(empty=True)
    env.setParam("WLSACCESSID", WLS_ID)
    env.setParam("WLSSECRET",   WLS_SECRET)
    env.setParam("LICENSEID",   LICENSE_ID)
    env.setParam("OutputFlag",  0)
    env.start()
    return env
GRB_ENV = make_env()


# -------------------------------------------------------------
# Global constants
# -------------------------------------------------------------
RNG_SEED            = 42
np.random.seed(RNG_SEED)

AREA_KM             = 10.0
N_DELIVERIES        = 50
DEPOT               = (0., 0.)

DRONE_SPEED_KMH     = 40.
DRONE_END_MIN       = 20
SERVICE_MIN_PER_CL  = 5

BIGM                = 1_000_000.0


# -------------------------------------------------------------
# Speed lookup from Predicted_Speeds.csv
# -------------------------------------------------------------
def build_speed_func(csv_path="Predicted Speed/Predicted_Speeds.csv"):
    df = pd.read_csv(csv_path).rename(columns=str.strip)
    if not {"Time of Day","Predicted Speed"}.issubset(df.columns):
        raise ValueError("CSV must contain 'Time of Day' + 'Predicted Speed'")
    df = df.sort_values("Time of Day")
    f  = interp1d(df["Time of Day"]%24, df["Predicted Speed"],
                  kind="linear", fill_value="extrapolate")
    def speed(t): return float(f(t%24))
    print(f"Loaded {len(df)} speed points – example 09:30 ⇒ {speed(9.5):.1f} km/h")
    return speed
speed_func = build_speed_func()


# -------------------------------------------------------------
# Instance helpers
# -------------------------------------------------------------
def gen_locations(n=N_DELIVERIES, area=AREA_KM):
    return np.vstack([DEPOT, np.random.uniform(-area, area, size=(n,2))])

def kmeans_endurance(locs):
    K=1
    while True:
        km = KMeans(n_clusters=K, random_state=RNG_SEED, n_init=10).fit(locs[1:])
        ok=True
        for i,ctr in enumerate(km.cluster_centers_):
            dkm = np.linalg.norm(locs[1:][km.labels_==i]-ctr, axis=1)
            rt  = 2*dkm/DRONE_SPEED_KMH + SERVICE_MIN_PER_CL/60.
            if (rt>DRONE_END_MIN/60.).any(): ok=False; break
        if ok: return km.labels_, km.cluster_centers_
        K+=1


# -------------------------------------------------------------
# Integrated MILP builder
# -------------------------------------------------------------
def build_milp(locs, centres, labels):
    nStop   = len(centres)+1
    custIdx = np.arange(1,len(locs))

    xy   = np.vstack([DEPOT, centres])
    Dman = cdist(xy,xy,metric="cityblock")
    Deuc = cdist(locs,xy)

    m = gp.Model(env=GRB_ENV);  m.Params.OutputFlag=0

    r    = m.addVars(nStop,nStop,vtype=GRB.BINARY)
    Tdep = m.addVars(nStop,lb=0)
    Tarr = m.addVars(nStop,lb=0)
    Td   = m.addVars(len(centres),lb=0)
    y    = m.addVars(len(custIdx),len(centres),vtype=GRB.BINARY)

    m.setObjective(
          gp.quicksum(Dman[i,j]/speed_func(0)*r[i,j]
                      for i in range(nStop) for j in range(nStop) if i!=j)
        + gp.quicksum(Td[k] for k in range(len(centres)))
        + SERVICE_MIN_PER_CL/60.*len(centres),
        GRB.MINIMIZE)

    for i in range(nStop):
        m.addConstr(gp.quicksum(r[i,j] for j in range(nStop) if j!=i)==1)
        m.addConstr(gp.quicksum(r[j,i] for j in range(nStop) if j!=i)==1)

    u = m.addVars(nStop,lb=0,ub=nStop-1)
    for i,j in itertools.permutations(range(1,nStop),2):
        m.addConstr(u[i]-u[j]+(nStop-1)*r[i,j] <= nStop-2)

    for i,j in itertools.product(range(nStop),range(nStop)):
        if i==j: continue
        m.addConstr(Tarr[j] >= Tdep[i] + Dman[i,j]/speed_func(0)
                    - BIGM*(1-r[i,j]))
        if i!=0:
            m.addConstr(Tdep[i] >= Tarr[i] + Td[i-1] + SERVICE_MIN_PER_CL/60.)
    m.addConstr(Tdep[0]==0)            #  ❌ removed Tarr[0]==0

    for cIdx,cust in enumerate(custIdx):
        m.addConstr(gp.quicksum(y[cIdx,k] for k in range(len(centres)))==1)
        for k in range(len(centres)):
            rt = 2*Deuc[cust,k+1]/DRONE_SPEED_KMH + SERVICE_MIN_PER_CL/60.
            m.addConstr(rt - DRONE_END_MIN/60. - BIGM*(1-y[cIdx,k]) <= 0)
            m.addConstr(Td[k] >= rt*y[cIdx,k])

    return m


# -------------------------------------------------------------
# PSO fitness
# -------------------------------------------------------------
def pso_fitness(w, locs, centres0, labels0):
    K = len(centres0)
    ctrs = centres0 + w.reshape(K,2)

    for k,c in enumerate(ctrs):
        d = np.linalg.norm(locs[1:][labels0==k]-c,axis=1)
        rt= 2*d/DRONE_SPEED_KMH + SERVICE_MIN_PER_CL/60.
        if (rt>DRONE_END_MIN/60.).any(): return 1e6

    m = build_milp(locs, ctrs, labels0); m.optimize()
    return 1e6 if m.SolCount==0 else m.ObjVal


# -------------------------------------------------------------
# Solve one instance
# -------------------------------------------------------------
def solve_instance(locs):
    labels0, centres0 = kmeans_endurance(locs)
    K,lb,ub = len(centres0), [-2]*2*len(centres0), [2]*2*len(centres0)

    best_w,best_f = pso(pso_fitness, lb, ub,
                        swarmsize=30, maxiter=15, debug=False,
                        args=(locs, centres0, labels0))

    chosen = centres0 if best_f>=1e6 else centres0 + best_w.reshape(K,2)
    mdl   = build_milp(locs, chosen, labels0);  mdl.optimize()
    if mdl.SolCount==0:
        mdl = build_milp(locs, centres0, labels0); mdl.optimize()

    return np.inf if mdl.SolCount==0 else mdl.ObjVal


# -------------------------------------------------------------
# Demo
# -------------------------------------------------------------
if __name__=="__main__":
    locs=gen_locations()
    best=solve_instance(locs)
    if np.isfinite(best):
        print(f"\nPTD-VRPD finished – makespan {best:.2f} hours")
    else:
        print("\nPTD-VRPD infeasible (unexpected)")
# Out:
# Loaded 96 speed points – example 09:30 ⇒ 66.3 km/h
# Stopping search: maximum iterations reached --> 15
#
# PTD-VRPD finished – makespan 3.38 hours

# %%
# =============================================================
#  PTD-VRPD  ·  static speed profile · cloud-licence Gurobi
#            + Matplotlib plot of the optimized route
# =============================================================

#  pip install gurobipy pyswarm pandas numpy scikit-learn matplotlib

import numpy as np, pandas as pd, itertools, matplotlib.pyplot as plt
from   sklearn.cluster       import KMeans
from   pyswarm               import pso
import gurobipy as gp
from   gurobipy              import GRB
from   scipy.interpolate      import interp1d
from   scipy.spatial.distance import cdist


# -------------------------------------------------------------
# ➜  SET YOUR CLOUD-LICENCE CREDENTIALS  (unchanged)
# -------------------------------------------------------------
WLS_ID     = "95c3994f-513d-4b8c-a42c-0194dad8ec5c"
WLS_SECRET = "3dc0e444-1f74-49f3-96cc-e9abaabb8ce4"
LICENSE_ID = 2551395
def make_env():
    env = gp.Env(empty=True)
    env.setParam("WLSACCESSID", WLS_ID)
    env.setParam("WLSSECRET",   WLS_SECRET)
    env.setParam("LICENSEID",   LICENSE_ID)
    env.setParam("OutputFlag",  0)
    env.start()
    return env
GRB_ENV = make_env()


# -------------------------------------------------------------
# Global constants
# -------------------------------------------------------------
RNG_SEED            = 42
np.random.seed()

AREA_KM             = 10.0
N_DELIVERIES        = 50
DEPOT               = (0., 0.)

DRONE_SPEED_KMH     = 40.
DRONE_END_MIN       = 20
SERVICE_MIN_PER_CL  = 5
BIGM                = 1_000_000.0


# -------------------------------------------------------------
# Speed lookup
# -------------------------------------------------------------
def build_speed_func(csv_path="Predicted Speed/Predicted_Speeds.csv"):
    df = pd.read_csv(csv_path).rename(columns=str.strip)
    if not {"Time of Day","Predicted Speed"}.issubset(df.columns):
        raise ValueError("CSV must contain 'Time of Day' + 'Predicted Speed'")
    df = df.sort_values("Time of Day")
    f  = interp1d(df["Time of Day"]%24, df["Predicted Speed"],
                  kind="linear", fill_value="extrapolate")
    def speed(t): return float(f(t%24))
    print(f"Loaded {len(df)} speed points – example 09:30 ⇒ {speed(9.5):.1f} km/h")
    return speed
speed_func = build_speed_func()


# -------------------------------------------------------------
# Instance helpers
# -------------------------------------------------------------
def gen_locations(n=N_DELIVERIES, area=AREA_KM):
    return np.vstack([DEPOT, np.random.uniform(-area, area, size=(n,2))])

def kmeans_endurance(locs):
    K=1
    while True:
        km = KMeans(n_clusters=K, random_state=RNG_SEED, n_init=10).fit(locs[1:])
        ok=True
        for i,ctr in enumerate(km.cluster_centers_):
            dkm = np.linalg.norm(locs[1:][km.labels_==i]-ctr, axis=1)
            rt  = 2*dkm/DRONE_SPEED_KMH + SERVICE_MIN_PER_CL/60.
            if (rt>DRONE_END_MIN/60.).any():
                ok=False; break
        if ok: return km.labels_, km.cluster_centers_
        K+=1


# -------------------------------------------------------------
# Integrated MILP builder
# -------------------------------------------------------------
def build_milp(locs, centres, labels):
    nStop   = len(centres)+1
    custIdx = np.arange(1,len(locs))

    xy   = np.vstack([DEPOT, centres])
    Dman = cdist(xy,xy,metric="cityblock")
    Deuc = cdist(locs,xy)

    m = gp.Model(env=GRB_ENV);  m.Params.OutputFlag=0

    r    = m.addVars(nStop,nStop,vtype=GRB.BINARY, name="r")
    Tdep = m.addVars(nStop,lb=0, name="Tdep")
    Tarr = m.addVars(nStop,lb=0, name="Tarr")
    Td   = m.addVars(len(centres),lb=0, name="Tdrone")
    y    = m.addVars(len(custIdx),len(centres),vtype=GRB.BINARY, name="y")

    m.setObjective(
          gp.quicksum(Dman[i,j]/speed_func(0)*r[i,j]
                      for i in range(nStop) for j in range(nStop) if i!=j)
        + gp.quicksum(Td[k] for k in range(len(centres)))
        + SERVICE_MIN_PER_CL/60.*len(centres),
        GRB.MINIMIZE)

    for i in range(nStop):
        m.addConstr(gp.quicksum(r[i,j] for j in range(nStop) if j!=i)==1)
        m.addConstr(gp.quicksum(r[j,i] for j in range(nStop) if j!=i)==1)

    u = m.addVars(nStop,lb=0,ub=nStop-1, name="u")
    for i,j in itertools.permutations(range(1,nStop),2):
        m.addConstr(u[i]-u[j]+(nStop-1)*r[i,j] <= nStop-2)

    for i,j in itertools.product(range(nStop),range(nStop)):
        if i==j: continue
        m.addConstr(Tarr[j] >= Tdep[i] + Dman[i,j]/speed_func(0)
                    - BIGM*(1-r[i,j]))
        if i!=0:
            m.addConstr(Tdep[i] >= Tarr[i] + Td[i-1] + SERVICE_MIN_PER_CL/60.)
    m.addConstr(Tdep[0]==0)      # depot departure time fixed

    for cIdx,cust in enumerate(custIdx):
        m.addConstr(gp.quicksum(y[cIdx,k] for k in range(len(centres)))==1)
        for k in range(len(centres)):
            rt = 2*Deuc[cust,k+1]/DRONE_SPEED_KMH + SERVICE_MIN_PER_CL/60.
            m.addConstr(rt - DRONE_END_MIN/60.-BIGM*(1-y[cIdx,k]) <= 0)
            m.addConstr(Td[k] >= rt * y[cIdx,k])

    return m, r


# -------------------------------------------------------------
# PSO fitness
# -------------------------------------------------------------
def pso_fitness(w, locs, centres0, labels0):
    K=len(centres0)
    ctrs = centres0 + w.reshape(K,2)
    # quick reject
    for k,c in enumerate(ctrs):
        d = np.linalg.norm(locs[1:][labels0==k]-c,axis=1)
        rt= 2*d/DRONE_SPEED_KMH + SERVICE_MIN_PER_CL/60.
        if (rt>DRONE_END_MIN/60.).any(): return 1e6
    m,_ = build_milp(locs, ctrs, labels0); m.optimize()
    return 1e6 if m.SolCount==0 else m.ObjVal


# -------------------------------------------------------------
# Extract route from r[i,j] binaries
# -------------------------------------------------------------
def extract_route(r_vars):
    # r_vars keys are 2-tuples
    edges = {(i,j) for (i,j),var in r_vars.items() if var.X > 0.5}
    route = [0]
    while len(route) < len(r_vars)**0.5:
        last = route[-1]
        next_stop = next(j for (i,j) in edges if i==last)
        if next_stop==0: break
        route.append(next_stop)
    route.append(0)
    return route


# -------------------------------------------------------------
# Solve instance and plot
# -------------------------------------------------------------
def solve_and_plot(locs):
    labels0, centres0 = kmeans_endurance(locs)
    K  = len(centres0)
    lb = [-2]*2*K;  ub=[2]*2*K

    best_w,best_f = pso(pso_fitness, lb, ub,
                        swarmsize=30, maxiter=15, debug=False,
                        args=(locs, centres0, labels0))

    centres = centres0 if best_f>=1e6 else centres0 + best_w.reshape(K,2)
    mdl,rVars = build_milp(locs, centres, labels0);  mdl.optimize()

    if mdl.SolCount==0:          # fallback (shouldn’t happen)
        centres = centres0
        mdl,rVars = build_milp(locs, centres, labels0); mdl.optimize()

    makespan = np.inf if mdl.SolCount==0 else mdl.ObjVal

    # plot
    route = extract_route(rVars)
    plt.figure(figsize=(7,7))
    # customers
    for k in range(K):
        pts = locs[1:][labels0==k]
        plt.scatter(pts[:,0], pts[:,1], s=15, alpha=0.6, label=f'Cluster {k+1}')
    # centres
    plt.scatter(centres[:,0], centres[:,1], marker='^', c='k', s=80, label='Stop')
    # depot
    plt.scatter(*DEPOT, marker='*', c='red', s=120, label='Depot')
    # truck path
    path_xy = np.vstack([DEPOT, centres])[route]
    plt.plot(path_xy[:,0], path_xy[:,1], 'k--', lw=1.5, label='Truck path')
    plt.title(f'Optimized truck route  |  makespan {makespan:.2f} h')
    plt.legend(loc='best', fontsize=8)
    plt.axis('equal'); plt.grid(True)
    plt.show()

    return makespan


# -------------------------------------------------------------
# Run
# -------------------------------------------------------------
if __name__ == "__main__":
    locs = gen_locations()
    best = solve_and_plot(locs)
    if np.isfinite(best):
        print(f"\nPTD-VRPD finished – makespan {best:.2f} hours")
    else:
        print("\nPTD-VRPD infeasible (unexpected)")
# Out:
# Loaded 96 speed points – example 09:30 ⇒ 66.3 km/h
# Stopping search: maximum iterations reached --> 15
# PTD-VRPD finished – makespan 3.82 hours

# %%
# =============================================================
#  PTD-VRPD  ·  static speed profile · cloud-licence Gurobi
#            + debug print statements
# =============================================================

#  pip install gurobipy pyswarm ortools pandas numpy scikit-learn matplotlib

import numpy as np, pandas as pd, itertools, matplotlib.pyplot as plt
from   sklearn.cluster       import KMeans
from   pyswarm               import pso
import gurobipy as gp
from   gurobipy              import GRB
from   scipy.interpolate      import interp1d
from   scipy.spatial.distance import cdist

# -------------------------------------------------------------
# 0.  Cloud licence credentials
# -------------------------------------------------------------
WLS_ID     = "95c3994f-513d-4b8c-a42c-0194dad8ec5c"
WLS_SECRET = "3dc0e444-1f74-49f3-96cc-e9abaabb8ce4"
LICENSE_ID = 2551395
def make_env():
    env = gp.Env(empty=True)
    env.setParam("WLSACCESSID", WLS_ID)
    env.setParam("WLSSECRET",   WLS_SECRET)
    env.setParam("LICENSEID",   LICENSE_ID)
    env.setParam("OutputFlag",  0)
    env.start()
    return env
GRB_ENV = make_env()
print("[DEBUG] Gurobi cloud environment initialized.")

# -------------------------------------------------------------
# 1.  Global constants
# -------------------------------------------------------------
RNG_SEED            = 42
np.random.seed(RNG_SEED)

AREA_KM             = 10.0
N_DELIVERIES        = 50
DEPOT               = (0., 0.)

DRONE_SPEED_KMH     = 40.
DRONE_END_MIN       = 20
SERVICE_MIN_PER_CL  = 5
BIGM                = 1_000_000.0

# -------------------------------------------------------------
# 2.  Speed lookup
# -------------------------------------------------------------
def build_speed_func(csv_path="Predicted Speed/Predicted_Speeds.csv"):
    df = pd.read_csv(csv_path).rename(columns=str.strip)
    if not {"Time of Day","Predicted Speed"}.issubset(df.columns):
        raise ValueError("CSV must contain 'Time of Day' + 'Predicted Speed'")
    df = df.sort_values("Time of Day")
    f  = interp1d(df["Time of Day"]%24, df["Predicted Speed"],
                  kind="linear", fill_value="extrapolate")
    def speed(t): return float(f(t%24))
    print(f"[DEBUG] Loaded {len(df)} speed points – example 09:30 ⇒ {speed(9.5):.1f} km/h")
    return speed

speed_func = build_speed_func()

# -------------------------------------------------------------
# 3.  Instance helpers
# -------------------------------------------------------------
def gen_locations(n=N_DELIVERIES, area=AREA_KM):
    locs = np.vstack([DEPOT, np.random.uniform(-area, area, size=(n,2))])
    print(f"[DEBUG] Generated {n} delivery locations.")
    return locs

def kmeans_endurance(locs):
    K=1
    while True:
        km = KMeans(n_clusters=K, random_state=RNG_SEED, n_init=10).fit(locs[1:])
        ok=True
        for i,ctr in enumerate(km.cluster_centers_):
            dkm = np.linalg.norm(locs[1:][km.labels_==i]-ctr,axis=1)
            rt  = 2*dkm/DRONE_SPEED_KMH + SERVICE_MIN_PER_CL/60.
            if (rt>DRONE_END_MIN/60.).any():
                ok=False; break
        if ok:
            print(f"[DEBUG] K-means found feasible K={K} clusters.")
            return km.labels_, km.cluster_centers_
        K+=1

# -------------------------------------------------------------
# 4.  Integrated MILP builder
# -------------------------------------------------------------
def build_milp(locs, centres, labels):
    nStop   = len(centres)+1
    custIdx = np.arange(1,len(locs))

    xy   = np.vstack([DEPOT, centres])
    Dman = cdist(xy,xy,metric="cityblock")
    Deuc = cdist(locs,xy)

    m = gp.Model(env=GRB_ENV)
    m.Params.OutputFlag = 0

    r    = m.addVars(nStop,nStop,vtype=GRB.BINARY, name="r")
    Tdep = m.addVars(nStop,lb=0, name="Tdep")
    Tarr = m.addVars(nStop,lb=0, name="Tarr")
    Td   = m.addVars(len(centres),lb=0, name="Tdrone")
    y    = m.addVars(len(custIdx),len(centres),vtype=GRB.BINARY, name="y")

    m.setObjective(
          gp.quicksum(Dman[i,j]/speed_func(0)*r[i,j]
                      for i in range(nStop) for j in range(nStop) if i!=j)
        + gp.quicksum(Td[k] for k in range(len(centres)))
        + SERVICE_MIN_PER_CL/60.*len(centres),
        GRB.MINIMIZE)

    # routing & subtours
    for i in range(nStop):
        m.addConstr(gp.quicksum(r[i,j] for j in range(nStop) if j!=i)==1)
        m.addConstr(gp.quicksum(r[j,i] for j in range(nStop) if j!=i)==1)
    u = m.addVars(nStop,lb=0,ub=nStop-1)
    for i,j in itertools.permutations(range(1,nStop),2):
        m.addConstr(u[i]-u[j]+(nStop-1)*r[i,j] <= nStop-2)

    # timing
    for i,j in itertools.product(range(nStop),range(nStop)):
        if i==j: continue
        m.addConstr(Tarr[j] >= Tdep[i] + Dman[i,j]/speed_func(0)
                    - BIGM*(1-r[i,j]))
        if i!=0:
            m.addConstr(Tdep[i] >= Tarr[i] + Td[i-1] + SERVICE_MIN_PER_CL/60.)
    m.addConstr(Tdep[0]==0)

    # assignment & drone endurance
    for cIdx,cust in enumerate(custIdx):
        m.addConstr(gp.quicksum(y[cIdx,k] for k in range(len(centres)))==1)
        for k in range(len(centres)):
            rt = 2*Deuc[cust,k+1]/DRONE_SPEED_KMH + SERVICE_MIN_PER_CL/60.
            m.addConstr(rt - DRONE_END_MIN/60.-BIGM*(1-y[cIdx,k]) <= 0)
            m.addConstr(Td[k] >= rt * y[cIdx,k])

    print(f"[DEBUG] Built MILP with {nStop} stops and {len(custIdx)} customers.")
    return m, r

# -------------------------------------------------------------
# 5.  PSO fitness
# -------------------------------------------------------------
def pso_fitness(w, locs, centres0, labels0):
    K    = len(centres0)
    ctrs = centres0 + w.reshape(K,2)

    # quick reject & debug
    for k,c in enumerate(ctrs):
        d = np.linalg.norm(locs[1:][labels0==k]-c,axis=1)
        rt= 2*d/DRONE_SPEED_KMH + SERVICE_MIN_PER_CL/60.
        if (rt>DRONE_END_MIN/60.).any():
            print(f"[DEBUG][PSO] Particle violated endurance in cluster {k}.")
            return 1e6

    m,_ = build_milp(locs, ctrs, labels0)
    m.optimize()
    if m.SolCount == 0:
        print("[DEBUG][PSO] Particle MILP infeasible.")
        return 1e6

    print(f"[DEBUG][PSO] Particle objective = {m.ObjVal:.2f} h")
    return m.ObjVal

# -------------------------------------------------------------
# 6.  Extract and plot route
# -------------------------------------------------------------
def extract_route(r_vars):
    edges = {(i,j) for (i,j),v in r_vars.items() if v.X>0.5}
    route=[0]
    nStop = int(np.sqrt(len(r_vars)))
    while len(route)<nStop+1:
        last=route[-1]
        nxt = next(j for (i,j) in edges if i==last)
        route.append(nxt)
        if nxt==0: break
    print(f"[DEBUG] Extracted truck route: {route}")
    return route

def plot_solution(locs, centres, labels, route, makespan):
    plt.figure(figsize=(7,7))
    K = len(centres)
    for k in range(K):
        pts=locs[1:][labels==k]
        plt.scatter(pts[:,0],pts[:,1],s=15,alpha=0.6,label=f'Cluster {k+1}')
    plt.scatter(centres[:,0],centres[:,1],marker='^',c='k',s=80,label='Stop')
    plt.scatter(*DEPOT,marker='*',c='red',s=120,label='Depot')
    path_xy=np.vstack([DEPOT,centres])[route]
    plt.plot(path_xy[:,0],path_xy[:,1],'k--',lw=1.5,label='Truck path')
    plt.title(f'Optimized route (makespan {makespan:.2f} h)')
    plt.legend(fontsize=8); plt.axis('equal'); plt.grid(True)
    plt.show()

# -------------------------------------------------------------
# 7.  Solve & plot in one go
# -------------------------------------------------------------
def solve_and_plot(locs):
    labels0, centres0 = kmeans_endurance(locs)
    K  = len(centres0)
    lb = [-2]*2*K; ub=[2]*2*K

    print("[DEBUG] Starting PSO...")
    best_w, best_f = pso(pso_fitness, lb, ub,
                        swarmsize=30, maxiter=15, debug=False,
                        args=(locs, centres0, labels0))
    print(f"[DEBUG] PSO completed: best_f = {best_f:.2f}")

    centres = centres0 if best_f>=1e6 else centres0 + best_w.reshape(K,2)
    print(f"[DEBUG] Using centres:\n{centres}")

    mdl, rVars = build_milp(locs, centres, labels0)
    mdl.optimize()
    if mdl.SolCount==0:
        print("[DEBUG] Final MILP infeasible, falling back to raw centres.")
        centres = centres0
        mdl, rVars = build_milp(locs, centres, labels0)
        mdl.optimize()

    makespan = np.inf if mdl.SolCount==0 else mdl.ObjVal
    route    = extract_route(rVars)
    plot_solution(locs, centres, labels0, route, makespan)
    return makespan

# -------------------------------------------------------------
# 8.  Demo run
# -------------------------------------------------------------
if __name__=="__main__":
    locs = gen_locations()
    best = solve_and_plot(locs)
    if np.isfinite(best):
        print(f"\nPTD-VRPD finished – makespan {best:.2f} hours")
    else:
        print("\nPTD-VRPD infeasible (unexpected)")
# Out:
# [DEBUG] Gurobi cloud environment initialized.
# [DEBUG] Loaded 96 speed points – example 09:30 ⇒ 66.3 km/h
# [DEBUG] Generated 50 delivery locations.
# [DEBUG] K-means found feasible K=7 clusters.
# [DEBUG] Starting PSO...
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 3.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 1.
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.59 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.56 h
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.63 h
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.57 h
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.60 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.66 h
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.54 h
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.58 h
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.62 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.60 h
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.62 h
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.63 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.63 h
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.55 h
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.54 h
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.51 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.58 h
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.54 h
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.55 h
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.62 h
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.51 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.57 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.56 h
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.49 h
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.54 h
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.68 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.51 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.52 h
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG][PSO] Particle violated endurance in cluster 2.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.49 h
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.48 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.49 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.52 h
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.52 h
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.50 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.51 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.52 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.47 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.48 h
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.53 h
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.57 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.50 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.49 h
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.57 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.49 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.51 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.48 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.46 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.47 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.48 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.49 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.57 h
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.55 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.48 h
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.48 h
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.64 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.51 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.45 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.50 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.46 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.48 h
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.50 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.62 h
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.50 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.49 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.46 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.68 h
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.50 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.47 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.45 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.44 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.44 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.47 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.45 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.46 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.50 h
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.53 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.47 h
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.47 h
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.55 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.48 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.45 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.46 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.43 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.46 h
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.47 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.52 h
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.46 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.47 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.45 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.61 h
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.46 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.46 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.43 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.43 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.42 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.47 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.44 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.44 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.45 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.40 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.45 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.46 h
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.46 h
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.49 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.44 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.44 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.42 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.43 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.45 h
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.43 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.48 h
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.46 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.46 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.43 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.51 h
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.44 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.43 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.45 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.45 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.40 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.45 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.43 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.42 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.42 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.40 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.43 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.44 h
# [DEBUG][PSO] Particle violated endurance in cluster 4.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.45 h
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.45 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.42 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.43 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.42 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.42 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.45 h
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.43 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.43 h
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.44 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.42 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.42 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.43 h
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.43 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.41 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.44 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.43 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.40 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.42 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.42 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.41 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.40 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.44 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.42 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.44 h
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.44 h
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.41 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.42 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.42 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.41 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.43 h
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.41 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.41 h
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.42 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.41 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.41 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.42 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.63 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.42 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.41 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.41 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.41 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.39 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.40 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.41 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.39 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.38 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.42 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.42 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.44 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.59 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.42 h
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.41 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.39 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.40 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.41 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.39 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.40 h
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.39 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.40 h
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.40 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.39 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.40 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.38 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.50 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.38 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.40 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.39 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.39 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.39 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.39 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.40 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.38 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.38 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.41 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.40 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.41 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.51 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.40 h
# [DEBUG][PSO] Particle violated endurance in cluster 0.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.39 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.38 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.40 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.40 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.39 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.39 h
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.38 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.39 h
# [DEBUG][PSO] Particle violated endurance in cluster 5.
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.39 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.38 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.39 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.38 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.44 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.38 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.40 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.38 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.38 h
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG][PSO] Particle objective = 3.39 h
# Stopping search: maximum iterations reached --> 15
# [DEBUG] PSO completed: best_f = 3.38
# [DEBUG] Using centres:
# [[-6.78064053 -6.61368776]
#  [ 5.7539058   0.59778734]
#  [-8.05502401  6.97307605]
#  [ 3.54793856 -5.33256264]
#  [ 0.14703493  6.47620863]
#  [-3.81789901 -0.83095701]
#  [ 8.99767691  6.33353488]]
# [DEBUG] Built MILP with 8 stops and 50 customers.
# [DEBUG] Extracted truck route: [0, 4, 2, 7, 5, 3, 1, 6, 0]
# PTD-VRPD finished – makespan 3.38 hours

# %%
# =============================================================
#  PTD-VRPD  ·  static speed profile · cloud-licence Gurobi
#            + per-MILP debug: truck/drone/service/total times
# =============================================================

#  pip install gurobipy pyswarm ortools pandas numpy scikit-learn matplotlib

import numpy as np, pandas as pd, itertools, matplotlib.pyplot as plt
from   sklearn.cluster       import KMeans
from   pyswarm               import pso
import gurobipy as gp
from   gurobipy              import GRB
from   scipy.interpolate      import interp1d
from   scipy.spatial.distance import cdist

# -------------------------------------------------------------
# 0. Cloud licence credentials
# -------------------------------------------------------------
WLS_ID     = "95c3994f-513d-4b8c-a42c-0194dad8ec5c"
WLS_SECRET = "3dc0e444-1f74-49f3-96cc-e9abaabb8ce4"
LICENSE_ID = 2551395
def make_env():
    env = gp.Env(empty=True)
    env.setParam("WLSACCESSID", WLS_ID)
    env.setParam("WLSSECRET",   WLS_SECRET)
    env.setParam("LICENSEID",   LICENSE_ID)
    env.setParam("OutputFlag",  0)
    env.start()
    return env
GRB_ENV = make_env()
print("[DEBUG] Gurobi cloud environment initialized.")

# -------------------------------------------------------------
# 1. Global constants
# -------------------------------------------------------------
RNG_SEED            = 42
np.random.seed(RNG_SEED)

AREA_KM             = 10.0
N_DELIVERIES        = 50
DEPOT               = (0., 0.)

DRONE_SPEED_KMH     = 40.
DRONE_END_MIN       = 20
SERVICE_MIN_PER_CL  = 5
BIGM                = 1_000_000.0

# -------------------------------------------------------------
# 2. Speed lookup
# -------------------------------------------------------------
def build_speed_func(csv_path="Predicted Speed/Predicted_Speeds.csv"):
    df = pd.read_csv(csv_path).rename(columns=str.strip)
    if not {"Time of Day","Predicted Speed"}.issubset(df.columns):
        raise ValueError("CSV must contain 'Time of Day' and 'Predicted Speed'")
    df = df.sort_values("Time of Day")
    f  = interp1d(df["Time of Day"]%24, df["Predicted Speed"],
                  kind="linear", fill_value="extrapolate")
    def speed(t): return float(f(t%24))
    print(f"[DEBUG] Loaded {len(df)} speed points – example 09:30 ⇒ {speed(9.5):.1f} km/h")
    return speed
speed_func = build_speed_func()

# -------------------------------------------------------------
# 3. Instance helpers
# -------------------------------------------------------------
def gen_locations(n=N_DELIVERIES, area=AREA_KM):
    locs = np.vstack([DEPOT, np.random.uniform(-area, area, size=(n,2))])
    print(f"[DEBUG] Generated {n} delivery locations.")
    return locs

def kmeans_endurance(locs):
    K=1
    while True:
        km = KMeans(n_clusters=K, random_state=RNG_SEED, n_init=10).fit(locs[1:])
        ok=True
        for i,ctr in enumerate(km.cluster_centers_):
            dkm = np.linalg.norm(locs[1:][km.labels_==i]-ctr, axis=1)
            rt  = 2*dkm/DRONE_SPEED_KMH + SERVICE_MIN_PER_CL/60.
            if (rt>DRONE_END_MIN/60.).any():
                ok=False; break
        if ok:
            print(f"[DEBUG] K-means found feasible K={K} clusters.")
            return km.labels_, km.cluster_centers_
        K+=1

# -------------------------------------------------------------
# 4. Build & solve MILP, with debug prints
# -------------------------------------------------------------
def build_and_solve_milp(locs, centres, labels, tag=""):
    """
    Builds and solves the MILP, then prints truck/drone/service/total times.
    Returns (model, rVars).
    """
    nStop   = len(centres)+1
    custIdx = np.arange(1,len(locs))

    xy   = np.vstack([DEPOT, centres])
    Dman = cdist(xy,xy,metric="cityblock")
    Deuc = cdist(locs,xy)

    m = gp.Model(env=GRB_ENV)
    m.Params.OutputFlag = 0

    r    = m.addVars(nStop,nStop, vtype=GRB.BINARY, name="r")
    Tdep = m.addVars(nStop, lb=0, name="Tdep")
    Tarr = m.addVars(nStop, lb=0, name="Tarr")
    Td   = m.addVars(len(centres), lb=0, name="Tdrone")
    y    = m.addVars(len(custIdx), len(centres), vtype=GRB.BINARY, name="y")

    # Objective
    m.setObjective(
        gp.quicksum(Dman[i,j]/speed_func(0)*r[i,j]
                    for i in range(nStop) for j in range(nStop) if i!=j)
      + gp.quicksum(Td[k] for k in range(len(centres)))
      + SERVICE_MIN_PER_CL/60.*len(centres),
      GRB.MINIMIZE)

    # Routing & subtours
    for i in range(nStop):
        m.addConstr(gp.quicksum(r[i,j] for j in range(nStop) if j!=i)==1)
        m.addConstr(gp.quicksum(r[j,i] for j in range(nStop) if j!=i)==1)
    u = m.addVars(nStop, lb=0, ub=nStop-1, name="u")
    for i,j in itertools.permutations(range(1,nStop),2):
        m.addConstr(u[i]-u[j]+(nStop-1)*r[i,j] <= nStop-2)

    # Timing
    for i,j in itertools.product(range(nStop),range(nStop)):
        if i==j: continue
        m.addConstr(Tarr[j] >= Tdep[i] + Dman[i,j]/speed_func(0)
                    - BIGM*(1-r[i,j]))
        if i!=0:
            m.addConstr(Tdep[i] >= Tarr[i] + Td[i-1] + SERVICE_MIN_PER_CL/60.)
    m.addConstr(Tdep[0]==0)

    # Drone assignment & endurance
    for cIdx,cust in enumerate(custIdx):
        m.addConstr(gp.quicksum(y[cIdx,k] for k in range(len(centres)))==1)
        for k in range(len(centres)):
            rt = 2*Deuc[cust,k+1]/DRONE_SPEED_KMH + SERVICE_MIN_PER_CL/60.
            m.addConstr(rt - DRONE_END_MIN/60. - BIGM*(1-y[cIdx,k]) <= 0)
            m.addConstr(Td[k] >= rt * y[cIdx,k])

    # Solve
    m.optimize()
    if m.SolCount == 0:
        print(f"[DEBUG]{tag} MILP infeasible.")
        return m, r

    # Compute times
    truck_time  = sum((Dman[i,j]/speed_func(0)) * r[i,j].X
                       for i in range(nStop) for j in range(nStop) if i!=j)
    drone_time  = sum(Td[k].X for k in range(len(centres)))
    service_time= SERVICE_MIN_PER_CL/60.*len(centres)
    total_time  = truck_time + drone_time + service_time

    print(f"[DEBUG]{tag} MILP solved:")
    print(f"        Truck time:  {truck_time:.3f} h")
    print(f"        Drone time:  {drone_time:.3f} h")
    print(f"        Service time:{service_time:.3f} h")
    print(f"        Total time:  {total_time:.3f} h  (ObjVal {m.ObjVal:.3f})")
    return m, r

# -------------------------------------------------------------
# 5. PSO fitness
# -------------------------------------------------------------
def pso_fitness(w, locs, centres0, labels0):
    K    = len(centres0)
    ctrs = centres0 + w.reshape(K,2)

    # quick reject
    for k,c in enumerate(ctrs):
        d = np.linalg.norm(locs[1:][labels0==k]-c,axis=1)
        rt= 2*d/DRONE_SPEED_KMH + SERVICE_MIN_PER_CL/60.
        if (rt>DRONE_END_MIN/60.).any():
            print(f"[DEBUG][PSO] Particle violates endurance at cluster {k}.")
            return 1e6

    m,r = build_and_solve_milp(locs, ctrs, labels0, tag="[PSO]")
    return 1e6 if m.SolCount==0 else m.ObjVal

# -------------------------------------------------------------
# 6. Extract route helper
# -------------------------------------------------------------
def extract_route(r_vars):
    edges = {(i,j) for (i,j),v in r_vars.items() if v.X>0.5}
    route=[0]
    nStop = int(np.sqrt(len(r_vars)))
    while len(route)<nStop+1:
        last=route[-1]
        nxt = next(j for (i,j) in edges if i==last)
        route.append(nxt)
        if nxt==0: break
    print(f"[DEBUG] Extracted route: {route}")
    return route

# -------------------------------------------------------------
# 7. Solve & plot
# -------------------------------------------------------------
def solve_and_plot(locs):
    labels0, centres0 = kmeans_endurance(locs)
    K  = len(centres0)
    lb = [-2]*2*K; ub=[2]*2*K

    print("[DEBUG] Starting PSO...")
    best_w, best_f = pso(pso_fitness, lb, ub,
                        swarmsize=30, maxiter=15, debug=False,
                        args=(locs, centres0, labels0))
    print(f"[DEBUG] PSO best_f = {best_f:.3f}")

    centres = centres0 if best_f>=1e6 else centres0 + best_w.reshape(K,2)
    mdl, rVars = build_and_solve_milp(locs, centres, labels0, tag="[FINAL]")
    if mdl.SolCount==0:
        print("[DEBUG] FINAL MILP infeasible, falling back.")
        centres = centres0
        mdl, rVars = build_and_solve_milp(locs, centres, labels0, tag="[FALLBACK]")

    route = extract_route(rVars)

    # Plot
    plt.figure(figsize=(7,7))
    for k in range(len(centres)):
        pts=locs[1:][labels0==k]
        plt.scatter(pts[:,0],pts[:,1],s=15,alpha=0.6,label=f'Cluster {k+1}')
    plt.scatter(centres[:,0],centres[:,1],marker='^',c='k',s=80,label='Stop')
    plt.scatter(*DEPOT,marker='*',c='red',s=120,label='Depot')
    path_xy=np.vstack([DEPOT,centres])[route]
    plt.plot(path_xy[:,0],path_xy[:,1],'k--',lw=1.5,label='Truck path')
    plt.title(f'Route (makespan {mdl.ObjVal:.2f} h)')
    plt.legend(fontsize=8); plt.axis('equal'); plt.grid(True)
    plt.show()

    return mdl.ObjVal

# -------------------------------------------------------------
# 8. Demo run
# -------------------------------------------------------------
if __name__=="__main__":
    locs = gen_locations()
    best = solve_and_plot(locs)
    if np.isfinite(best):
        print(f"\nPTD-VRPD finished – makespan {best:.2f} hours")
    else:
        print("\nPTD-VRPD infeasible (unexpected)")
# Out:
# [DEBUG] Gurobi cloud environment initialized.
# [DEBUG] Loaded 96 speed points – example 09:30 ⇒ 66.3 km/h
# [DEBUG] Generated 50 delivery locations.
# [DEBUG] K-means found feasible K=7 clusters.
# [DEBUG] Starting PSO...
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 3.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 1.
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.118 h
#         Drone time:  1.893 h
#         Service time:0.583 h
#         Total time:  3.594 h  (ObjVal 3.594)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.094 h
#         Drone time:  1.877 h
#         Service time:0.583 h
#         Total time:  3.555 h  (ObjVal 3.555)
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.121 h
#         Drone time:  1.926 h
#         Service time:0.583 h
#         Total time:  3.631 h  (ObjVal 3.631)
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.098 h
#         Drone time:  1.892 h
#         Service time:0.583 h
#         Total time:  3.574 h  (ObjVal 3.574)
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.122 h
#         Drone time:  1.897 h
#         Service time:0.583 h
#         Total time:  3.603 h  (ObjVal 3.603)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.153 h
#         Drone time:  1.924 h
#         Service time:0.583 h
#         Total time:  3.660 h  (ObjVal 3.660)
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.071 h
#         Drone time:  1.888 h
#         Service time:0.583 h
#         Total time:  3.543 h  (ObjVal 3.543)
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.116 h
#         Drone time:  1.879 h
#         Service time:0.583 h
#         Total time:  3.578 h  (ObjVal 3.578)
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.065 h
#         Drone time:  1.976 h
#         Service time:0.583 h
#         Total time:  3.624 h  (ObjVal 3.624)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.042 h
#         Drone time:  1.973 h
#         Service time:0.583 h
#         Total time:  3.599 h  (ObjVal 3.599)
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.145 h
#         Drone time:  1.896 h
#         Service time:0.583 h
#         Total time:  3.624 h  (ObjVal 3.624)
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.119 h
#         Drone time:  1.930 h
#         Service time:0.583 h
#         Total time:  3.633 h  (ObjVal 3.633)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.130 h
#         Drone time:  1.921 h
#         Service time:0.583 h
#         Total time:  3.634 h  (ObjVal 3.634)
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.060 h
#         Drone time:  1.909 h
#         Service time:0.583 h
#         Total time:  3.552 h  (ObjVal 3.552)
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.097 h
#         Drone time:  1.857 h
#         Service time:0.583 h
#         Total time:  3.537 h  (ObjVal 3.537)
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.012 h
#         Drone time:  1.913 h
#         Service time:0.583 h
#         Total time:  3.509 h  (ObjVal 3.509)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.105 h
#         Drone time:  1.893 h
#         Service time:0.583 h
#         Total time:  3.582 h  (ObjVal 3.582)
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.025 h
#         Drone time:  1.927 h
#         Service time:0.583 h
#         Total time:  3.536 h  (ObjVal 3.536)
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.048 h
#         Drone time:  1.918 h
#         Service time:0.583 h
#         Total time:  3.550 h  (ObjVal 3.550)
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.064 h
#         Drone time:  1.971 h
#         Service time:0.583 h
#         Total time:  3.619 h  (ObjVal 3.619)
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.081 h
#         Drone time:  1.850 h
#         Service time:0.583 h
#         Total time:  3.515 h  (ObjVal 3.515)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.073 h
#         Drone time:  1.913 h
#         Service time:0.583 h
#         Total time:  3.570 h  (ObjVal 3.570)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.047 h
#         Drone time:  1.926 h
#         Service time:0.583 h
#         Total time:  3.556 h  (ObjVal 3.556)
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.052 h
#         Drone time:  1.855 h
#         Service time:0.583 h
#         Total time:  3.490 h  (ObjVal 3.490)
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.104 h
#         Drone time:  1.856 h
#         Service time:0.583 h
#         Total time:  3.544 h  (ObjVal 3.544)
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.093 h
#         Drone time:  1.999 h
#         Service time:0.583 h
#         Total time:  3.676 h  (ObjVal 3.676)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.036 h
#         Drone time:  1.886 h
#         Service time:0.583 h
#         Total time:  3.505 h  (ObjVal 3.505)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.076 h
#         Drone time:  1.856 h
#         Service time:0.583 h
#         Total time:  3.516 h  (ObjVal 3.516)
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] Particle violates endurance at cluster 2.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.050 h
#         Drone time:  1.855 h
#         Service time:0.583 h
#         Total time:  3.488 h  (ObjVal 3.488)
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.010 h
#         Drone time:  1.891 h
#         Service time:0.583 h
#         Total time:  3.485 h  (ObjVal 3.485)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.043 h
#         Drone time:  1.858 h
#         Service time:0.583 h
#         Total time:  3.485 h  (ObjVal 3.485)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.025 h
#         Drone time:  1.910 h
#         Service time:0.583 h
#         Total time:  3.518 h  (ObjVal 3.518)
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.022 h
#         Drone time:  1.911 h
#         Service time:0.583 h
#         Total time:  3.516 h  (ObjVal 3.516)
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.036 h
#         Drone time:  1.878 h
#         Service time:0.583 h
#         Total time:  3.497 h  (ObjVal 3.497)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.035 h
#         Drone time:  1.888 h
#         Service time:0.583 h
#         Total time:  3.506 h  (ObjVal 3.506)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.005 h
#         Drone time:  1.934 h
#         Service time:0.583 h
#         Total time:  3.522 h  (ObjVal 3.522)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.047 h
#         Drone time:  1.842 h
#         Service time:0.583 h
#         Total time:  3.472 h  (ObjVal 3.472)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.045 h
#         Drone time:  1.847 h
#         Service time:0.583 h
#         Total time:  3.475 h  (ObjVal 3.475)
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.087 h
#         Drone time:  1.862 h
#         Service time:0.583 h
#         Total time:  3.532 h  (ObjVal 3.532)
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.089 h
#         Drone time:  1.902 h
#         Service time:0.583 h
#         Total time:  3.575 h  (ObjVal 3.575)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.053 h
#         Drone time:  1.867 h
#         Service time:0.583 h
#         Total time:  3.504 h  (ObjVal 3.504)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.062 h
#         Drone time:  1.849 h
#         Service time:0.583 h
#         Total time:  3.494 h  (ObjVal 3.494)
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.051 h
#         Drone time:  1.936 h
#         Service time:0.583 h
#         Total time:  3.570 h  (ObjVal 3.570)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.053 h
#         Drone time:  1.853 h
#         Service time:0.583 h
#         Total time:  3.489 h  (ObjVal 3.489)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.070 h
#         Drone time:  1.857 h
#         Service time:0.583 h
#         Total time:  3.510 h  (ObjVal 3.510)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.031 h
#         Drone time:  1.869 h
#         Service time:0.583 h
#         Total time:  3.484 h  (ObjVal 3.484)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.007 h
#         Drone time:  1.872 h
#         Service time:0.583 h
#         Total time:  3.463 h  (ObjVal 3.463)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.024 h
#         Drone time:  1.864 h
#         Service time:0.583 h
#         Total time:  3.472 h  (ObjVal 3.472)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.004 h
#         Drone time:  1.887 h
#         Service time:0.583 h
#         Total time:  3.475 h  (ObjVal 3.475)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.057 h
#         Drone time:  1.846 h
#         Service time:0.583 h
#         Total time:  3.486 h  (ObjVal 3.486)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.060 h
#         Drone time:  1.922 h
#         Service time:0.583 h
#         Total time:  3.565 h  (ObjVal 3.565)
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.068 h
#         Drone time:  1.896 h
#         Service time:0.583 h
#         Total time:  3.547 h  (ObjVal 3.547)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.031 h
#         Drone time:  1.869 h
#         Service time:0.583 h
#         Total time:  3.484 h  (ObjVal 3.484)
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.003 h
#         Drone time:  1.890 h
#         Service time:0.583 h
#         Total time:  3.476 h  (ObjVal 3.476)
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.066 h
#         Drone time:  1.987 h
#         Service time:0.583 h
#         Total time:  3.636 h  (ObjVal 3.636)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.027 h
#         Drone time:  1.896 h
#         Service time:0.583 h
#         Total time:  3.506 h  (ObjVal 3.506)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.006 h
#         Drone time:  1.856 h
#         Service time:0.583 h
#         Total time:  3.446 h  (ObjVal 3.446)
# [DEBUG][PSO] MILP solved:
#         Truck time:  0.998 h
#         Drone time:  1.917 h
#         Service time:0.583 h
#         Total time:  3.499 h  (ObjVal 3.499)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.032 h
#         Drone time:  1.846 h
#         Service time:0.583 h
#         Total time:  3.461 h  (ObjVal 3.461)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.031 h
#         Drone time:  1.863 h
#         Service time:0.583 h
#         Total time:  3.477 h  (ObjVal 3.477)
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.055 h
#         Drone time:  1.865 h
#         Service time:0.583 h
#         Total time:  3.503 h  (ObjVal 3.503)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.127 h
#         Drone time:  1.912 h
#         Service time:0.583 h
#         Total time:  3.622 h  (ObjVal 3.622)
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.057 h
#         Drone time:  1.864 h
#         Service time:0.583 h
#         Total time:  3.505 h  (ObjVal 3.505)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.050 h
#         Drone time:  1.854 h
#         Service time:0.583 h
#         Total time:  3.488 h  (ObjVal 3.488)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.038 h
#         Drone time:  1.838 h
#         Service time:0.583 h
#         Total time:  3.460 h  (ObjVal 3.460)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.142 h
#         Drone time:  1.955 h
#         Service time:0.583 h
#         Total time:  3.680 h  (ObjVal 3.680)
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.024 h
#         Drone time:  1.896 h
#         Service time:0.583 h
#         Total time:  3.504 h  (ObjVal 3.504)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.045 h
#         Drone time:  1.840 h
#         Service time:0.583 h
#         Total time:  3.468 h  (ObjVal 3.468)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.054 h
#         Drone time:  1.813 h
#         Service time:0.583 h
#         Total time:  3.451 h  (ObjVal 3.451)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.029 h
#         Drone time:  1.826 h
#         Service time:0.583 h
#         Total time:  3.438 h  (ObjVal 3.438)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.010 h
#         Drone time:  1.851 h
#         Service time:0.583 h
#         Total time:  3.445 h  (ObjVal 3.445)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.016 h
#         Drone time:  1.873 h
#         Service time:0.583 h
#         Total time:  3.472 h  (ObjVal 3.472)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.009 h
#         Drone time:  1.854 h
#         Service time:0.583 h
#         Total time:  3.445 h  (ObjVal 3.445)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.042 h
#         Drone time:  1.837 h
#         Service time:0.583 h
#         Total time:  3.463 h  (ObjVal 3.463)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.062 h
#         Drone time:  1.852 h
#         Service time:0.583 h
#         Total time:  3.497 h  (ObjVal 3.497)
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.042 h
#         Drone time:  1.906 h
#         Service time:0.583 h
#         Total time:  3.531 h  (ObjVal 3.531)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.022 h
#         Drone time:  1.865 h
#         Service time:0.583 h
#         Total time:  3.470 h  (ObjVal 3.470)
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] MILP solved:
#         Truck time:  0.995 h
#         Drone time:  1.888 h
#         Service time:0.583 h
#         Total time:  3.467 h  (ObjVal 3.467)
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.048 h
#         Drone time:  1.921 h
#         Service time:0.583 h
#         Total time:  3.552 h  (ObjVal 3.552)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.027 h
#         Drone time:  1.865 h
#         Service time:0.583 h
#         Total time:  3.476 h  (ObjVal 3.476)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.000 h
#         Drone time:  1.866 h
#         Service time:0.583 h
#         Total time:  3.449 h  (ObjVal 3.449)
# [DEBUG][PSO] MILP solved:
#         Truck time:  0.998 h
#         Drone time:  1.880 h
#         Service time:0.583 h
#         Total time:  3.461 h  (ObjVal 3.461)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.024 h
#         Drone time:  1.826 h
#         Service time:0.583 h
#         Total time:  3.433 h  (ObjVal 3.433)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.027 h
#         Drone time:  1.852 h
#         Service time:0.583 h
#         Total time:  3.463 h  (ObjVal 3.463)
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.030 h
#         Drone time:  1.854 h
#         Service time:0.583 h
#         Total time:  3.468 h  (ObjVal 3.468)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.082 h
#         Drone time:  1.857 h
#         Service time:0.583 h
#         Total time:  3.522 h  (ObjVal 3.522)
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.029 h
#         Drone time:  1.846 h
#         Service time:0.583 h
#         Total time:  3.458 h  (ObjVal 3.458)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.045 h
#         Drone time:  1.845 h
#         Service time:0.583 h
#         Total time:  3.473 h  (ObjVal 3.473)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.024 h
#         Drone time:  1.844 h
#         Service time:0.583 h
#         Total time:  3.451 h  (ObjVal 3.451)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.130 h
#         Drone time:  1.893 h
#         Service time:0.583 h
#         Total time:  3.606 h  (ObjVal 3.606)
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.016 h
#         Drone time:  1.860 h
#         Service time:0.583 h
#         Total time:  3.459 h  (ObjVal 3.459)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.037 h
#         Drone time:  1.836 h
#         Service time:0.583 h
#         Total time:  3.457 h  (ObjVal 3.457)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.038 h
#         Drone time:  1.810 h
#         Service time:0.583 h
#         Total time:  3.431 h  (ObjVal 3.431)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.035 h
#         Drone time:  1.807 h
#         Service time:0.583 h
#         Total time:  3.425 h  (ObjVal 3.425)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.018 h
#         Drone time:  1.821 h
#         Service time:0.583 h
#         Total time:  3.422 h  (ObjVal 3.422)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.013 h
#         Drone time:  1.874 h
#         Service time:0.583 h
#         Total time:  3.471 h  (ObjVal 3.471)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.012 h
#         Drone time:  1.849 h
#         Service time:0.583 h
#         Total time:  3.444 h  (ObjVal 3.444)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.023 h
#         Drone time:  1.835 h
#         Service time:0.583 h
#         Total time:  3.441 h  (ObjVal 3.441)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.051 h
#         Drone time:  1.816 h
#         Service time:0.583 h
#         Total time:  3.450 h  (ObjVal 3.450)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.034 h
#         Drone time:  1.786 h
#         Service time:0.583 h
#         Total time:  3.403 h  (ObjVal 3.403)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.023 h
#         Drone time:  1.846 h
#         Service time:0.583 h
#         Total time:  3.452 h  (ObjVal 3.452)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.040 h
#         Drone time:  1.837 h
#         Service time:0.583 h
#         Total time:  3.460 h  (ObjVal 3.460)
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.001 h
#         Drone time:  1.875 h
#         Service time:0.583 h
#         Total time:  3.459 h  (ObjVal 3.459)
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.029 h
#         Drone time:  1.879 h
#         Service time:0.583 h
#         Total time:  3.492 h  (ObjVal 3.492)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.029 h
#         Drone time:  1.832 h
#         Service time:0.583 h
#         Total time:  3.445 h  (ObjVal 3.445)
# [DEBUG][PSO] MILP solved:
#         Truck time:  0.994 h
#         Drone time:  1.861 h
#         Service time:0.583 h
#         Total time:  3.438 h  (ObjVal 3.438)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.002 h
#         Drone time:  1.838 h
#         Service time:0.583 h
#         Total time:  3.424 h  (ObjVal 3.424)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.024 h
#         Drone time:  1.821 h
#         Service time:0.583 h
#         Total time:  3.428 h  (ObjVal 3.428)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.034 h
#         Drone time:  1.837 h
#         Service time:0.583 h
#         Total time:  3.455 h  (ObjVal 3.455)
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.025 h
#         Drone time:  1.826 h
#         Service time:0.583 h
#         Total time:  3.434 h  (ObjVal 3.434)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.049 h
#         Drone time:  1.843 h
#         Service time:0.583 h
#         Total time:  3.476 h  (ObjVal 3.476)
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.017 h
#         Drone time:  1.863 h
#         Service time:0.583 h
#         Total time:  3.463 h  (ObjVal 3.463)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.037 h
#         Drone time:  1.835 h
#         Service time:0.583 h
#         Total time:  3.456 h  (ObjVal 3.456)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.017 h
#         Drone time:  1.827 h
#         Service time:0.583 h
#         Total time:  3.428 h  (ObjVal 3.428)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.103 h
#         Drone time:  1.822 h
#         Service time:0.583 h
#         Total time:  3.508 h  (ObjVal 3.508)
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.011 h
#         Drone time:  1.844 h
#         Service time:0.583 h
#         Total time:  3.439 h  (ObjVal 3.439)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.035 h
#         Drone time:  1.808 h
#         Service time:0.583 h
#         Total time:  3.426 h  (ObjVal 3.426)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.035 h
#         Drone time:  1.828 h
#         Service time:0.583 h
#         Total time:  3.447 h  (ObjVal 3.447)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.045 h
#         Drone time:  1.821 h
#         Service time:0.583 h
#         Total time:  3.449 h  (ObjVal 3.449)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.025 h
#         Drone time:  1.790 h
#         Service time:0.583 h
#         Total time:  3.398 h  (ObjVal 3.398)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.016 h
#         Drone time:  1.849 h
#         Service time:0.583 h
#         Total time:  3.448 h  (ObjVal 3.448)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.013 h
#         Drone time:  1.836 h
#         Service time:0.583 h
#         Total time:  3.432 h  (ObjVal 3.432)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.010 h
#         Drone time:  1.826 h
#         Service time:0.583 h
#         Total time:  3.420 h  (ObjVal 3.420)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.040 h
#         Drone time:  1.799 h
#         Service time:0.583 h
#         Total time:  3.422 h  (ObjVal 3.422)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.043 h
#         Drone time:  1.776 h
#         Service time:0.583 h
#         Total time:  3.402 h  (ObjVal 3.402)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.010 h
#         Drone time:  1.837 h
#         Service time:0.583 h
#         Total time:  3.430 h  (ObjVal 3.430)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.042 h
#         Drone time:  1.812 h
#         Service time:0.583 h
#         Total time:  3.437 h  (ObjVal 3.437)
# [DEBUG][PSO] Particle violates endurance at cluster 4.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.007 h
#         Drone time:  1.865 h
#         Service time:0.583 h
#         Total time:  3.454 h  (ObjVal 3.454)
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.020 h
#         Drone time:  1.845 h
#         Service time:0.583 h
#         Total time:  3.449 h  (ObjVal 3.449)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.027 h
#         Drone time:  1.807 h
#         Service time:0.583 h
#         Total time:  3.418 h  (ObjVal 3.418)
# [DEBUG][PSO] MILP solved:
#         Truck time:  0.997 h
#         Drone time:  1.855 h
#         Service time:0.583 h
#         Total time:  3.435 h  (ObjVal 3.435)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.007 h
#         Drone time:  1.830 h
#         Service time:0.583 h
#         Total time:  3.420 h  (ObjVal 3.420)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.022 h
#         Drone time:  1.813 h
#         Service time:0.583 h
#         Total time:  3.419 h  (ObjVal 3.419)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.035 h
#         Drone time:  1.831 h
#         Service time:0.583 h
#         Total time:  3.449 h  (ObjVal 3.449)
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.023 h
#         Drone time:  1.819 h
#         Service time:0.583 h
#         Total time:  3.425 h  (ObjVal 3.425)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.026 h
#         Drone time:  1.818 h
#         Service time:0.583 h
#         Total time:  3.427 h  (ObjVal 3.427)
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.016 h
#         Drone time:  1.844 h
#         Service time:0.583 h
#         Total time:  3.444 h  (ObjVal 3.444)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.030 h
#         Drone time:  1.807 h
#         Service time:0.583 h
#         Total time:  3.420 h  (ObjVal 3.420)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.016 h
#         Drone time:  1.818 h
#         Service time:0.583 h
#         Total time:  3.417 h  (ObjVal 3.417)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.060 h
#         Drone time:  1.785 h
#         Service time:0.583 h
#         Total time:  3.429 h  (ObjVal 3.429)
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.018 h
#         Drone time:  1.829 h
#         Service time:0.583 h
#         Total time:  3.431 h  (ObjVal 3.431)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.028 h
#         Drone time:  1.803 h
#         Service time:0.583 h
#         Total time:  3.415 h  (ObjVal 3.415)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.033 h
#         Drone time:  1.826 h
#         Service time:0.583 h
#         Total time:  3.442 h  (ObjVal 3.442)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.038 h
#         Drone time:  1.806 h
#         Service time:0.583 h
#         Total time:  3.427 h  (ObjVal 3.427)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.028 h
#         Drone time:  1.786 h
#         Service time:0.583 h
#         Total time:  3.397 h  (ObjVal 3.397)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.024 h
#         Drone time:  1.817 h
#         Service time:0.583 h
#         Total time:  3.425 h  (ObjVal 3.425)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.022 h
#         Drone time:  1.815 h
#         Service time:0.583 h
#         Total time:  3.420 h  (ObjVal 3.420)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.012 h
#         Drone time:  1.812 h
#         Service time:0.583 h
#         Total time:  3.408 h  (ObjVal 3.408)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.023 h
#         Drone time:  1.789 h
#         Service time:0.583 h
#         Total time:  3.395 h  (ObjVal 3.395)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.037 h
#         Drone time:  1.822 h
#         Service time:0.583 h
#         Total time:  3.443 h  (ObjVal 3.443)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.006 h
#         Drone time:  1.832 h
#         Service time:0.583 h
#         Total time:  3.421 h  (ObjVal 3.421)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.039 h
#         Drone time:  1.814 h
#         Service time:0.583 h
#         Total time:  3.437 h  (ObjVal 3.437)
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.017 h
#         Drone time:  1.840 h
#         Service time:0.583 h
#         Total time:  3.440 h  (ObjVal 3.440)
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.022 h
#         Drone time:  1.806 h
#         Service time:0.583 h
#         Total time:  3.412 h  (ObjVal 3.412)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.006 h
#         Drone time:  1.826 h
#         Service time:0.583 h
#         Total time:  3.415 h  (ObjVal 3.415)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.012 h
#         Drone time:  1.820 h
#         Service time:0.583 h
#         Total time:  3.415 h  (ObjVal 3.415)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.021 h
#         Drone time:  1.801 h
#         Service time:0.583 h
#         Total time:  3.406 h  (ObjVal 3.406)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.030 h
#         Drone time:  1.814 h
#         Service time:0.583 h
#         Total time:  3.427 h  (ObjVal 3.427)
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.022 h
#         Drone time:  1.804 h
#         Service time:0.583 h
#         Total time:  3.410 h  (ObjVal 3.410)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.010 h
#         Drone time:  1.815 h
#         Service time:0.583 h
#         Total time:  3.409 h  (ObjVal 3.409)
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.018 h
#         Drone time:  1.818 h
#         Service time:0.583 h
#         Total time:  3.419 h  (ObjVal 3.419)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.025 h
#         Drone time:  1.798 h
#         Service time:0.583 h
#         Total time:  3.406 h  (ObjVal 3.406)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.016 h
#         Drone time:  1.808 h
#         Service time:0.583 h
#         Total time:  3.407 h  (ObjVal 3.407)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.039 h
#         Drone time:  1.795 h
#         Service time:0.583 h
#         Total time:  3.417 h  (ObjVal 3.417)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.089 h
#         Drone time:  1.955 h
#         Service time:0.583 h
#         Total time:  3.628 h  (ObjVal 3.628)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.018 h
#         Drone time:  1.817 h
#         Service time:0.583 h
#         Total time:  3.418 h  (ObjVal 3.418)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.025 h
#         Drone time:  1.802 h
#         Service time:0.583 h
#         Total time:  3.411 h  (ObjVal 3.411)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.030 h
#         Drone time:  1.800 h
#         Service time:0.583 h
#         Total time:  3.413 h  (ObjVal 3.413)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.029 h
#         Drone time:  1.794 h
#         Service time:0.583 h
#         Total time:  3.406 h  (ObjVal 3.406)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.029 h
#         Drone time:  1.780 h
#         Service time:0.583 h
#         Total time:  3.392 h  (ObjVal 3.392)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.025 h
#         Drone time:  1.794 h
#         Service time:0.583 h
#         Total time:  3.403 h  (ObjVal 3.403)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.025 h
#         Drone time:  1.804 h
#         Service time:0.583 h
#         Total time:  3.413 h  (ObjVal 3.413)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.015 h
#         Drone time:  1.796 h
#         Service time:0.583 h
#         Total time:  3.394 h  (ObjVal 3.394)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.017 h
#         Drone time:  1.780 h
#         Service time:0.583 h
#         Total time:  3.380 h  (ObjVal 3.380)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.031 h
#         Drone time:  1.803 h
#         Service time:0.583 h
#         Total time:  3.417 h  (ObjVal 3.417)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.011 h
#         Drone time:  1.824 h
#         Service time:0.583 h
#         Total time:  3.418 h  (ObjVal 3.418)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.035 h
#         Drone time:  1.818 h
#         Service time:0.583 h
#         Total time:  3.436 h  (ObjVal 3.436)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.121 h
#         Drone time:  1.885 h
#         Service time:0.583 h
#         Total time:  3.589 h  (ObjVal 3.589)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.021 h
#         Drone time:  1.821 h
#         Service time:0.583 h
#         Total time:  3.425 h  (ObjVal 3.425)
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.016 h
#         Drone time:  1.813 h
#         Service time:0.583 h
#         Total time:  3.412 h  (ObjVal 3.412)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.015 h
#         Drone time:  1.795 h
#         Service time:0.583 h
#         Total time:  3.394 h  (ObjVal 3.394)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.012 h
#         Drone time:  1.806 h
#         Service time:0.583 h
#         Total time:  3.401 h  (ObjVal 3.401)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.016 h
#         Drone time:  1.807 h
#         Service time:0.583 h
#         Total time:  3.407 h  (ObjVal 3.407)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.021 h
#         Drone time:  1.789 h
#         Service time:0.583 h
#         Total time:  3.393 h  (ObjVal 3.393)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.023 h
#         Drone time:  1.796 h
#         Service time:0.583 h
#         Total time:  3.402 h  (ObjVal 3.402)
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.020 h
#         Drone time:  1.791 h
#         Service time:0.583 h
#         Total time:  3.395 h  (ObjVal 3.395)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.004 h
#         Drone time:  1.809 h
#         Service time:0.583 h
#         Total time:  3.396 h  (ObjVal 3.396)
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.018 h
#         Drone time:  1.799 h
#         Service time:0.583 h
#         Total time:  3.400 h  (ObjVal 3.400)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.021 h
#         Drone time:  1.790 h
#         Service time:0.583 h
#         Total time:  3.394 h  (ObjVal 3.394)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.017 h
#         Drone time:  1.800 h
#         Service time:0.583 h
#         Total time:  3.401 h  (ObjVal 3.401)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.018 h
#         Drone time:  1.776 h
#         Service time:0.583 h
#         Total time:  3.377 h  (ObjVal 3.377)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.061 h
#         Drone time:  1.861 h
#         Service time:0.583 h
#         Total time:  3.505 h  (ObjVal 3.505)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.016 h
#         Drone time:  1.783 h
#         Service time:0.583 h
#         Total time:  3.382 h  (ObjVal 3.382)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.021 h
#         Drone time:  1.798 h
#         Service time:0.583 h
#         Total time:  3.403 h  (ObjVal 3.403)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.025 h
#         Drone time:  1.786 h
#         Service time:0.583 h
#         Total time:  3.394 h  (ObjVal 3.394)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.023 h
#         Drone time:  1.787 h
#         Service time:0.583 h
#         Total time:  3.393 h  (ObjVal 3.393)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.026 h
#         Drone time:  1.778 h
#         Service time:0.583 h
#         Total time:  3.388 h  (ObjVal 3.388)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.024 h
#         Drone time:  1.783 h
#         Service time:0.583 h
#         Total time:  3.390 h  (ObjVal 3.390)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.022 h
#         Drone time:  1.793 h
#         Service time:0.583 h
#         Total time:  3.399 h  (ObjVal 3.399)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.016 h
#         Drone time:  1.784 h
#         Service time:0.583 h
#         Total time:  3.384 h  (ObjVal 3.384)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.014 h
#         Drone time:  1.782 h
#         Service time:0.583 h
#         Total time:  3.379 h  (ObjVal 3.379)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.028 h
#         Drone time:  1.798 h
#         Service time:0.583 h
#         Total time:  3.410 h  (ObjVal 3.410)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.015 h
#         Drone time:  1.802 h
#         Service time:0.583 h
#         Total time:  3.400 h  (ObjVal 3.400)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.032 h
#         Drone time:  1.792 h
#         Service time:0.583 h
#         Total time:  3.407 h  (ObjVal 3.407)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.093 h
#         Drone time:  1.830 h
#         Service time:0.583 h
#         Total time:  3.506 h  (ObjVal 3.506)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.021 h
#         Drone time:  1.797 h
#         Service time:0.583 h
#         Total time:  3.401 h  (ObjVal 3.401)
# [DEBUG][PSO] Particle violates endurance at cluster 0.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.018 h
#         Drone time:  1.788 h
#         Service time:0.583 h
#         Total time:  3.389 h  (ObjVal 3.389)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.015 h
#         Drone time:  1.784 h
#         Service time:0.583 h
#         Total time:  3.382 h  (ObjVal 3.382)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.016 h
#         Drone time:  1.798 h
#         Service time:0.583 h
#         Total time:  3.397 h  (ObjVal 3.397)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.019 h
#         Drone time:  1.801 h
#         Service time:0.583 h
#         Total time:  3.403 h  (ObjVal 3.403)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.020 h
#         Drone time:  1.784 h
#         Service time:0.583 h
#         Total time:  3.387 h  (ObjVal 3.387)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.019 h
#         Drone time:  1.787 h
#         Service time:0.583 h
#         Total time:  3.390 h  (ObjVal 3.390)
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.020 h
#         Drone time:  1.775 h
#         Service time:0.583 h
#         Total time:  3.378 h  (ObjVal 3.378)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.006 h
#         Drone time:  1.797 h
#         Service time:0.583 h
#         Total time:  3.386 h  (ObjVal 3.386)
# [DEBUG][PSO] Particle violates endurance at cluster 5.
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.019 h
#         Drone time:  1.790 h
#         Service time:0.583 h
#         Total time:  3.392 h  (ObjVal 3.392)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.017 h
#         Drone time:  1.779 h
#         Service time:0.583 h
#         Total time:  3.379 h  (ObjVal 3.379)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.018 h
#         Drone time:  1.787 h
#         Service time:0.583 h
#         Total time:  3.388 h  (ObjVal 3.388)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.007 h
#         Drone time:  1.794 h
#         Service time:0.583 h
#         Total time:  3.385 h  (ObjVal 3.385)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.023 h
#         Drone time:  1.832 h
#         Service time:0.583 h
#         Total time:  3.438 h  (ObjVal 3.438)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.015 h
#         Drone time:  1.782 h
#         Service time:0.583 h
#         Total time:  3.380 h  (ObjVal 3.380)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.020 h
#         Drone time:  1.794 h
#         Service time:0.583 h
#         Total time:  3.398 h  (ObjVal 3.398)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.019 h
#         Drone time:  1.775 h
#         Service time:0.583 h
#         Total time:  3.378 h  (ObjVal 3.378)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.019 h
#         Drone time:  1.775 h
#         Service time:0.583 h
#         Total time:  3.378 h  (ObjVal 3.378)
# [DEBUG][PSO] MILP solved:
#         Truck time:  1.022 h
#         Drone time:  1.783 h
#         Service time:0.583 h
#         Total time:  3.389 h  (ObjVal 3.389)
# Stopping search: maximum iterations reached --> 15
# [DEBUG] PSO best_f = 3.377
# [DEBUG][FINAL] MILP solved:
#         Truck time:  1.018 h
#         Drone time:  1.776 h
#         Service time:0.583 h
#         Total time:  3.377 h  (ObjVal 3.377)
# [DEBUG] Extracted route: [0, 4, 2, 7, 5, 3, 1, 6, 0]
# PTD-VRPD finished – makespan 3.38 hours

# %%
# =============================================================
#  PTD-VRPD  ·  static speed profile · cloud-licence Gurobi
#            + PSO iteration & particle debug
# =============================================================

# pip install gurobipy pyswarm ortools pandas numpy scikit-learn matplotlib

import numpy as np, pandas as pd, itertools, matplotlib.pyplot as plt
from   sklearn.cluster       import KMeans
from   pyswarm               import pso
import gurobipy as gp
from   gurobipy              import GRB
from   scipy.interpolate      import interp1d
from   scipy.spatial.distance import cdist

# -------------------------------------------------------------
# 0. Cloud licence credentials
# -------------------------------------------------------------
WLS_ID     = "95c3994f-513d-4b8c-a42c-0194dad8ec5c"
WLS_SECRET = "3dc0e444-1f74-49f3-96cc-e9abaabb8ce4"
LICENSE_ID = 2551395
def make_env():
    env = gp.Env(empty=True)
    env.setParam("WLSACCESSID", WLS_ID)
    env.setParam("WLSSECRET",   WLS_SECRET)
    env.setParam("LICENSEID",   LICENSE_ID)
    env.setParam("OutputFlag",  0)
    env.start()
    return env
GRB_ENV = make_env()
print("[DEBUG] Gurobi cloud environment initialized.")

# -------------------------------------------------------------
# 1. Global constants
# -------------------------------------------------------------
RNG_SEED            = 42
np.random.seed()

AREA_KM             = 10.0
N_DELIVERIES        = 50
DEPOT               = (0., 0.)

DRONE_SPEED_KMH     = 40.
DRONE_END_MIN       = 20
SERVICE_MIN_PER_CL  = 5
BIGM                = 1_000_000.0

# PSO iteration & particle tracking
SWARM_SIZE   = 30
ITERATIONS  = 15
call_counter = 0
iter_counter = 0

# -------------------------------------------------------------
# 2. Speed lookup
# -------------------------------------------------------------
def build_speed_func(csv_path="Predicted Speed/Predicted_Speeds.csv"):
    df = pd.read_csv(csv_path).rename(columns=str.strip)
    if not {"Time of Day","Predicted Speed"}.issubset(df.columns):
        raise ValueError("CSV must contain 'Time of Day' + 'Predicted Speed'")
    df = df.sort_values("Time of Day")
    f  = interp1d(df["Time of Day"]%24, df["Predicted Speed"],
                  kind="linear", fill_value="extrapolate")
    def speed(t): return float(f(t%24))
    print(f"[DEBUG] Loaded {len(df)} speed points – example 09:30 ⇒ {speed(9.5):.1f} km/h")
    return speed
speed_func = build_speed_func()

# -------------------------------------------------------------
# 3. Instance helpers
# -------------------------------------------------------------
def gen_locations(n=N_DELIVERIES, area=AREA_KM):
    locs = np.vstack([DEPOT, np.random.uniform(-area, area, size=(n,2))])
    print(f"[DEBUG] Generated {n} delivery locations.")
    return locs

def kmeans_endurance(locs):
    K=1
    while True:
        km = KMeans(n_clusters=K, random_state=RNG_SEED, n_init=10).fit(locs[1:])
        ok=True
        for i,ctr in enumerate(km.cluster_centers_):
            dkm = np.linalg.norm(locs[1:][km.labels_==i]-ctr, axis=1)
            rt  = 2*dkm/DRONE_SPEED_KMH + SERVICE_MIN_PER_CL/60.
            if (rt>DRONE_END_MIN/60.).any():
                ok=False; break
        if ok:
            print(f"[DEBUG] K-means found feasible K={K} clusters.")
            return km.labels_, km.cluster_centers_
        K+=1

# -------------------------------------------------------------
# 4. Build & solve MILP with debug
# -------------------------------------------------------------
def build_and_solve_milp(locs, centres, labels, tag=""):
    nStop   = len(centres)+1
    custIdx = np.arange(1,len(locs))

    xy   = np.vstack([DEPOT, centres])
    Dman = cdist(xy,xy,metric="cityblock")
    Deuc = cdist(locs,xy)

    m = gp.Model(env=GRB_ENV)
    m.Params.OutputFlag = 0

    r    = m.addVars(nStop,nStop, vtype=GRB.BINARY, name="r")
    Tdep = m.addVars(nStop, lb=0, name="Tdep")
    Tarr = m.addVars(nStop, lb=0, name="Tarr")
    Td   = m.addVars(len(centres), lb=0, name="Tdrone")
    y    = m.addVars(len(custIdx), len(centres), vtype=GRB.BINARY, name="y")

    # Objective
    m.setObjective(
        gp.quicksum(Dman[i,j]/speed_func(0)*r[i,j]
                    for i in range(nStop) for j in range(nStop) if i!=j)
      + gp.quicksum(Td[k] for k in range(len(centres)))
      + SERVICE_MIN_PER_CL/60.*len(centres),
      GRB.MINIMIZE)

    # Routing & subtours
    for i in range(nStop):
        m.addConstr(gp.quicksum(r[i,j] for j in range(nStop) if j!=i)==1)
        m.addConstr(gp.quicksum(r[j,i] for j in range(nStop) if j!=i)==1)
    u = m.addVars(nStop, lb=0, ub=nStop-1, name="u")
    for i,j in itertools.permutations(range(1,nStop),2):
        m.addConstr(u[i]-u[j]+(nStop-1)*r[i,j] <= nStop-2)

    # Timing
    for i,j in itertools.product(range(nStop),range(nStop)):
        if i==j: continue
        m.addConstr(Tarr[j] >= Tdep[i] + Dman[i,j]/speed_func(0)
                    - BIGM*(1-r[i,j]))
        if i!=0:
            m.addConstr(Tdep[i] >= Tarr[i] + Td[i-1] + SERVICE_MIN_PER_CL/60.)
    m.addConstr(Tdep[0]==0)

    # Drone assignment & endurance
    for cIdx,cust in enumerate(custIdx):
        m.addConstr(gp.quicksum(y[cIdx,k] for k in range(len(centres)))==1)
        for k in range(len(centres)):
            rt = 2*Deuc[cust,k+1]/DRONE_SPEED_KMH + SERVICE_MIN_PER_CL/60.
            m.addConstr(rt - DRONE_END_MIN/60.-BIGM*(1-y[cIdx,k]) <= 0)
            m.addConstr(Td[k] >= rt * y[cIdx,k])

    # Solve
    m.optimize()
    if m.SolCount == 0:
        print(f"[DEBUG]{tag} MILP infeasible.")
        return m, r

    # Compute and print component times
    truck_time  = sum((Dman[i,j]/speed_func(0)) * r[i,j].X
                       for i in range(nStop) for j in range(nStop) if i!=j)
    drone_time  = sum(Td[k].X for k in range(len(centres)))
    service_time= SERVICE_MIN_PER_CL/60.*len(centres)
    total_time  = truck_time + drone_time + service_time

    print(f"[DEBUG]{tag} MILP solved:")
    print(f"   → Truck time   = {truck_time:.3f} h")
    print(f"   → Drone time   = {drone_time:.3f} h")
    print(f"   → Service time = {service_time:.3f} h")
    print(f"   → Total time   = {total_time:.3f} h (Obj {m.ObjVal:.3f})")
    return m, r

# -------------------------------------------------------------
# 5. PSO fitness with iteration + particle debug
# -------------------------------------------------------------
def pso_fitness(w, locs, centres0, labels0):
    global call_counter, iter_counter
    call_counter += 1
    if call_counter % SWARM_SIZE == 1:
        iter_counter += 1
        print(f"[DEBUG][PSO] Starting iteration {iter_counter}")

    particle_idx = ((call_counter-1) % SWARM_SIZE) + 1
    K    = len(centres0)
    ctrs = centres0 + w.reshape(K,2)

    # quick reject
    for k,c in enumerate(ctrs):
        d = np.linalg.norm(locs[1:][labels0==k]-c,axis=1)
        rt= 2*d/DRONE_SPEED_KMH + SERVICE_MIN_PER_CL/60.
        if (rt>DRONE_END_MIN/60.).any():
            print(f"[DEBUG][PSO] Iter {iter_counter} P{particle_idx} → endurance VIOLATION in cluster {k}")
            return 1e6

    # passes endurance
    print(f"[DEBUG][PSO] Iter {iter_counter} P{particle_idx} → endurance OK, centres =\n{ctrs}")

    m,r = build_and_solve_milp(locs, ctrs, labels0, tag=f"[PSO it{iter_counter} p{particle_idx}]")
    return 1e6 if m.SolCount==0 else m.ObjVal

# -------------------------------------------------------------
# 6. Extract route helper
# -------------------------------------------------------------
def extract_route(r_vars):
    edges = {(i,j) for (i,j),v in r_vars.items() if v.X>0.5}
    route=[0]
    nStop=int(np.sqrt(len(r_vars)))
    while len(route)<nStop+1:
        last=route[-1]
        nxt = next(j for (i,j) in edges if i==last)
        route.append(nxt)
        if nxt==0: break
    print(f"[DEBUG] Extracted route: {route}")
    return route

# -------------------------------------------------------------
# 7. Solve & plot
# -------------------------------------------------------------
def solve_and_plot(locs):
    global call_counter, iter_counter
    call_counter, iter_counter = 0, 0

    labels0, centres0 = kmeans_endurance(locs)
    lb = [-2]*2*len(centres0)
    ub = [ 2]*2*len(centres0)

    print("[DEBUG] Beginning PSO...")
    best_w, best_f = pso(pso_fitness, lb, ub,
                         swarmsize=SWARM_SIZE, maxiter=ITERATIONS, debug=False,
                         args=(locs, centres0, labels0))
    print(f"[DEBUG] PSO completed: best_f = {best_f:.3f}")

    centres = centres0 if best_f>=1e6 else centres0 + best_w.reshape(len(centres0),2)
    mdl, rVars = build_and_solve_milp(locs, centres, labels0, tag="[FINAL]")
    if mdl.SolCount==0:
        print("[DEBUG] FINAL infeasible, fallback.")
        centres = centres0
        mdl, rVars = build_and_solve_milp(locs, centres, labels0, tag="[FALLBACK]")

    route = extract_route(rVars)

    # plot
    plt.figure(figsize=(7,7))
    for k in range(len(centres)):
        pts=locs[1:][labels0==k]
        plt.scatter(pts[:,0],pts[:,1],s=15,alpha=0.6,label=f'Cl {k+1}')
    plt.scatter(centres[:,0],centres[:,1],
                marker='^',c='k',s=80,label='Stop')
    plt.scatter(*DEPOT,marker='*',c='r',s=120,label='Depot')
    path_xy=np.vstack([DEPOT,centres])[route]
    plt.plot(path_xy[:,0],path_xy[:,1],'k--',lw=1.5,label='Truck path')
    plt.title(f'Route (makespan {mdl.ObjVal:.2f} h)')
    plt.legend(fontsize=8); plt.axis('equal'); plt.grid(True)
    plt.show()

    return mdl.ObjVal

# -------------------------------------------------------------
# 8. Demo
# -------------------------------------------------------------
if __name__=="__main__":
    locs = gen_locations()
    best = solve_and_plot(locs)
    if np.isfinite(best):
        print(f"\nPTD-VRPD finished – makespan {best:.2f} hours")
    else:
        print("\nPTD-VRPD infeasible (unexpected)")
# Out:
# [DEBUG] Gurobi cloud environment initialized.
# [DEBUG] Loaded 96 speed points – example 09:30 ⇒ 66.3 km/h
# [DEBUG] Generated 50 delivery locations.
# [DEBUG] K-means found feasible K=8 clusters.
# [DEBUG] Beginning PSO...
# [DEBUG][PSO] Starting iteration 1
# [DEBUG][PSO] Iter 1 P1 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 1 P2 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 1 P3 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 1 P4 → endurance VIOLATION in cluster 3
# [DEBUG][PSO] Iter 1 P5 → endurance VIOLATION in cluster 5
# [DEBUG][PSO] Iter 1 P6 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 1 P7 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 1 P8 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 1 P9 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 1 P10 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 1 P11 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 1 P12 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 1 P13 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 1 P14 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 1 P15 → endurance VIOLATION in cluster 5
# [DEBUG][PSO] Iter 1 P16 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 1 P17 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 1 P18 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 1 P19 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 1 P20 → endurance VIOLATION in cluster 6
# [DEBUG][PSO] Iter 1 P21 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 1 P22 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 1 P23 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 1 P24 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 1 P25 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 1 P26 → endurance VIOLATION in cluster 5
# [DEBUG][PSO] Iter 1 P27 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 1 P28 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 1 P29 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 1 P30 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Starting iteration 2
# [DEBUG][PSO] Iter 2 P1 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 2 P2 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 2 P3 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 2 P4 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 2 P5 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 2 P6 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 2 P7 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 2 P8 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 2 P9 → endurance VIOLATION in cluster 5
# [DEBUG][PSO] Iter 2 P10 → endurance VIOLATION in cluster 3
# [DEBUG][PSO] Iter 2 P11 → endurance VIOLATION in cluster 2
# [DEBUG][PSO] Iter 2 P12 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 2 P13 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 2 P14 → endurance VIOLATION in cluster 3
# [DEBUG][PSO] Iter 2 P15 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 2 P16 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 2 P17 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 2 P18 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 2 P19 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 2 P20 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 2 P21 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 2 P22 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 2 P23 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 2 P24 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 2 P25 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 2 P26 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 2 P27 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 2 P28 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 2 P29 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 2 P30 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Starting iteration 3
# [DEBUG][PSO] Iter 3 P1 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 3 P2 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 3 P3 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 3 P4 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 3 P5 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 3 P6 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 3 P7 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 3 P8 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 3 P9 → endurance VIOLATION in cluster 5
# [DEBUG][PSO] Iter 3 P10 → endurance VIOLATION in cluster 3
# [DEBUG][PSO] Iter 3 P11 → endurance VIOLATION in cluster 2
# [DEBUG][PSO] Iter 3 P12 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 3 P13 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 3 P14 → endurance VIOLATION in cluster 3
# [DEBUG][PSO] Iter 3 P15 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 3 P16 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 3 P17 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 3 P18 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 3 P19 → endurance VIOLATION in cluster 6
# [DEBUG][PSO] Iter 3 P20 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 3 P21 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 3 P22 → endurance VIOLATION in cluster 3
# [DEBUG][PSO] Iter 3 P23 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 3 P24 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 3 P25 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 3 P26 → endurance VIOLATION in cluster 5
# [DEBUG][PSO] Iter 3 P27 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 3 P28 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 3 P29 → endurance VIOLATION in cluster 5
# [DEBUG][PSO] Iter 3 P30 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Starting iteration 4
# [DEBUG][PSO] Iter 4 P1 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 4 P2 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 4 P3 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 4 P4 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 4 P5 → endurance OK, centres =
# [[-7.32886739  1.13596836]
#  [ 5.29488965 -7.36353394]
#  [ 7.43441335  2.27276011]
#  [-7.25458101  6.93589682]
#  [ 1.7370549  -8.9438431 ]
#  [-6.1069993  -6.11339757]
#  [ 0.13304936  0.67998421]
#  [ 5.99370996  9.9035234 ]]
# [DEBUG][PSO it4 p5] MILP solved:
#    → Truck time   = 1.101 h
#    → Drone time   = 1.881 h
#    → Service time = 0.667 h
#    → Total time   = 3.648 h (Obj 3.648)
# [DEBUG][PSO] Iter 4 P6 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 4 P7 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 4 P8 → endurance VIOLATION in cluster 5
# [DEBUG][PSO] Iter 4 P9 → endurance VIOLATION in cluster 5
# [DEBUG][PSO] Iter 4 P10 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 4 P11 → endurance VIOLATION in cluster 2
# [DEBUG][PSO] Iter 4 P12 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 4 P13 → endurance VIOLATION in cluster 6
# [DEBUG][PSO] Iter 4 P14 → endurance VIOLATION in cluster 3
# [DEBUG][PSO] Iter 4 P15 → endurance VIOLATION in cluster 5
# [DEBUG][PSO] Iter 4 P16 → endurance OK, centres =
# [[-6.69840614  0.65247057]
#  [ 5.65270363 -6.95125069]
#  [ 6.56333278  2.1425077 ]
#  [-6.35218746  6.7589415 ]
#  [ 3.24595183 -8.38744783]
#  [-5.72483507 -6.23120544]
#  [ 0.31024754  0.68854424]
#  [ 7.16167957  9.6465198 ]]
# [DEBUG][PSO it4 p16] MILP solved:
#    → Truck time   = 1.062 h
#    → Drone time   = 2.000 h
#    → Service time = 0.667 h
#    → Total time   = 3.728 h (Obj 3.728)
# [DEBUG][PSO] Iter 4 P17 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 4 P18 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 4 P19 → endurance OK, centres =
# [[-6.2826524   0.91025135]
#  [ 5.36304988 -6.49663189]
#  [ 5.75821057  1.11904048]
#  [-7.38074885  7.30259592]
#  [ 0.21110119 -7.64547055]
#  [-6.14400172 -5.63704604]
#  [ 0.17082179  1.94921298]
#  [ 6.61806806  7.95236514]]
# [DEBUG][PSO it4 p19] MILP solved:
#    → Truck time   = 1.012 h
#    → Drone time   = 2.042 h
#    → Service time = 0.667 h
#    → Total time   = 3.721 h (Obj 3.721)
# [DEBUG][PSO] Iter 4 P20 → endurance VIOLATION in cluster 6
# [DEBUG][PSO] Iter 4 P21 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 4 P22 → endurance VIOLATION in cluster 6
# [DEBUG][PSO] Iter 4 P23 → endurance OK, centres =
# [[-5.97594252  0.37315788]
#  [ 6.5679207  -5.83427391]
#  [ 5.71672599  3.23849485]
#  [-7.74490254  6.91387696]
#  [ 0.06798283 -8.99392469]
#  [-5.77150959 -5.70079857]
#  [-0.14661111  1.060687  ]
#  [ 6.31386093  7.51822766]]
# [DEBUG][PSO it4 p23] MILP solved:
#    → Truck time   = 1.055 h
#    → Drone time   = 2.194 h
#    → Service time = 0.667 h
#    → Total time   = 3.915 h (Obj 3.915)
# [DEBUG][PSO] Iter 4 P24 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 4 P25 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 4 P26 → endurance VIOLATION in cluster 5
# [DEBUG][PSO] Iter 4 P27 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 4 P28 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 4 P29 → endurance OK, centres =
# [[-5.81513648  0.37786426]
#  [ 5.15215226 -6.52741192]
#  [ 7.90872762  1.46388336]
#  [-5.93781965  6.50437522]
#  [ 2.9882738  -8.48116379]
#  [-4.66253116 -6.32309682]
#  [ 1.15059305  0.60046054]
#  [ 8.47223276  8.8679465 ]]
# [DEBUG][PSO it4 p29] MILP solved:
#    → Truck time   = 1.044 h
#    → Drone time   = 2.095 h
#    → Service time = 0.667 h
#    → Total time   = 3.806 h (Obj 3.806)
# [DEBUG][PSO] Iter 4 P30 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Starting iteration 5
# [DEBUG][PSO] Iter 5 P1 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 5 P2 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 5 P3 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 5 P4 → endurance VIOLATION in cluster 3
# [DEBUG][PSO] Iter 5 P5 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 5 P6 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 5 P7 → endurance OK, centres =
# [[-6.24117489  0.83459505]
#  [ 5.68989585 -6.80931765]
#  [ 7.1434349   2.14920116]
#  [-6.86346169  7.66375027]
#  [ 1.94910272 -7.41890557]
#  [-5.88883407 -5.55291415]
#  [ 0.70754416  0.49504577]
#  [ 6.66324959 10.12063276]]
# [DEBUG][PSO it5 p7] MILP solved:
#    → Truck time   = 1.053 h
#    → Drone time   = 2.095 h
#    → Service time = 0.667 h
#    → Total time   = 3.815 h (Obj 3.815)
# [DEBUG][PSO] Iter 5 P8 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 5 P9 → endurance VIOLATION in cluster 5
# [DEBUG][PSO] Iter 5 P10 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 5 P11 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 5 P12 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 5 P13 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 5 P14 → endurance OK, centres =
# [[-6.13573147  0.84123673]
#  [ 6.11513746 -6.34852992]
#  [ 7.02403892  1.48252838]
#  [-7.94675398  7.63936763]
#  [ 1.74225787 -8.56599951]
#  [-6.79305232 -6.17049375]
#  [ 0.88981836  0.6877961 ]
#  [ 5.40949693  8.76820338]]
# [DEBUG][PSO it5 p14] MILP solved:
#    → Truck time   = 1.105 h
#    → Drone time   = 2.116 h
#    → Service time = 0.667 h
#    → Total time   = 3.888 h (Obj 3.888)
# [DEBUG][PSO] Iter 5 P15 → endurance OK, centres =
# [[-6.92604129  1.46037468]
#  [ 5.10666054 -6.97792747]
#  [ 6.81243983  1.51578441]
#  [-7.34625516  7.69685317]
#  [ 2.37678056 -7.83659095]
#  [-4.91430674 -6.09422754]
#  [-0.33031623  1.15313967]
#  [ 7.2575583   9.11635347]]
# [DEBUG][PSO it5 p15] MILP solved:
#    → Truck time   = 1.032 h
#    → Drone time   = 1.851 h
#    → Service time = 0.667 h
#    → Total time   = 3.549 h (Obj 3.549)
# [DEBUG][PSO] Iter 5 P16 → endurance OK, centres =
# [[-6.65939426  1.09523196]
#  [ 5.28422279 -6.56685447]
#  [ 7.12135325  1.78565008]
#  [-6.64813289  7.34760806]
#  [ 2.75330187 -8.31585174]
#  [-6.14937338 -6.13101929]
#  [ 0.23363724  1.19638118]
#  [ 6.68904125  9.71193468]]
# [DEBUG][PSO it5 p16] MILP solved:
#    → Truck time   = 1.049 h
#    → Drone time   = 2.051 h
#    → Service time = 0.667 h
#    → Total time   = 3.767 h (Obj 3.767)
# [DEBUG][PSO] Iter 5 P17 → endurance VIOLATION in cluster 6
# [DEBUG][PSO] Iter 5 P18 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 5 P19 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 5 P20 → endurance OK, centres =
# [[-6.66059232 -0.11334354]
#  [ 5.59595182 -7.14590747]
#  [ 7.01273233  1.31307684]
#  [-6.75445924  6.92213834]
#  [ 2.90651219 -8.41349286]
#  [-5.89378808 -6.12534186]
#  [ 0.39132411  1.28387199]
#  [ 6.09461943  9.31080137]]
# [DEBUG][PSO it5 p20] MILP solved:
#    → Truck time   = 1.049 h
#    → Drone time   = 2.058 h
#    → Service time = 0.667 h
#    → Total time   = 3.774 h (Obj 3.774)
# [DEBUG][PSO] Iter 5 P21 → endurance OK, centres =
# [[-5.39207501  0.54293262]
#  [ 5.59016197 -7.06414221]
#  [ 6.40854629  2.75233638]
#  [-7.93904027  7.60060515]
#  [ 1.29601277 -7.45004533]
#  [-6.58681498 -7.58775863]
#  [ 1.04096639  1.13492642]
#  [ 7.42668061 10.43314306]]
# [DEBUG][PSO it5 p21] MILP solved:
#    → Truck time   = 1.136 h
#    → Drone time   = 2.103 h
#    → Service time = 0.667 h
#    → Total time   = 3.906 h (Obj 3.906)
# [DEBUG][PSO] Iter 5 P22 → endurance OK, centres =
# [[-7.33482789  1.50427378]
#  [ 5.2654928  -6.04269042]
#  [ 6.63128024  0.84737353]
#  [-6.64220937  6.75480011]
#  [ 2.13184177 -8.44205136]
#  [-6.49254759 -5.8170046 ]
#  [-0.12661721  0.95865759]
#  [ 5.90750348  7.95358751]]
# [DEBUG][PSO it5 p22] MILP solved:
#    → Truck time   = 1.015 h
#    → Drone time   = 2.003 h
#    → Service time = 0.667 h
#    → Total time   = 3.685 h (Obj 3.685)
# [DEBUG][PSO] Iter 5 P23 → endurance OK, centres =
# [[-6.69839997  0.86159747]
#  [ 5.93712715 -5.89583741]
#  [ 6.33043452  2.35486597]
#  [-7.21746899  7.62789744]
#  [ 1.18030816 -8.89184387]
#  [-5.49790922 -6.14659766]
#  [-0.07097529  1.29602718]
#  [ 7.05819278  8.32452256]]
# [DEBUG][PSO it5 p23] MILP solved:
#    → Truck time   = 1.059 h
#    → Drone time   = 2.066 h
#    → Service time = 0.667 h
#    → Total time   = 3.792 h (Obj 3.792)
# [DEBUG][PSO] Iter 5 P24 → endurance OK, centres =
# [[-6.8972153   1.64489177]
#  [ 5.2191578  -6.28835633]
#  [ 6.83659282  2.36651896]
#  [-7.06362881  6.20127003]
#  [ 2.09143501 -8.10799994]
#  [-5.50983289 -6.02537311]
#  [ 0.19176657  0.37543065]
#  [ 6.39791068  8.57202554]]
# [DEBUG][PSO it5 p24] MILP solved:
#    → Truck time   = 1.013 h
#    → Drone time   = 2.010 h
#    → Service time = 0.667 h
#    → Total time   = 3.690 h (Obj 3.690)
# [DEBUG][PSO] Iter 5 P25 → endurance VIOLATION in cluster 5
# [DEBUG][PSO] Iter 5 P26 → endurance VIOLATION in cluster 5
# [DEBUG][PSO] Iter 5 P27 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 5 P28 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 5 P29 → endurance OK, centres =
# [[-6.14549638  0.18459067]
#  [ 5.19871196 -6.47643533]
#  [ 7.58250454  1.48991526]
#  [-6.36917269  6.57476077]
#  [ 2.29767198 -8.31372312]
#  [-4.98888245 -6.11590062]
#  [ 0.31433179  0.67119721]
#  [ 7.53165545  8.93587544]]
# [DEBUG][PSO it5 p29] MILP solved:
#    → Truck time   = 1.030 h
#    → Drone time   = 2.035 h
#    → Service time = 0.667 h
#    → Total time   = 3.731 h (Obj 3.731)
# [DEBUG][PSO] Iter 5 P30 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Starting iteration 6
# [DEBUG][PSO] Iter 6 P1 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 6 P2 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 6 P3 → endurance VIOLATION in cluster 6
# [DEBUG][PSO] Iter 6 P4 → endurance VIOLATION in cluster 3
# [DEBUG][PSO] Iter 6 P5 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 6 P6 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 6 P7 → endurance OK, centres =
# [[-6.92112389  1.30963336]
#  [ 5.26923513 -7.32837803]
#  [ 7.30156737  2.76537404]
#  [-6.93224363  8.2476934 ]
#  [ 1.74498656 -7.31113887]
#  [-6.06199074 -5.93869781]
#  [ 0.60067341  0.52179857]
#  [ 6.94566542  9.46091559]]
# [DEBUG][PSO it6 p7] MILP solved:
#    → Truck time   = 1.027 h
#    → Drone time   = 1.825 h
#    → Service time = 0.667 h
#    → Total time   = 3.518 h (Obj 3.518)
# [DEBUG][PSO] Iter 6 P8 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 6 P9 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 6 P10 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 6 P11 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 6 P12 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 6 P13 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 6 P14 → endurance OK, centres =
# [[-6.03569716  0.64043696]
#  [ 5.94151621 -6.77536547]
#  [ 7.40602547  1.54260583]
#  [-7.45243207  8.42073331]
#  [ 1.723089   -8.65606625]
#  [-7.64229235 -6.21794177]
#  [ 0.58785128  0.97889568]
#  [ 5.86887929  8.99498896]]
# [DEBUG][PSO it6 p14] MILP solved:
#    → Truck time   = 1.133 h
#    → Drone time   = 2.158 h
#    → Service time = 0.667 h
#    → Total time   = 3.958 h (Obj 3.958)
# [DEBUG][PSO] Iter 6 P15 → endurance OK, centres =
# [[-6.94413967  1.75857121]
#  [ 4.94683166 -7.73954509]
#  [ 6.70884989  1.69196503]
#  [-7.22449875  7.71503195]
#  [ 2.34313896 -8.05351185]
#  [-6.0491376  -6.29790926]
#  [-0.7054771   0.9004662 ]
#  [ 7.0241585   9.24648933]]
# [DEBUG][PSO it6 p15] MILP solved:
#    → Truck time   = 1.052 h
#    → Drone time   = 1.811 h
#    → Service time = 0.667 h
#    → Total time   = 3.530 h (Obj 3.530)
# [DEBUG][PSO] Iter 6 P16 → endurance OK, centres =
# [[-6.65890695  1.14780296]
#  [ 5.1482326  -6.83249707]
#  [ 7.40945029  2.03247085]
#  [-6.78591061  7.77003781]
#  [ 2.35466447 -7.92353636]
#  [-6.32973961 -6.00760279]
#  [ 0.40044792  0.94999326]
#  [ 6.57850301  9.66682239]]
# [DEBUG][PSO it6 p16] MILP solved:
#    → Truck time   = 1.045 h
#    → Drone time   = 1.862 h
#    → Service time = 0.667 h
#    → Total time   = 3.573 h (Obj 3.573)
# [DEBUG][PSO] Iter 6 P17 → endurance VIOLATION in cluster 6
# [DEBUG][PSO] Iter 6 P18 → endurance OK, centres =
# [[-5.5104801   1.56774487]
#  [ 6.66322975 -7.01595565]
#  [ 7.19467129  1.76319945]
#  [-6.61227023  7.70876516]
#  [ 1.98459876 -8.40539773]
#  [-5.05726388 -5.67141192]
#  [-0.03787491  1.30089246]
#  [ 8.12795795  8.36568385]]
# [DEBUG][PSO it6 p18] MILP solved:
#    → Truck time   = 1.034 h
#    → Drone time   = 2.175 h
#    → Service time = 0.667 h
#    → Total time   = 3.876 h (Obj 3.876)
# [DEBUG][PSO] Iter 6 P19 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 6 P20 → endurance OK, centres =
# [[-6.58961889  0.53509272]
#  [ 5.54991482 -7.58770731]
#  [ 7.07164366  1.45969466]
#  [-6.50848984  7.65789237]
#  [ 2.53652524 -7.95198629]
#  [-6.3833757  -6.27135659]
#  [-0.07876991  0.75346343]
#  [ 6.73000781  9.77080659]]
# [DEBUG][PSO it6 p20] MILP solved:
#    → Truck time   = 1.047 h
#    → Drone time   = 2.066 h
#    → Service time = 0.667 h
#    → Total time   = 3.780 h (Obj 3.780)
# [DEBUG][PSO] Iter 6 P21 → endurance OK, centres =
# [[-5.96722355  0.98995331]
#  [ 5.68524539 -7.00980849]
#  [ 6.57989112  2.77988693]
#  [-7.83064391  8.17799685]
#  [ 1.48289849 -6.98222778]
#  [-7.02441264 -7.3273928 ]
#  [ 0.81089121  1.36835986]
#  [ 7.33093498 10.7918672 ]]
# [DEBUG][PSO it6 p21] MILP solved:
#    → Truck time   = 1.132 h
#    → Drone time   = 2.194 h
#    → Service time = 0.667 h
#    → Total time   = 3.993 h (Obj 3.993)
# [DEBUG][PSO] Iter 6 P22 → endurance OK, centres =
# [[-7.03759191  1.64203608]
#  [ 5.09303877 -6.38845451]
#  [ 6.43561836  2.03964697]
#  [-6.37697285  7.49861033]
#  [ 1.51785656 -8.23693213]
#  [-5.83627062 -5.85007195]
#  [ 0.1837836   1.34223025]
#  [ 6.05839006  8.87264201]]
# [DEBUG][PSO it6 p22] MILP solved:
#    → Truck time   = 1.009 h
#    → Drone time   = 2.016 h
#    → Service time = 0.667 h
#    → Total time   = 3.691 h (Obj 3.691)
# [DEBUG][PSO] Iter 6 P23 → endurance OK, centres =
# [[-7.08220803  1.18910533]
#  [ 5.33753386 -5.95077941]
#  [ 6.81600397  2.02942973]
#  [-6.86929432  8.18059231]
#  [ 1.88340272 -8.37495701]
#  [-5.52386998 -6.3155238 ]
#  [ 0.06935045  1.32611132]
#  [ 7.39634985  8.82368714]]
# [DEBUG][PSO it6 p23] MILP solved:
#    → Truck time   = 1.047 h
#    → Drone time   = 2.009 h
#    → Service time = 0.667 h
#    → Total time   = 3.722 h (Obj 3.722)
# [DEBUG][PSO] Iter 6 P24 → endurance OK, centres =
# [[-7.3150826   1.84203309]
#  [ 5.45962793 -7.16593736]
#  [ 6.87686094  2.66978236]
#  [-6.86573928  7.1773262 ]
#  [ 1.8437121  -7.54487663]
#  [-5.4077474  -6.35327644]
#  [-0.245602    0.75930222]
#  [ 6.34906587  8.61665065]]
# [DEBUG][PSO it6 p24] MILP solved:
#    → Truck time   = 1.012 h
#    → Drone time   = 2.055 h
#    → Service time = 0.667 h
#    → Total time   = 3.733 h (Obj 3.733)
# [DEBUG][PSO] Iter 6 P25 → endurance OK, centres =
# [[-5.3159391   1.54948881]
#  [ 5.3905364  -6.80645329]
#  [ 7.07356809  2.72068924]
#  [-7.29068232  7.56987605]
#  [ 1.20741924 -7.36487958]
#  [-4.92374418 -5.83254625]
#  [-1.01974639  0.68917079]
#  [ 6.03210876  9.38912827]]
# [DEBUG][PSO it6 p25] MILP solved:
#    → Truck time   = 1.020 h
#    → Drone time   = 2.228 h
#    → Service time = 0.667 h
#    → Total time   = 3.915 h (Obj 3.915)
# [DEBUG][PSO] Iter 6 P26 → endurance VIOLATION in cluster 5
# [DEBUG][PSO] Iter 6 P27 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 6 P28 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 6 P29 → endurance OK, centres =
# [[-6.3678346   0.24906207]
#  [ 5.22942291 -6.79089935]
#  [ 7.29888947  1.93037927]
#  [-6.6969809   7.32196327]
#  [ 1.76482265 -7.75916187]
#  [-5.36841979 -5.98346144]
#  [-0.07128472  0.63643909]
#  [ 6.97504192  9.05062884]]
# [DEBUG][PSO it6 p29] MILP solved:
#    → Truck time   = 1.021 h
#    → Drone time   = 2.059 h
#    → Service time = 0.667 h
#    → Total time   = 3.747 h (Obj 3.747)
# [DEBUG][PSO] Iter 6 P30 → endurance VIOLATION in cluster 6
# [DEBUG][PSO] Starting iteration 7
# [DEBUG][PSO] Iter 7 P1 → endurance VIOLATION in cluster 6
# [DEBUG][PSO] Iter 7 P2 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 7 P3 → endurance OK, centres =
# [[-7.40443929  0.56952187]
#  [ 5.01459316 -6.85709114]
#  [ 6.3136121   2.52761049]
#  [-7.2187301   7.44330945]
#  [ 2.59034183 -6.71786491]
#  [-5.5793995  -5.81692672]
#  [ 0.03072728  1.26167017]
#  [ 6.31415918  9.95549557]]
# [DEBUG][PSO it7 p3] MILP solved:
#    → Truck time   = 1.006 h
#    → Drone time   = 1.956 h
#    → Service time = 0.667 h
#    → Total time   = 3.628 h (Obj 3.628)
# [DEBUG][PSO] Iter 7 P4 → endurance VIOLATION in cluster 3
# [DEBUG][PSO] Iter 7 P5 → endurance OK, centres =
# [[-7.02949122  0.94121995]
#  [ 4.92836229 -7.03709524]
#  [ 7.02875539  2.52210363]
#  [-7.13529747  7.47543918]
#  [ 2.29403504 -8.11746367]
#  [-5.40290753 -5.48653628]
#  [ 0.58196318  0.54669407]
#  [ 6.78346789  9.53599625]]
# [DEBUG][PSO it7 p5] MILP solved:
#    → Truck time   = 1.039 h
#    → Drone time   = 1.889 h
#    → Service time = 0.667 h
#    → Total time   = 3.595 h (Obj 3.595)
# [DEBUG][PSO] Iter 7 P6 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 7 P7 → endurance OK, centres =
# [[-7.26109839  1.54715251]
#  [ 5.05890477 -7.58790823]
#  [ 7.3806336   3.07346049]
#  [-6.9666346   8.53966497]
#  [ 1.64292849 -7.25725553]
#  [-6.14856907 -6.13158964]
#  [ 0.54723804  0.53517497]
#  [ 7.08687334  9.13105701]]
# [DEBUG][PSO it7 p7] MILP solved:
#    → Truck time   = 1.030 h
#    → Drone time   = 1.771 h
#    → Service time = 0.667 h
#    → Total time   = 3.468 h (Obj 3.468)
# [DEBUG][PSO] Iter 7 P8 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 7 P9 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 7 P10 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 7 P11 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 7 P12 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 7 P13 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 7 P14 → endurance OK, centres =
# [[-6.05216504  0.62700366]
#  [ 5.46471194 -7.03719442]
#  [ 7.4025      1.97049361]
#  [-7.14346611  8.54967926]
#  [ 1.71107156 -8.24602074]
#  [-7.70209737 -6.21132215]
#  [ 0.56557322  0.834527  ]
#  [ 6.20444827  9.11229406]]
# [DEBUG][PSO it7 p14] MILP solved:
#    → Truck time   = 1.104 h
#    → Drone time   = 2.090 h
#    → Service time = 0.667 h
#    → Total time   = 3.861 h (Obj 3.861)
# [DEBUG][PSO] Iter 7 P15 → endurance OK, centres =
# [[-7.05359472  1.84530839]
#  [ 4.88036273 -7.73954509]
#  [ 6.71761047  1.9512637 ]
#  [-7.13285789  7.81320879]
#  [ 2.25750551 -7.88013864]
#  [-6.64944555 -6.34558993]
#  [-0.56605427  0.76098798]
#  [ 6.93846566  9.26824057]]
# [DEBUG][PSO it7 p15] MILP solved:
#    → Truck time   = 1.037 h
#    → Drone time   = 1.830 h
#    → Service time = 0.667 h
#    → Total time   = 3.534 h (Obj 3.534)
# [DEBUG][PSO] Iter 7 P16 → endurance OK, centres =
# [[-6.70026182  1.25131806]
#  [ 5.06656672 -7.15960213]
#  [ 7.54158537  2.37050136]
#  [-6.90709114  8.09071453]
#  [ 2.04710154 -7.52707487]
#  [-6.38859628 -5.96733025]
#  [ 0.49479737  0.72314858]
#  [ 6.6425213   9.63145928]]
# [DEBUG][PSO it7 p16] MILP solved:
#    → Truck time   = 1.037 h
#    → Drone time   = 1.840 h
#    → Service time = 0.667 h
#    → Total time   = 3.544 h (Obj 3.544)
# [DEBUG][PSO] Iter 7 P17 → endurance VIOLATION in cluster 5
# [DEBUG][PSO] Iter 7 P18 → endurance OK, centres =
# [[-5.57475262  1.55698924]
#  [ 6.24695039 -6.91207721]
#  [ 7.23212222  2.33635268]
#  [-6.53736098  8.14615957]
#  [ 1.88133461 -7.93208346]
#  [-5.78515479 -5.79834834]
#  [ 0.12390856  0.85134947]
#  [ 8.22902438  8.19324701]]
# [DEBUG][PSO it7 p18] MILP solved:
#    → Truck time   = 1.041 h
#    → Drone time   = 2.089 h
#    → Service time = 0.667 h
#    → Total time   = 3.797 h (Obj 3.797)
# [DEBUG][PSO] Iter 7 P19 → endurance OK, centres =
# [[-6.69977795  1.65277397]
#  [ 4.86399259 -6.91786716]
#  [ 6.58275415  1.82523729]
#  [-7.10895805  8.03476052]
#  [ 1.17823116 -7.60493431]
#  [-6.06262489 -5.90945964]
#  [ 0.04436899  0.98065894]
#  [ 6.87430297  8.99838831]]
# [DEBUG][PSO it7 p19] MILP solved:
#    → Truck time   = 1.003 h
#    → Drone time   = 1.838 h
#    → Service time = 0.667 h
#    → Total time   = 3.508 h (Obj 3.508)
# [DEBUG][PSO] Iter 7 P20 → endurance OK, centres =
# [[-6.87971667  0.91084727]
#  [ 5.49687447 -7.71281901]
#  [ 7.23467485  2.21685563]
#  [-6.62444048  8.07595739]
#  [ 2.1548171  -7.71664087]
#  [-6.50578669 -6.32089833]
#  [-0.24665141  0.54136803]
#  [ 6.79093766  9.69822475]]
# [DEBUG][PSO it7 p20] MILP solved:
#    → Truck time   = 1.054 h
#    → Drone time   = 2.076 h
#    → Service time = 0.667 h
#    → Total time   = 3.797 h (Obj 3.797)
# [DEBUG][PSO] Iter 7 P21 → endurance OK, centres =
# [[-6.26084851  1.22212881]
#  [ 5.43694177 -7.05309827]
#  [ 6.89374755  2.88028435]
#  [-7.6896976   8.26571667]
#  [ 1.58989892 -7.01615316]
#  [-7.11669944 -7.05906619]
#  [ 0.61334484  1.06722317]
#  [ 7.2172849  10.09647844]]
# [DEBUG][PSO it7 p21] MILP solved:
#    → Truck time   = 1.085 h
#    → Drone time   = 2.132 h
#    → Service time = 0.667 h
#    → Total time   = 3.884 h (Obj 3.884)
# [DEBUG][PSO] Iter 7 P22 → endurance OK, centres =
# [[-7.08615062  1.63651   ]
#  [ 5.07925045 -6.54155218]
#  [ 6.79523526  2.67189081]
#  [-6.38328402  7.70467289]
#  [ 1.41812348 -7.94668252]
#  [-5.66521781 -5.98265348]
#  [ 0.3029171   1.35539618]
#  [ 6.14510261  9.20984789]]
# [DEBUG][PSO it7 p22] MILP solved:
#    → Truck time   = 1.022 h
#    → Drone time   = 1.991 h
#    → Service time = 0.667 h
#    → Total time   = 3.680 h (Obj 3.680)
# [DEBUG][PSO] Iter 7 P23 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 7 P24 → endurance OK, centres =
# [[-7.43447775  1.89285697]
#  [ 5.4464238  -7.70319991]
#  [ 6.88922014  2.9027045 ]
#  [-6.86075483  7.3031852 ]
#  [ 1.81335434 -7.284714  ]
#  [-5.75178073 -6.35779161]
#  [-0.27045794  0.81738927]
#  [ 6.52148866  8.83952201]]
# [DEBUG][PSO it7 p24] MILP solved:
#    → Truck time   = 1.035 h
#    → Drone time   = 2.033 h
#    → Service time = 0.667 h
#    → Total time   = 3.735 h (Obj 3.735)
# [DEBUG][PSO] Iter 7 P25 → endurance OK, centres =
# [[-5.88806839  1.74034277]
#  [ 5.20025683 -7.13405007]
#  [ 6.95691802  3.33307534]
#  [-7.23531013  8.26003756]
#  [ 1.05527626 -7.29946419]
#  [-5.65629792 -5.82173155]
#  [-0.83434017  0.70099021]
#  [ 6.07020765  9.40202885]]
# [DEBUG][PSO it7 p25] MILP solved:
#    → Truck time   = 1.034 h
#    → Drone time   = 1.967 h
#    → Service time = 0.667 h
#    → Total time   = 3.668 h (Obj 3.668)
# [DEBUG][PSO] Iter 7 P26 → endurance OK, centres =
# [[-6.54597137  1.72842737]
#  [ 5.69314608 -6.7321479 ]
#  [ 6.39023269  2.41904967]
#  [-6.29856491  9.41553114]
#  [ 1.142948   -7.07666644]
#  [-4.79156136 -5.98900484]
#  [ 0.45255343  1.16081485]
#  [ 7.55150353  8.22517035]]
# [DEBUG][PSO it7 p26] MILP solved:
#    → Truck time   = 1.014 h
#    → Drone time   = 2.034 h
#    → Service time = 0.667 h
#    → Total time   = 3.714 h (Obj 3.714)
# [DEBUG][PSO] Iter 7 P27 → endurance VIOLATION in cluster 6
# [DEBUG][PSO] Iter 7 P28 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 7 P29 → endurance OK, centres =
# [[-6.69093359  0.71652096]
#  [ 5.21853547 -7.22209127]
#  [ 7.32785897  2.51408948]
#  [-6.77439928  7.98065408]
#  [ 1.5331998  -7.50799445]
#  [-5.7081118  -5.98571764]
#  [-0.02457875  0.58569821]
#  [ 6.78748728  9.10158817]]
# [DEBUG][PSO it7 p29] MILP solved:
#    → Truck time   = 1.017 h
#    → Drone time   = 1.856 h
#    → Service time = 0.667 h
#    → Total time   = 3.539 h (Obj 3.539)
# [DEBUG][PSO] Iter 7 P30 → endurance OK, centres =
# [[-6.75137192  1.3139934 ]
#  [ 5.4006384  -5.93200579]
#  [ 6.46979673  2.2328016 ]
#  [-6.94650972  7.99348904]
#  [ 0.98836001 -6.90140836]
#  [-5.75978758 -5.45685103]
#  [ 0.69870358  1.1130289 ]
#  [ 6.2901717   8.8186029 ]]
# [DEBUG][PSO it7 p30] MILP solved:
#    → Truck time   = 0.977 h
#    → Drone time   = 2.070 h
#    → Service time = 0.667 h
#    → Total time   = 3.713 h (Obj 3.713)
# [DEBUG][PSO] Starting iteration 8
# [DEBUG][PSO] Iter 8 P1 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 8 P2 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 8 P3 → endurance OK, centres =
# [[-7.5306029   0.9539187 ]
#  [ 4.98809002 -7.15291334]
#  [ 6.40465371  3.09231688]
#  [-7.15491612  7.83965836]
#  [ 2.34681201 -6.66104296]
#  [-5.87396963 -5.84419534]
#  [ 0.0590242   0.74183767]
#  [ 6.77405628  9.68548851]]
# [DEBUG][PSO it8 p3] MILP solved:
#    → Truck time   = 1.022 h
#    → Drone time   = 1.886 h
#    → Service time = 0.667 h
#    → Total time   = 3.575 h (Obj 3.575)
# [DEBUG][PSO] Iter 8 P4 → endurance VIOLATION in cluster 3
# [DEBUG][PSO] Iter 8 P5 → endurance OK, centres =
# [[-7.00008761  1.3047941 ]
#  [ 5.14137782 -7.05841721]
#  [ 7.17669321  2.62235554]
#  [-7.05085874  7.90353143]
#  [ 2.13367266 -7.63961537]
#  [-5.65070428 -5.83365315]
#  [ 0.45699917  0.76308854]
#  [ 7.0628397   9.45900552]]
# [DEBUG][PSO it8 p5] MILP solved:
#    → Truck time   = 1.032 h
#    → Drone time   = 1.830 h
#    → Service time = 0.667 h
#    → Total time   = 3.529 h (Obj 3.529)
# [DEBUG][PSO] Iter 8 P6 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 8 P7 → endurance OK, centres =
# [[-7.43108564  1.66591209]
#  [ 4.95373959 -7.71767332]
#  [ 7.42016672  3.22750371]
#  [-6.98383008  8.68565075]
#  [ 1.59189945 -7.23031385]
#  [-6.19185824 -6.22803555]
#  [ 0.52052036  0.54186317]
#  [ 7.1574773   8.96612772]]
# [DEBUG][PSO it8 p7] MILP solved:
#    → Truck time   = 1.032 h
#    → Drone time   = 1.770 h
#    → Service time = 0.667 h
#    → Total time   = 3.469 h (Obj 3.469)
# [DEBUG][PSO] Iter 8 P8 → endurance VIOLATION in cluster 2
# [DEBUG][PSO] Iter 8 P9 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 8 P10 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 8 P11 → endurance VIOLATION in cluster 6
# [DEBUG][PSO] Iter 8 P12 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 8 P13 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 8 P14 → endurance OK, centres =
# [[-6.06308209  0.92162007]
#  [ 5.06237843 -7.32167067]
#  [ 7.39994149  2.39522323]
#  [-6.94155884  8.61323499]
#  [ 1.67271714 -7.89031966]
#  [-7.42440631 -6.18889507]
#  [ 0.5522725   0.71523222]
#  [ 6.38305219  9.17576631]]
# [DEBUG][PSO it8 p14] MILP solved:
#    → Truck time   = 1.070 h
#    → Drone time   = 1.880 h
#    → Service time = 0.667 h
#    → Total time   = 3.617 h (Obj 3.617)
# [DEBUG][PSO] Iter 8 P15 → endurance OK, centres =
# [[-7.10113118e+00  1.72809613e+00]
#  [ 4.90759944e+00 -7.73954509e+00]
#  [ 6.96030133e+00  2.21917895e+00]
#  [-7.12012964e+00  7.92897790e+00]
#  [ 2.04572494e+00 -7.74431917e+00]
#  [-6.61336743e+00 -6.28021375e+00]
#  [-7.47031930e-03  6.95285696e-01]
#  [ 6.99092926e+00  9.22258134e+00]]
# [DEBUG][PSO it8 p15] MILP solved:
#    → Truck time   = 1.018 h
#    → Drone time   = 1.790 h
#    → Service time = 0.667 h
#    → Total time   = 3.475 h (Obj 3.475)
# [DEBUG][PSO] Iter 8 P16 → endurance OK, centres =
# [[-6.91677815  1.3711107 ]
#  [ 5.02425776 -7.40758756]
#  [ 7.5786167   2.88190138]
#  [-6.98236433  8.26015953]
#  [ 1.86826088 -7.25841046]
#  [-6.31553444 -6.00313364]
#  [ 0.56563959  0.60226772]
#  [ 6.79550892  9.59334382]]
# [DEBUG][PSO it8 p16] MILP solved:
#    → Truck time   = 1.035 h
#    → Drone time   = 1.824 h
#    → Service time = 0.667 h
#    → Total time   = 3.525 h (Obj 3.525)
# [DEBUG][PSO] Iter 8 P17 → endurance VIOLATION in cluster 5
# [DEBUG][PSO] Iter 8 P18 → endurance OK, centres =
# [[-6.32914552  1.54958296]
#  [ 5.71999092 -7.02770437]
#  [ 7.28456362  2.73745699]
#  [-6.58175093  8.40592323]
#  [ 1.71902943 -7.40408493]
#  [-6.32166704 -5.9549166 ]
#  [ 0.38319604  0.58974016]
#  [ 8.04264534  8.1190916 ]]
# [DEBUG][PSO it8 p18] MILP solved:
#    → Truck time   = 1.023 h
#    → Drone time   = 2.005 h
#    → Service time = 0.667 h
#    → Total time   = 3.694 h (Obj 3.694)
# [DEBUG][PSO] Iter 8 P19 → endurance OK, centres =
# [[-6.94560095  1.53416163]
#  [ 4.91852633 -7.23603161]
#  [ 6.71268326  2.38903245]
#  [-7.03689586  8.26578961]
#  [ 1.32281945 -7.19955128]
#  [-6.07661074 -6.03335014]
#  [ 0.41025853  0.6883907 ]
#  [ 6.86671463  8.95796107]]
# [DEBUG][PSO it8 p19] MILP solved:
#    → Truck time   = 0.991 h
#    → Drone time   = 1.779 h
#    → Service time = 0.667 h
#    → Total time   = 3.436 h (Obj 3.436)
# [DEBUG][PSO] Iter 8 P20 → endurance OK, centres =
# [[-6.9755724   0.85121133]
#  [ 5.42898902 -7.64407574]
#  [ 7.16683446  2.25928243]
#  [-6.82095891  8.17900096]
#  [ 1.98701471 -7.42328211]
#  [-6.29628556 -6.28473058]
#  [-0.09730032  0.84026501]
#  [ 6.77018279  9.60283863]]
# [DEBUG][PSO it8 p20] MILP solved:
#    → Truck time   = 1.044 h
#    → Drone time   = 1.885 h
#    → Service time = 0.667 h
#    → Total time   = 3.595 h (Obj 3.595)
# [DEBUG][PSO] Iter 8 P21 → endurance OK, centres =
# [[-6.4672196   1.43178955]
#  [ 5.22706975 -7.12253376]
#  [ 6.96332666  2.71770314]
#  [-7.44670887  8.30960085]
#  [ 1.56283799 -7.05971583]
#  [-6.70120855 -6.74992486]
#  [ 0.41504806  0.74956606]
#  [ 7.07823854  9.31468371]]
# [DEBUG][PSO it8 p21] MILP solved:
#    → Truck time   = 1.030 h
#    → Drone time   = 1.852 h
#    → Service time = 0.667 h
#    → Total time   = 3.549 h (Obj 3.549)
# [DEBUG][PSO] Iter 8 P22 → endurance OK, centres =
# [[-7.0531357   1.58780924]
#  [ 5.03253662 -6.72928843]
#  [ 6.96447116  2.89991343]
#  [-6.5872558   7.83417514]
#  [ 1.34052329 -7.67847138]
#  [-5.73337322 -6.07257966]
#  [ 0.38146563  1.17817519]
#  [ 6.40210934  9.32734251]]
# [DEBUG][PSO it8 p22] MILP solved:
#    → Truck time   = 1.020 h
#    → Drone time   = 1.822 h
#    → Service time = 0.667 h
#    → Total time   = 3.508 h (Obj 3.508)
# [DEBUG][PSO] Iter 8 P23 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 8 P24 → endurance OK, centres =
# [[-7.26945272e+00  1.74523775e+00]
#  [ 5.22906521e+00 -7.48607847e+00]
#  [ 6.79796113e+00  2.84138056e+00]
#  [-6.93342897e+00  7.37655872e+00]
#  [ 1.77055517e+00 -7.23596354e+00]
#  [-5.88019868e+00 -6.22555828e+00]
#  [ 2.85990777e-03  6.64454843e-01]
#  [ 6.64147122e+00  8.92583767e+00]]
# [DEBUG][PSO it8 p24] MILP solved:
#    → Truck time   = 1.010 h
#    → Drone time   = 1.799 h
#    → Service time = 0.667 h
#    → Total time   = 3.476 h (Obj 3.476)
# [DEBUG][PSO] Iter 8 P25 → endurance OK, centres =
# [[-6.32211032  1.78178006]
#  [ 5.02083764 -7.3452249 ]
#  [ 6.78386605  3.25771139]
#  [-7.18853772  8.60587359]
#  [ 1.00257115 -7.26613708]
#  [-6.13318931 -5.89742362]
#  [-0.57530849  0.70625785]
#  [ 6.14754754  9.40375046]]
# [DEBUG][PSO it8 p25] MILP solved:
#    → Truck time   = 1.027 h
#    → Drone time   = 1.960 h
#    → Service time = 0.667 h
#    → Total time   = 3.654 h (Obj 3.654)
# [DEBUG][PSO] Iter 8 P26 → endurance OK, centres =
# [[-6.68829584  1.72791107]
#  [ 5.61328291 -6.94444652]
#  [ 6.69419548  2.37872974]
#  [-6.39598874  9.42313952]
#  [ 1.24099479 -6.98437909]
#  [-5.75272865 -6.0583862 ]
#  [ 0.33223343  1.02088229]
#  [ 7.39220455  8.34800334]]
# [DEBUG][PSO it8 p26] MILP solved:
#    → Truck time   = 1.021 h
#    → Drone time   = 1.985 h
#    → Service time = 0.667 h
#    → Total time   = 3.673 h (Obj 3.673)
# [DEBUG][PSO] Iter 8 P27 → endurance VIOLATION in cluster 3
# [DEBUG][PSO] Iter 8 P28 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 8 P29 → endurance OK, centres =
# [[-6.85324049  0.98556936]
#  [ 5.16663658 -7.43902804]
#  [ 7.30513044  2.78381831]
#  [-6.8386212   8.44549024]
#  [ 1.40157829 -7.25028219]
#  [-5.92620543 -6.00894478]
#  [ 0.05171416  0.57904896]
#  [ 6.70065137  9.11992319]]
# [DEBUG][PSO it8 p29] MILP solved:
#    → Truck time   = 1.015 h
#    → Drone time   = 1.820 h
#    → Service time = 0.667 h
#    → Total time   = 3.501 h (Obj 3.501)
# [DEBUG][PSO] Iter 8 P30 → endurance OK, centres =
# [[-6.9644771   1.53276703]
#  [ 5.36374604 -6.04400736]
#  [ 6.42127162  2.40016178]
#  [-6.92925102  8.4221552 ]
#  [ 1.25410234 -6.74055084]
#  [-6.00753122 -5.65536159]
#  [ 0.40893073  0.8316818 ]
#  [ 6.57840335  8.8029516 ]]
# [DEBUG][PSO it8 p30] MILP solved:
#    → Truck time   = 0.975 h
#    → Drone time   = 2.033 h
#    → Service time = 0.667 h
#    → Total time   = 3.674 h (Obj 3.674)
# [DEBUG][PSO] Starting iteration 9
# [DEBUG][PSO] Iter 9 P1 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 9 P2 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 9 P3 → endurance OK, centres =
# [[-7.3080968   1.39291998]
#  [ 4.94277602 -7.31387837]
#  [ 6.51778292  3.17952759]
#  [-7.11036185  8.05062741]
#  [ 2.21253769 -6.6429363 ]
#  [-6.05447276 -5.93803716]
#  [ 0.12016578  0.47124977]
#  [ 7.00998618  9.53750851]]
# [DEBUG][PSO it9 p3] MILP solved:
#    → Truck time   = 1.022 h
#    → Drone time   = 1.837 h
#    → Service time = 0.667 h
#    → Total time   = 3.526 h (Obj 3.526)
# [DEBUG][PSO] Iter 9 P4 → endurance OK, centres =
# [[-7.27550771  1.5750638 ]
#  [ 5.68899192 -6.89665694]
#  [ 6.30127175  3.12929851]
#  [-7.81587668  7.77750778]
#  [ 1.95430037 -7.95041047]
#  [-5.9702271  -6.79312263]
#  [ 0.24546691  1.31949559]
#  [ 7.60106349  9.7893278 ]]
# [DEBUG][PSO it9 p4] MILP solved:
#    → Truck time   = 1.099 h
#    → Drone time   = 2.035 h
#    → Service time = 0.667 h
#    → Total time   = 3.801 h (Obj 3.801)
# [DEBUG][PSO] Iter 9 P5 → endurance OK, centres =
# [[-6.96382664  1.55630137]
#  [ 5.1513584  -7.10269543]
#  [ 7.11662803  2.63118637]
#  [-7.00591809  8.15834149]
#  [ 2.05116867 -7.19432232]
#  [-5.8715444  -6.10274802]
#  [ 0.39325428  0.84815545]
#  [ 7.15536829  9.40225591]]
# [DEBUG][PSO it9 p5] MILP solved:
#    → Truck time   = 1.016 h
#    → Drone time   = 1.792 h
#    → Service time = 0.667 h
#    → Total time   = 3.475 h (Obj 3.475)
# [DEBUG][PSO] Iter 9 P6 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 9 P7 → endurance OK, centres =
# [[-7.40494315  1.63171454]
#  [ 4.9462161  -7.55612675]
#  [ 7.30172841  3.06583319]
#  [-6.99212604  8.58981124]
#  [ 1.52385565 -7.22041716]
#  [-6.13781464 -6.18468508]
#  [ 0.47360313  0.59558703]
#  [ 7.03309022  8.88496414]]
# [DEBUG][PSO it9 p7] MILP solved:
#    → Truck time   = 1.021 h
#    → Drone time   = 1.764 h
#    → Service time = 0.667 h
#    → Total time   = 3.452 h (Obj 3.452)
# [DEBUG][PSO] Iter 9 P8 → endurance VIOLATION in cluster 2
# [DEBUG][PSO] Iter 9 P9 → endurance OK, centres =
# [[-7.72704242  1.91849699]
#  [ 6.20197007 -6.08713578]
#  [ 7.07851417  0.54376524]
#  [-6.36448187  7.28598079]
#  [ 1.69008118 -6.90827712]
#  [-5.4958373  -5.81429383]
#  [ 0.7145701   1.09869676]
#  [ 8.16008621  9.61417625]]
# [DEBUG][PSO it9 p9] MILP solved:
#    → Truck time   = 1.092 h
#    → Drone time   = 2.082 h
#    → Service time = 0.667 h
#    → Total time   = 3.841 h (Obj 3.841)
# [DEBUG][PSO] Iter 9 P10 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 9 P11 → endurance VIOLATION in cluster 6
# [DEBUG][PSO] Iter 9 P12 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 9 P13 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 9 P14 → endurance OK, centres =
# [[-6.31565243  1.17323357]
#  [ 4.79257815 -7.42762641]
#  [ 7.26143274  2.60718059]
#  [-6.86358652  8.49832933]
#  [ 1.59951206 -7.41996646]
#  [-7.06552808 -6.131494  ]
#  [ 0.54396175  0.64774923]
#  [ 6.54093175  9.15948879]]
# [DEBUG][PSO it9 p14] MILP solved:
#    → Truck time   = 1.026 h
#    → Drone time   = 1.838 h
#    → Service time = 0.667 h
#    → Total time   = 3.530 h (Obj 3.530)
# [DEBUG][PSO] Iter 9 P15 → endurance OK, centres =
# [[-7.11569638  1.57799311]
#  [ 4.92135252 -7.69088196]
#  [ 7.03597307  2.39998719]
#  [-7.08517175  8.0172427 ]
#  [ 1.82851912 -7.41591089]
#  [-6.33487288 -6.14896919]
#  [ 0.42765193  0.66000973]
#  [ 7.00955082  9.15268261]]
# [DEBUG][PSO it9 p15] MILP solved:
#    → Truck time   = 1.016 h
#    → Drone time   = 1.766 h
#    → Service time = 0.667 h
#    → Total time   = 3.448 h (Obj 3.448)
# [DEBUG][PSO] Iter 9 P16 → endurance OK, centres =
# [[-7.03000214  1.44826929]
#  [ 4.97607558 -7.48950524]
#  [ 7.4126926   3.11029146]
#  [-7.02935065  8.34586976]
#  [ 1.56048475 -7.12209371]
#  [-6.16248242 -6.03547649]
#  [ 0.56628512  0.56070046]
#  [ 6.88065389  9.48607367]]
# [DEBUG][PSO it9 p16] MILP solved:
#    → Truck time   = 1.030 h
#    → Drone time   = 1.817 h
#    → Service time = 0.667 h
#    → Total time   = 3.513 h (Obj 3.513)
# [DEBUG][PSO] Iter 9 P17 → endurance VIOLATION in cluster 5
# [DEBUG][PSO] Iter 9 P18 → endurance OK, centres =
# [[-6.96762232  1.54401702]
#  [ 5.25423254 -7.13799212]
#  [ 7.24102694  2.93679332]
#  [-6.68173959  8.47429039]
#  [ 1.59378893 -7.05065233]
#  [-6.55110888 -6.06557937]
#  [ 0.51665296  0.48812692]
#  [ 7.68748728  8.49833575]]
# [DEBUG][PSO it9 p18] MILP solved:
#    → Truck time   = 1.006 h
#    → Drone time   = 1.805 h
#    → Service time = 0.667 h
#    → Total time   = 3.477 h (Obj 3.477)
# [DEBUG][PSO] Iter 9 P19 → endurance OK, centres =
# [[-7.06851246  1.47485546]
#  [ 4.9457932  -7.39511383]
#  [ 6.77764781  2.67093003]
#  [-7.00086476  8.38130416]
#  [ 1.39511359 -6.99685977]
#  [-6.08360367 -6.09529539]
#  [ 0.5932033   0.54225658]
#  [ 6.86292046  8.93774745]]
# [DEBUG][PSO it9 p19] MILP solved:
#    → Truck time   = 0.996 h
#    → Drone time   = 1.789 h
#    → Service time = 0.667 h
#    → Total time   = 3.451 h (Obj 3.451)
# [DEBUG][PSO] Iter 9 P20 → endurance OK, centres =
# [[-7.00979684  1.12058464]
#  [ 5.37561198 -7.45982426]
#  [ 6.90628179  2.31927262]
#  [-7.00057829  8.25385371]
#  [ 1.81881609 -7.21898435]
#  [-6.11544385 -6.21159791]
#  [ 0.12769262  0.94112514]
#  [ 6.76700697  9.49251572]]
# [DEBUG][PSO it9 p20] MILP solved:
#    → Truck time   = 1.025 h
#    → Drone time   = 1.821 h
#    → Service time = 0.667 h
#    → Total time   = 3.513 h (Obj 3.513)
# [DEBUG][PSO] Iter 9 P21 → endurance OK, centres =
# [[-6.61653645  1.5763131 ]
#  [ 5.04027484 -7.21348122]
#  [ 6.89840443  2.57358929]
#  [-7.24788461  8.3301907 ]
#  [ 1.46368136 -7.11955596]
#  [-6.34741019 -6.51239288]
#  [ 0.31575056  0.56633337]
#  [ 7.0020825   8.7811136 ]]
# [DEBUG][PSO it9 p21] MILP solved:
#    → Truck time   = 0.998 h
#    → Drone time   = 1.787 h
#    → Service time = 0.667 h
#    → Total time   = 3.452 h (Obj 3.452)
# [DEBUG][PSO] Iter 9 P22 → endurance OK, centres =
# [[-7.01095533  1.54643824]
#  [ 4.98467978 -7.06626511]
#  [ 7.03591426  2.84409214]
#  [-6.86048141  8.02641064]
#  [ 1.29940537 -7.53738959]
#  [-5.79635733 -6.10650343]
#  [ 0.42951709  1.07994835]
#  [ 6.70684315  9.31569847]]
# [DEBUG][PSO it9 p22] MILP solved:
#    → Truck time   = 1.015 h
#    → Drone time   = 1.806 h
#    → Service time = 0.667 h
#    → Total time   = 3.487 h (Obj 3.487)
# [DEBUG][PSO] Iter 9 P23 → endurance OK, centres =
# [[-7.07658389  1.51222766]
#  [ 4.9773618  -6.68549209]
#  [ 7.07778565  2.22286308]
#  [-6.90261915  8.23514217]
#  [ 1.62608622 -7.32139867]
#  [-6.08998641 -6.23872192]
#  [ 0.28400435  0.9274008 ]
#  [ 7.25969455  9.01699489]]
# [DEBUG][PSO it9 p23] MILP solved:
#    → Truck time   = 1.009 h
#    → Drone time   = 1.772 h
#    → Service time = 0.667 h
#    → Total time   = 3.448 h (Obj 3.448)
# [DEBUG][PSO] Iter 9 P24 → endurance OK, centres =
# [[-7.12484736  1.58268727]
#  [ 4.98981089 -7.34944182]
#  [ 6.73828658  2.73568814]
#  [-6.97767228  7.66287918]
#  [ 1.56468538 -7.19606046]
#  [-6.01246161 -6.14227052]
#  [ 0.31894917  0.59549164]
#  [ 6.76679134  8.97880427]]
# [DEBUG][PSO it9 p24] MILP solved:
#    → Truck time   = 0.996 h
#    → Drone time   = 1.782 h
#    → Service time = 0.667 h
#    → Total time   = 3.445 h (Obj 3.445)
# [DEBUG][PSO] Iter 9 P25 → endurance OK, centres =
# [[-6.60495075  1.77381664]
#  [ 4.92400463 -7.4446046 ]
#  [ 6.69271028  3.04043462]
#  [-7.11200978  8.62701781]
#  [ 1.08047938 -7.23018359]
#  [-6.36907215 -5.96896331]
#  [-0.18694424  0.70812223]
#  [ 6.21134348  9.22725681]]
# [DEBUG][PSO it9 p25] MILP solved:
#    → Truck time   = 1.007 h
#    → Drone time   = 1.917 h
#    → Service time = 0.667 h
#    → Total time   = 3.590 h (Obj 3.590)
# [DEBUG][PSO] Iter 9 P26 → endurance OK, centres =
# [[-6.80265532  1.68890823]
#  [ 5.38303419 -7.19093644]
#  [ 6.85176085  2.35869754]
#  [-6.71858699  8.9057891 ]
#  [ 1.33032499 -7.00166033]
#  [-6.32806378 -6.08205258]
#  [ 0.28304207  0.87463876]
#  [ 7.23426208  8.63629301]]
# [DEBUG][PSO it9 p26] MILP solved:
#    → Truck time   = 1.005 h
#    → Drone time   = 1.965 h
#    → Service time = 0.667 h
#    → Total time   = 3.637 h (Obj 3.637)
# [DEBUG][PSO] Iter 9 P27 → endurance VIOLATION in cluster 3
# [DEBUG][PSO] Iter 9 P28 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 9 P29 → endurance OK, centres =
# [[-6.95336896  1.36557473]
#  [ 5.06088816 -7.48038169]
#  [ 7.10677523  2.90829629]
#  [-6.92599334  8.64351056]
#  [ 1.30645403 -7.10491874]
#  [-6.0375595  -6.03236527]
#  [ 0.21616559  0.61856413]
#  [ 6.68892173  9.08151964]]
# [DEBUG][PSO it9 p29] MILP solved:
#    → Truck time   = 1.009 h
#    → Drone time   = 1.800 h
#    → Service time = 0.667 h
#    → Total time   = 3.476 h (Obj 3.476)
# [DEBUG][PSO] Iter 9 P30 → endurance OK, centres =
# [[-7.0674212   1.64251198]
#  [ 5.17223089 -6.59745935]
#  [ 6.44146384  2.48273603]
#  [-6.97307315  8.56737454]
#  [ 1.38911414 -6.79356701]
#  [-6.16428623 -5.85239889]
#  [ 0.26454127  0.68292984]
#  [ 6.7838043   8.85739234]]
# [DEBUG][PSO it9 p30] MILP solved:
#    → Truck time   = 0.981 h
#    → Drone time   = 2.008 h
#    → Service time = 0.667 h
#    → Total time   = 3.655 h (Obj 3.655)
# [DEBUG][PSO] Starting iteration 10
# [DEBUG][PSO] Iter 10 P1 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 10 P2 → endurance VIOLATION in cluster 0
# [DEBUG][PSO] Iter 10 P3 → endurance OK, centres =
# [[-7.08213099  1.67266952]
#  [ 4.91480339 -7.36508392]
#  [ 6.63373216  3.07875228]
#  [-7.06338721  8.24868442]
#  [ 1.88104844 -6.67582453]
#  [-6.1501171  -6.00475378]
#  [ 0.27010116  0.35210732]
#  [ 7.06600985  9.18516246]]
# [DEBUG][PSO it10 p3] MILP solved:
#    → Truck time   = 1.007 h
#    → Drone time   = 1.808 h
#    → Service time = 0.667 h
#    → Total time   = 3.482 h (Obj 3.482)
# [DEBUG][PSO] Iter 10 P4 → endurance OK, centres =
# [[-6.97338365  1.59731331]
#  [ 5.67263075 -7.08592335]
#  [ 6.42655322  2.93352924]
#  [-7.52799404  8.09692663]
#  [ 1.75621774 -7.90906904]
#  [-5.99255812 -6.68027316]
#  [ 0.28431468  1.07702805]
#  [ 7.40867278  9.48306045]]
# [DEBUG][PSO it10 p4] MILP solved:
#    → Truck time   = 1.075 h
#    → Drone time   = 1.997 h
#    → Service time = 0.667 h
#    → Total time   = 3.739 h (Obj 3.739)
# [DEBUG][PSO] Iter 10 P5 → endurance OK, centres =
# [[-6.93823979  1.6766011 ]
#  [ 5.06672047 -7.16666769]
#  [ 7.04707306  2.51641248]
#  [-6.98543528  8.28778736]
#  [ 1.85581299 -6.97362228]
#  [-5.98745675 -6.2279659 ]
#  [ 0.36654096  0.86106105]
#  [ 7.19849567  9.33255209]]
# [DEBUG][PSO it10 p5] MILP solved:
#    → Truck time   = 1.011 h
#    → Drone time   = 1.772 h
#    → Service time = 0.667 h
#    → Total time   = 3.450 h (Obj 3.450)
# [DEBUG][PSO] Iter 10 P6 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 10 P7 → endurance OK, centres =
# [[-7.32662228  1.60629184]
#  [ 4.93571612 -7.35106499]
#  [ 7.20542799  2.90922652]
#  [-7.00099443  8.44326522]
#  [ 1.48044626 -7.212449  ]
#  [-6.08387598 -6.15789649]
#  [ 0.42794258  0.62967082]
#  [ 6.95045432  8.86483809]]
# [DEBUG][PSO it10 p7] MILP solved:
#    → Truck time   = 1.009 h
#    → Drone time   = 1.761 h
#    → Service time = 0.667 h
#    → Total time   = 3.437 h (Obj 3.437)
# [DEBUG][PSO] Iter 10 P8 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 10 P9 → endurance OK, centres =
# [[-7.53750313  1.78289274]
#  [ 6.10058476 -6.47892618]
#  [ 6.84167888  1.2374923 ]
#  [-6.30885688  7.54762756]
#  [ 1.68943988 -7.0482863 ]
#  [-5.67502263 -5.9601284 ]
#  [ 0.52933207  0.68427724]
#  [ 7.77577143  9.44391274]]
# [DEBUG][PSO it10 p9] MILP solved:
#    → Truck time   = 1.072 h
#    → Drone time   = 1.993 h
#    → Service time = 0.667 h
#    → Total time   = 3.732 h (Obj 3.732)
# [DEBUG][PSO] Iter 10 P10 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 10 P11 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 10 P12 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 10 P13 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 10 P14 → endurance OK, centres =
# [[-6.52177743  1.4493409 ]
#  [ 4.68748054 -7.47305435]
#  [ 6.96620026  2.70910103]
#  [-6.82631585  8.33940251]
#  [ 1.55131053 -7.11054752]
#  [-6.81588797 -6.1015315 ]
#  [ 0.48258421  0.61530164]
#  [ 6.63173767  9.12458202]]
# [DEBUG][PSO it10 p14] MILP solved:
#    → Truck time   = 1.001 h
# ...
#    → Drone time   = 1.743 h
#    → Service time = 0.667 h
#    → Total time   = 3.408 h (Obj 3.408)
# [DEBUG][PSO] Iter 15 P16 → endurance OK, centres =
# [[-7.00143015  1.88629236]
#  [ 4.96297488 -7.19327511]
#  [ 6.75833667  2.29333235]
#  [-7.03534949  8.64625557]
#  [ 1.34446836 -6.71690965]
#  [-6.43439024 -6.22393175]
#  [ 0.31720837  0.66189679]
#  [ 7.09830131  8.85097516]]
# [DEBUG][PSO it15 p16] MILP solved:
#    → Truck time   = 0.994 h
#    → Drone time   = 1.739 h
#    → Service time = 0.667 h
#    → Total time   = 3.400 h (Obj 3.400)
# [DEBUG][PSO] Iter 15 P17 → endurance VIOLATION in cluster 6
# [DEBUG][PSO] Iter 15 P18 → endurance OK, centres =
# [[-7.02452746  1.79382908]
#  [ 4.96730841 -7.21958448]
#  [ 6.75722621  2.32668816]
#  [-7.04166678  8.62982911]
#  [ 1.36660984 -6.71248532]
#  [-6.36371081 -6.22088134]
#  [ 0.31090918  0.65926319]
#  [ 7.07609866  8.94095991]]
# [DEBUG][PSO it15 p18] MILP solved:
#    → Truck time   = 0.997 h
#    → Drone time   = 1.739 h
#    → Service time = 0.667 h
#    → Total time   = 3.402 h (Obj 3.402)
# [DEBUG][PSO] Iter 15 P19 → endurance OK, centres =
# [[-6.95273558  1.84420816]
#  [ 4.97808713 -7.17623458]
#  [ 6.74778454  2.34870757]
#  [-7.02268229  8.60616233]
#  [ 1.42554872 -6.73486686]
#  [-6.36488776 -6.2310946 ]
#  [ 0.28229719  0.70501492]
#  [ 7.21519932  8.88425978]]
# [DEBUG][PSO it15 p19] MILP solved:
#    → Truck time   = 0.998 h
#    → Drone time   = 1.742 h
#    → Service time = 0.667 h
#    → Total time   = 3.406 h (Obj 3.406)
# [DEBUG][PSO] Iter 15 P20 → endurance OK, centres =
# [[-7.00472739  1.87502491]
#  [ 4.90502346 -7.19654889]
#  [ 6.77243155  2.41144667]
#  [-7.02166237  8.68314698]
#  [ 1.32218195 -6.73717513]
#  [-6.47267271 -6.20080269]
#  [ 0.31401207  0.59335782]
#  [ 7.18622735  8.82072818]]
# [DEBUG][PSO it15 p20] MILP solved:
#    → Truck time   = 0.994 h
#    → Drone time   = 1.746 h
#    → Service time = 0.667 h
#    → Total time   = 3.406 h (Obj 3.406)
# [DEBUG][PSO] Iter 15 P21 → endurance OK, centres =
# [[-7.04249149  1.8290667 ]
#  [ 4.96429767 -7.21735967]
#  [ 6.7482804   2.39321962]
#  [-7.00098568  8.5551843 ]
#  [ 1.37298501 -6.70539156]
#  [-6.4143395  -6.10313452]
#  [ 0.27422037  0.64009017]
#  [ 7.09789673  8.85511723]]
# [DEBUG][PSO it15 p21] MILP solved:
#    → Truck time   = 0.995 h
#    → Drone time   = 1.738 h
#    → Service time = 0.667 h
#    → Total time   = 3.400 h (Obj 3.400)
# [DEBUG][PSO] Iter 15 P22 → endurance OK, centres =
# [[-6.99344993  1.81914779]
#  [ 4.9668056  -7.23459394]
#  [ 6.75216659  2.39235548]
#  [-7.03902196  8.62870494]
#  [ 1.43676599 -6.8261626 ]
#  [-6.43241324 -6.20929269]
#  [ 0.31337119  0.62574376]
#  [ 7.16334352  8.72329802]]
# [DEBUG][PSO it15 p22] MILP solved:
#    → Truck time   = 0.994 h
#    → Drone time   = 1.747 h
#    → Service time = 0.667 h
#    → Total time   = 3.407 h (Obj 3.407)
# [DEBUG][PSO] Iter 15 P23 → endurance OK, centres =
# [[-7.04682838  1.8387038 ]
#  [ 5.01571507 -7.32371991]
#  [ 6.7826471   2.45462582]
#  [-7.02324841  8.69062684]
#  [ 1.37663341 -6.88696777]
#  [-6.44050957 -6.18622561]
#  [ 0.32486974  0.60791175]
#  [ 7.05254214  8.81550134]]
# [DEBUG][PSO it15 p23] MILP solved:
#    → Truck time   = 0.997 h
#    → Drone time   = 1.736 h
#    → Service time = 0.667 h
#    → Total time   = 3.400 h (Obj 3.400)
# [DEBUG][PSO] Iter 15 P24 → endurance OK, centres =
# [[-6.9977508   1.75929633]
#  [ 4.98837692 -7.22019553]
#  [ 6.76974849  2.40133511]
#  [-6.99796195  8.6619845 ]
#  [ 1.39923224 -6.69319158]
#  [-6.44428626 -6.21439494]
#  [ 0.30915189  0.6500719 ]
#  [ 7.10915322  8.85958909]]
# [DEBUG][PSO it15 p24] MILP solved:
#    → Truck time   = 0.995 h
#    → Drone time   = 1.740 h
#    → Service time = 0.667 h
#    → Total time   = 3.401 h (Obj 3.401)
# [DEBUG][PSO] Iter 15 P25 → endurance OK, centres =
# [[-7.0884347   1.81912821]
#  [ 4.91546477 -7.1907971 ]
#  [ 6.76980091  2.26625335]
#  [-7.00670867  8.60309633]
#  [ 1.52441454 -6.65977296]
#  [-6.39128705 -6.19120532]
#  [ 0.37090447  0.63932026]
#  [ 7.36457585  8.89203793]]
# [DEBUG][PSO it15 p25] MILP solved:
#    → Truck time   = 1.003 h
#    → Drone time   = 1.743 h
#    → Service time = 0.667 h
#    → Total time   = 3.413 h (Obj 3.413)
# [DEBUG][PSO] Iter 15 P26 → endurance OK, centres =
# [[-6.99153865  1.79009253]
#  [ 4.95408013 -7.21909071]
#  [ 6.76238445  2.39179143]
#  [-7.04850347  8.61755221]
#  [ 1.44579426 -6.86156159]
#  [-6.36462869 -6.23391968]
#  [ 0.31703713  0.65240269]
#  [ 7.15094348  8.90182036]]
# [DEBUG][PSO it15 p26] MILP solved:
#    → Truck time   = 0.998 h
#    → Drone time   = 1.740 h
#    → Service time = 0.667 h
#    → Total time   = 3.404 h (Obj 3.404)
# [DEBUG][PSO] Iter 15 P27 → endurance OK, centres =
# [[-7.05644354  1.83538778]
#  [ 5.20450875 -6.50844027]
#  [ 6.94126122  2.06900571]
#  [-7.07873751  8.51779593]
#  [ 1.36409775 -6.62183516]
#  [-6.38735944 -6.09404965]
#  [ 0.67308501  0.59741433]
#  [ 7.12702101  8.74455023]]
# [DEBUG][PSO it15 p27] MILP solved:
#    → Truck time   = 0.984 h
#    → Drone time   = 2.009 h
#    → Service time = 0.667 h
#    → Total time   = 3.660 h (Obj 3.660)
# [DEBUG][PSO] Iter 15 P28 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 15 P29 → endurance OK, centres =
# [[-7.01842332  1.88316856]
#  [ 4.96332987 -7.18646917]
#  [ 6.72799282  2.32837257]
#  [-7.06534007  8.60575761]
#  [ 1.34660229 -6.72685245]
#  [-6.41859626 -6.23485209]
#  [ 0.33546302  0.65605403]
#  [ 7.06308691  8.88555059]]
# [DEBUG][PSO it15 p29] MILP solved:
#    → Truck time   = 0.995 h
#    → Drone time   = 1.738 h
#    → Service time = 0.667 h
#    → Total time   = 3.399 h (Obj 3.399)
# [DEBUG][PSO] Iter 15 P30 → endurance OK, centres =
# [[-7.00697017  1.87007436]
#  [ 4.93821162 -7.21580426]
#  [ 6.73800969  2.40061931]
#  [-7.04795932  8.65204007]
#  [ 1.30536454 -6.73577433]
#  [-6.39248599 -6.20016194]
#  [ 0.31842344  0.64164532]
#  [ 7.10936733  8.88738137]]
# [DEBUG][PSO it15 p30] MILP solved:
#    → Truck time   = 0.996 h
#    → Drone time   = 1.738 h
#    → Service time = 0.667 h
#    → Total time   = 3.400 h (Obj 3.400)
# [DEBUG][PSO] Starting iteration 16
# [DEBUG][PSO] Iter 16 P1 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 16 P2 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 16 P3 → endurance OK, centres =
# [[-6.98121305  1.88926061]
#  [ 4.96737804 -7.23481831]
#  [ 6.75946115  2.28133785]
#  [-7.03067258  8.64895487]
#  [ 1.34340135 -6.75302829]
#  [-6.44953555 -6.23885912]
#  [ 0.33041721  0.72870213]
#  [ 7.073303    8.88137986]]
# [DEBUG][PSO it16 p3] MILP solved:
#    → Truck time   = 0.995 h
#    → Drone time   = 1.740 h
#    → Service time = 0.667 h
#    → Total time   = 3.402 h (Obj 3.402)
# [DEBUG][PSO] Iter 16 P4 → endurance OK, centres =
# [[-7.00547943  1.82806435]
#  [ 4.95978346 -7.2953997 ]
#  [ 6.76146596  2.30244024]
#  [-6.94730986  8.68414569]
#  [ 1.28777208 -6.63154002]
#  [-6.45182621 -6.11738444]
#  [ 0.31780097  0.60645932]
#  [ 7.04579196  8.84449581]]
# [DEBUG][PSO it16 p4] MILP solved:
#    → Truck time   = 0.994 h
#    → Drone time   = 1.736 h
#    → Service time = 0.667 h
#    → Total time   = 3.397 h (Obj 3.397)
# [DEBUG][PSO] Iter 16 P5 → endurance OK, centres =
# [[-7.009066    1.82416495]
#  [ 4.95813736 -7.24078883]
#  [ 6.81695771  2.37816206]
#  [-7.04147112  8.64881691]
#  [ 1.31753685 -6.73376167]
#  [-6.40046804 -6.1817105 ]
#  [ 0.32887182  0.63404584]
#  [ 7.0781552   8.89309753]]
# [DEBUG][PSO it16 p5] MILP solved:
#    → Truck time   = 0.996 h
#    → Drone time   = 1.737 h
#    → Service time = 0.667 h
#    → Total time   = 3.399 h (Obj 3.399)
# [DEBUG][PSO] Iter 16 P6 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 16 P7 → endurance OK, centres =
# [[-6.9561392   1.84234481]
#  [ 4.97389712 -7.22929518]
#  [ 6.72158193  2.32768981]
#  [-7.00406105  8.69446605]
#  [ 1.32092258 -6.64698353]
#  [-6.43324257 -6.173857  ]
#  [ 0.32206562  0.64961421]
#  [ 7.01810919  8.89016944]]
# [DEBUG][PSO it16 p7] MILP solved:
#    → Truck time   = 0.993 h
#    → Drone time   = 1.739 h
#    → Service time = 0.667 h
#    → Total time   = 3.399 h (Obj 3.399)
# [DEBUG][PSO] Iter 16 P8 → endurance OK, centres =
# [[-6.93568094  1.80024957]
#  [ 5.68882801 -7.38140564]
#  [ 6.85014605  2.2725489 ]
#  [-6.94049657  8.67003025]
#  [ 1.31007212 -6.70182741]
#  [-6.34494857 -6.04369649]
#  [ 0.38347517  0.71048935]
#  [ 7.01371621  8.95688179]]
# [DEBUG][PSO it16 p8] MILP solved:
#    → Truck time   = 1.018 h
#    → Drone time   = 1.974 h
#    → Service time = 0.667 h
#    → Total time   = 3.658 h (Obj 3.658)
# [DEBUG][PSO] Iter 16 P9 → endurance OK, centres =
# [[-7.10541133  1.73534409]
#  [ 4.82502503 -7.29635178]
#  [ 6.76780059  2.4608534 ]
#  [-7.14021807  8.75889019]
#  [ 1.41013042 -6.71550399]
#  [-6.51771939 -6.19816763]
#  [ 0.13297917  0.59134763]
#  [ 6.98975715  8.9085213 ]]
# [DEBUG][PSO it16 p9] MILP solved:
#    → Truck time   = 0.995 h
#    → Drone time   = 1.764 h
#    → Service time = 0.667 h
#    → Total time   = 3.426 h (Obj 3.426)
# [DEBUG][PSO] Iter 16 P10 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 16 P11 → endurance OK, centres =
# [[-6.71578809  1.22585026]
#  [ 4.95570697 -7.13669647]
#  [ 6.87805807  2.96305383]
#  [-6.79851656  8.523769  ]
#  [ 1.63913    -7.08543917]
#  [-5.59542503 -5.66231892]
#  [-0.29285028  0.53364821]
#  [ 7.66731682  9.69368816]]
# [DEBUG][PSO it16 p11] MILP solved:
#    → Truck time   = 1.034 h
#    → Drone time   = 1.948 h
#    → Service time = 0.667 h
#    → Total time   = 3.648 h (Obj 3.648)
# [DEBUG][PSO] Iter 16 P12 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 16 P13 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 16 P14 → endurance OK, centres =
# [[-7.09140244  1.87766869]
#  [ 4.99516855 -7.2010992 ]
#  [ 6.7526755   2.36014571]
#  [-7.01894607  8.69515046]
#  [ 1.29262768 -6.60165721]
#  [-6.36566341 -6.17951547]
#  [ 0.31194081  0.63935123]
#  [ 7.20440986  8.85411998]]
# [DEBUG][PSO it16 p14] MILP solved:
#    → Truck time   = 1.000 h
#    → Drone time   = 1.734 h
#    → Service time = 0.667 h
#    → Total time   = 3.400 h (Obj 3.400)
# [DEBUG][PSO] Iter 16 P15 → endurance OK, centres =
# [[-7.00921934  1.85405947]
#  [ 4.97369535 -7.18665336]
#  [ 6.80480581  2.35374733]
#  [-7.01573147  8.68242447]
#  [ 1.35651288 -6.68041646]
#  [-6.42569315 -6.20280509]
#  [ 0.24976065  0.64816806]
#  [ 7.0905104   8.89756368]]
# [DEBUG][PSO it16 p15] MILP solved:
#    → Truck time   = 0.995 h
#    → Drone time   = 1.739 h
#    → Service time = 0.667 h
#    → Total time   = 3.401 h (Obj 3.401)
# [DEBUG][PSO] Iter 16 P16 → endurance OK, centres =
# [[-7.00162941  1.86446351]
#  [ 4.9650955  -7.21570407]
#  [ 6.7727773   2.26501153]
#  [-7.00106423  8.65956716]
#  [ 1.33757996 -6.67720489]
#  [-6.45118696 -6.20719732]
#  [ 0.31170665  0.65836065]
#  [ 7.08659613  8.84161966]]
# [DEBUG][PSO it16 p16] MILP solved:
#    → Truck time   = 0.993 h
#    → Drone time   = 1.739 h
#    → Service time = 0.667 h
#    → Total time   = 3.399 h (Obj 3.399)
# [DEBUG][PSO] Iter 16 P17 → endurance VIOLATION in cluster 5
# [DEBUG][PSO] Iter 16 P18 → endurance OK, centres =
# [[-6.94635885  1.81259814]
#  [ 4.9840601  -7.22067154]
#  [ 6.74386917  2.31611463]
#  [-7.00873408  8.65208987]
#  [ 1.32441615 -6.70546021]
#  [-6.4005853  -6.1881511 ]
#  [ 0.30063682  0.6668351 ]
#  [ 7.05755358  8.90621572]]
# [DEBUG][PSO it16 p18] MILP solved:
#    → Truck time   = 0.995 h
#    → Drone time   = 1.738 h
#    → Service time = 0.667 h
#    → Total time   = 3.400 h (Obj 3.400)
# [DEBUG][PSO] Iter 16 P19 → endurance OK, centres =
# [[-6.98350012  1.88286857]
#  [ 4.96585944 -7.21706344]
#  [ 6.74455956  2.34867411]
#  [-7.0119663   8.62751191]
#  [ 1.37055586 -6.68277646]
#  [-6.43152999 -6.22620111]
#  [ 0.2809254   0.701353  ]
#  [ 7.17134422  8.86688519]]
# [DEBUG][PSO it16 p19] MILP solved:
#    → Truck time   = 0.997 h
#    → Drone time   = 1.740 h
#    → Service time = 0.667 h
#    → Total time   = 3.404 h (Obj 3.404)
# [DEBUG][PSO] Iter 16 P20 → endurance OK, centres =
# [[-7.00451942  1.86487392]
#  [ 4.91412332 -7.23143866]
#  [ 6.76937585  2.38860561]
#  [-6.97682272  8.68583811]
#  [ 1.30286811 -6.67743491]
#  [-6.48247721 -6.20176116]
#  [ 0.30980189  0.59343981]
#  [ 7.17174255  8.83174735]]
# [DEBUG][PSO it16 p20] MILP solved:
#    → Truck time   = 0.994 h
#    → Drone time   = 1.744 h
#    → Service time = 0.667 h
#    → Total time   = 3.405 h (Obj 3.405)
# [DEBUG][PSO] Iter 16 P21 → endurance OK, centres =
# [[-7.01088831  1.83971182]
#  [ 4.97190574 -7.21479561]
#  [ 6.74808549  2.3535356 ]
#  [-7.01393731  8.60524874]
#  [ 1.33635257 -6.65361653]
#  [-6.45004666 -6.12633171]
#  [ 0.30358864  0.63809581]
#  [ 7.09587465  8.88174235]]
# [DEBUG][PSO it16 p21] MILP solved:
#    → Truck time   = 0.995 h
#    → Drone time   = 1.733 h
#    → Service time = 0.667 h
#    → Total time   = 3.395 h (Obj 3.395)
# [DEBUG][PSO] Iter 16 P22 → endurance OK, centres =
# [[-7.01078446  1.83273839]
#  [ 4.96866426 -7.2178156 ]
#  [ 6.71874131  2.3767745 ]
#  [-7.01808393  8.64435847]
#  [ 1.40327596 -6.69995616]
#  [-6.45763068 -6.17470917]
#  [ 0.30895394  0.62766158]
#  [ 7.12408818  8.80790366]]
# [DEBUG][PSO it16 p22] MILP solved:
#    → Truck time   = 0.994 h
#    → Drone time   = 1.740 h
#    → Service time = 0.667 h
#    → Total time   = 3.401 h (Obj 3.401)
# [DEBUG][PSO] Iter 16 P23 → endurance OK, centres =
# [[-7.05787408  1.87959138]
#  [ 4.98732972 -7.30433544]
#  [ 6.75926274  2.44176226]
#  [-7.01638717  8.68932664]
#  [ 1.34950061 -6.84740015]
#  [-6.43972851 -6.17513627]
#  [ 0.32450992  0.62680938]
#  [ 7.0878421   8.84908186]]
# [DEBUG][PSO it16 p23] MILP solved:
#    → Truck time   = 0.998 h
#    → Drone time   = 1.734 h
#    → Service time = 0.667 h
#    → Total time   = 3.399 h (Obj 3.399)
# [DEBUG][PSO] Iter 16 P24 → endurance OK, centres =
# [[-6.99896464  1.80122699]
#  [ 4.99007484 -7.21330282]
#  [ 6.75393457  2.37069566]
#  [-7.00191849  8.67321238]
#  [ 1.34664098 -6.66691809]
#  [-6.43624581 -6.17715727]
#  [ 0.30147896  0.66232051]
#  [ 7.12266856  8.86495475]]
# [DEBUG][PSO it16 p24] MILP solved:
#    → Truck time   = 0.996 h
#    → Drone time   = 1.737 h
#    → Service time = 0.667 h
#    → Total time   = 3.399 h (Obj 3.399)
# [DEBUG][PSO] Iter 16 P25 → endurance OK, centres =
# [[-7.07106225  1.83007816]
#  [ 4.91271593 -7.19950894]
#  [ 6.75579599  2.33324171]
#  [-7.01828223  8.6111176 ]
#  [ 1.44560421 -6.67014553]
#  [-6.42274016 -6.18480859]
#  [ 0.35517012  0.64787921]
#  [ 7.30044039  8.90151757]]
# [DEBUG][PSO it16 p25] MILP solved:
#    → Truck time   = 1.001 h
#    → Drone time   = 1.739 h
#    → Service time = 0.667 h
#    → Total time   = 3.407 h (Obj 3.407)
# [DEBUG][PSO] Iter 16 P26 → endurance OK, centres =
# [[-7.00737981  1.80823611]
#  [ 4.97291612 -7.2039689 ]
#  [ 6.7392487   2.39086847]
#  [-7.02379099  8.63565797]
#  [ 1.42204691 -6.81286363]
#  [-6.35988112 -6.18640756]
#  [ 0.32668575  0.65684541]
#  [ 7.13991596  8.89285569]]
# [DEBUG][PSO it16 p26] MILP solved:
#    → Truck time   = 0.997 h
#    → Drone time   = 1.737 h
#    → Service time = 0.667 h
#    → Total time   = 3.400 h (Obj 3.400)
# [DEBUG][PSO] Iter 16 P27 → endurance OK, centres =
# [[-7.04970788  1.84240266]
#  [ 5.10254098 -7.08472206]
#  [ 6.81836616  2.34568843]
#  [-6.94547517  8.58608687]
#  [ 1.33911315 -6.61875639]
#  [-6.35927677 -6.14821338]
#  [ 0.57485603  0.66729206]
#  [ 7.09393907  8.88489601]]
# [DEBUG][PSO it16 p27] MILP solved:
#    → Truck time   = 0.996 h
#    → Drone time   = 1.743 h
#    → Service time = 0.667 h
#    → Total time   = 3.406 h (Obj 3.406)
# [DEBUG][PSO] Iter 16 P28 → endurance VIOLATION in cluster 1
# [DEBUG][PSO] Iter 16 P29 → endurance OK, centres =
# [[-7.01597827  1.86888073]
#  [ 4.96526264 -7.18918343]
#  [ 6.71753004  2.34116332]
#  [-7.04226176  8.60504992]
#  [ 1.34724589 -6.71087813]
#  [-6.42246848 -6.20223325]
#  [ 0.33191762  0.65107824]
#  [ 7.07260267  8.87835887]]
# [DEBUG][PSO it16 p29] MILP solved:
#    → Truck time   = 0.994 h
#    → Drone time   = 1.736 h
#    → Service time = 0.667 h
#    → Total time   = 3.397 h (Obj 3.397)
# [DEBUG][PSO] Iter 16 P30 → endurance OK, centres =
# [[-7.00850525  1.86970995]
#  [ 4.94561395 -7.17407676]
#  [ 6.72422141  2.37414588]
#  [-7.03584868  8.63900621]
#  [ 1.29517211 -6.68658895]
#  [-6.3878681  -6.18109416]
#  [ 0.34481861  0.66509304]
#  [ 7.09123987  8.87600199]]
# [DEBUG][PSO it16 p30] MILP solved:
#    → Truck time   = 0.994 h
#    → Drone time   = 1.736 h
#    → Service time = 0.667 h
#    → Total time   = 3.397 h (Obj 3.397)
# Stopping search: maximum iterations reached --> 15
# [DEBUG] PSO completed: best_f = 3.395
# [DEBUG][FINAL] MILP solved:
#    → Truck time   = 0.995 h
#    → Drone time   = 1.733 h
#    → Service time = 0.667 h
#    → Total time   = 3.395 h (Obj 3.395)
# [DEBUG] Extracted route: [0, 7, 3, 8, 4, 1, 6, 5, 2, 0]
# PTD-VRPD finished – makespan 3.39 hours

# %%
# =============================================================
#  PTD-VRPD  ·  static speed profile · cloud-licence Gurobi
#            baseline (clustering) vs. optimised (PSO) comparison
# =============================================================

#  pip install gurobipy pyswarm pandas numpy scikit-learn matplotlib

import numpy as np, pandas as pd, itertools, matplotlib.pyplot as plt
from   sklearn.cluster       import KMeans
from   pyswarm               import pso
import gurobipy as gp
from   gurobipy              import GRB
from   scipy.interpolate      import interp1d
from   scipy.spatial.distance import cdist

# -------------------------------------------------------------
# 0.  Cloud-licence credentials
# -------------------------------------------------------------
WLS_ID     = "95c3994f-513d-4b8c-a42c-0194dad8ec5c"
WLS_SECRET = "3dc0e444-1f74-49f3-96cc-e9abaabb8ce4"
LICENSE_ID = 2551395
def make_env():
    env = gp.Env(empty=True)
    env.setParam("WLSACCESSID", WLS_ID)
    env.setParam("WLSSECRET",   WLS_SECRET)
    env.setParam("LICENSEID",   LICENSE_ID)
    env.setParam("OutputFlag",  0)
    env.start()
    return env
GRB_ENV = make_env()
print("[DEBUG] Gurobi cloud environment initialized.")

# -------------------------------------------------------------
# 1.  Global constants
# -------------------------------------------------------------
RNG_SEED            = 42
np.random.seed()

AREA_KM             = 10.0
N_DELIVERIES        = 100
DEPOT               = (0., 0.)

DRONE_SPEED_KMH     = 40.
DRONE_END_MIN       = 20
SERVICE_MIN_PER_CL  = 5
BIGM                = 1_000_000.0

# PSO bookkeeping
SWARM_SIZE   = 100
ITERATIONS  = 15
call_counter = 0
iter_counter = 0

# -------------------------------------------------------------
# 2.  Speed lookup
# -------------------------------------------------------------
def build_speed_func(csv_path="Predicted Speed/Predicted_Speeds.csv"):
    df = pd.read_csv(csv_path).rename(columns=str.strip)
    if not {"Time of Day","Predicted Speed"}.issubset(df.columns):
        raise ValueError("CSV must contain 'Time of Day' + 'Predicted Speed'")
    df = df.sort_values("Time of Day")
    f  = interp1d(df["Time of Day"]%24, df["Predicted Speed"],
                  kind="linear", fill_value="extrapolate")
    def speed(t): return float(f(t%24))
    print(f"[DEBUG] Loaded {len(df)} speed points – example 09:30 ⇒ {speed(9.5):.1f} km/h")
    return speed
speed_func = build_speed_func()

# -------------------------------------------------------------
# 3.  Instance helpers
# -------------------------------------------------------------
def gen_locations(n=N_DELIVERIES, area=AREA_KM):
    locs = np.vstack([DEPOT, np.random.uniform(-area, area, size=(n,2))])
    print(f"[DEBUG] Generated {n} delivery locations.")
    return locs

def kmeans_endurance(locs):
    K=1
    while True:
        km = KMeans(n_clusters=K, random_state=RNG_SEED, n_init=10).fit(locs[1:])
        ok=True
        for i,ctr in enumerate(km.cluster_centers_):
            dkm = np.linalg.norm(locs[1:][km.labels_==i]-ctr, axis=1)
            rt  = 2*dkm/DRONE_SPEED_KMH + SERVICE_MIN_PER_CL/60.
            if (rt>DRONE_END_MIN/60.).any():
                ok=False; break
        if ok:
            print(f"[DEBUG] K-means found feasible K={K} clusters.")
            return km.labels_, km.cluster_centers_
        K+=1

# -------------------------------------------------------------
# 4.  Build & solve MILP (with component-time debug)
# -------------------------------------------------------------
def build_and_solve_milp(locs, centres, labels, tag=""):
    nStop   = len(centres)+1
    custIdx = np.arange(1,len(locs))

    xy   = np.vstack([DEPOT, centres])
    Dman = cdist(xy,xy,metric="cityblock")
    Deuc = cdist(locs,xy)

    m = gp.Model(env=GRB_ENV); m.Params.OutputFlag=0

    ############################
    # decision variables
    ############################
    r    = m.addVars(nStop,nStop,vtype=GRB.BINARY,name="r") # routing
    Tdep = m.addVars(nStop,lb=0,name="Tdep") # departure times
    Tarr = m.addVars(nStop,lb=0,name="Tarr") # arrival times
    Td   = m.addVars(len(centres),lb=0,name="Tdrone") # drone times
    y    = m.addVars(len(custIdx),len(centres),vtype=GRB.BINARY,name="y") # drone assignment
    
    ##########################
    # objective
    ##########################
    m.setObjective(
        gp.quicksum(Dman[i,j]/speed_func(0)*r[i,j]
                    for i in range(nStop) for j in range(nStop) if i!=j)
    + gp.quicksum(Td[k] for k in range(len(centres)))
    + SERVICE_MIN_PER_CL/60.*len(centres),
    GRB.MINIMIZE)

    ##########################
    # constraints
    ##########################
    # routing & subtour elimination 
    for i in range(nStop):
        m.addConstr(gp.quicksum(r[i,j] for j in range(nStop) if j!=i)==1)
        m.addConstr(gp.quicksum(r[j,i] for j in range(nStop) if j!=i)==1)
    u = m.addVars(nStop,lb=0,ub=nStop-1)
    for i,j in itertools.permutations(range(1,nStop),2):
        m.addConstr(u[i]-u[j]+(nStop-1)*r[i,j] <= nStop-2)

    # timing constraints
    for i,j in itertools.product(range(nStop),range(nStop)):
        if i==j: continue
        m.addConstr(Tarr[j] >= Tdep[i] + Dman[i,j]/speed_func(0)
                    - BIGM*(1-r[i,j]))
        if i!=0:
            m.addConstr(Tdep[i] >= Tarr[i] + Td[i-1] + SERVICE_MIN_PER_CL/60.)
    m.addConstr(Tdep[0]==0)

    # drone assignment & endurance constraints
    for cIdx,cust in enumerate(custIdx):
        m.addConstr(gp.quicksum(y[cIdx,k] for k in range(len(centres)))==1)
        for k in range(len(centres)):
            rt = 2*Deuc[cust,k+1]/DRONE_SPEED_KMH
            m.addConstr(rt - DRONE_END_MIN/60. - BIGM*(1-y[cIdx,k]) <= 0)
            m.addConstr(Td[k] >= rt*y[cIdx,k])

    m.optimize()
    if m.SolCount==0:
        print(f"[DEBUG]{tag} MILP infeasible.")
        return np.inf, m, r

    # component times 
    truck_time  = sum((Dman[i,j]/speed_func(0))*r[i,j].X
                       for i in range(nStop) for j in range(nStop) if i!=j)
    drone_time  = sum(Td[k].X for k in range(len(centres)))
    service_time= SERVICE_MIN_PER_CL/60.*len(centres)
    total_time  = truck_time + drone_time + service_time

    print(f"[DEBUG]{tag} MILP solved:")
    print(f"   → Truck   {truck_time:.3f} h | Drone {drone_time:.3f} h | "
          f"Service {service_time:.3f} h | Total {total_time:.3f} h")
    return total_time, m, r

# -------------------------------------------------------------
# 5.  PSO fitness with iteration/particle debug
# -------------------------------------------------------------
def pso_fitness(w, locs, centres0, labels0):
    global call_counter, iter_counter
    call_counter += 1

    # Once we've seen SWARM_SIZE evaluations, that's the end of iteration 1, etc.
    if call_counter % SWARM_SIZE == 0:
        iteration = call_counter // SWARM_SIZE
        if 1 <= iteration <= ITERATIONS:
            iter_counter = iteration
            print(f"[DEBUG][PSO] -------------------- iteration {iter_counter} ---------------------")

    particle_idx = ((call_counter - 1) % SWARM_SIZE) + 1
    K = len(centres0)
    ctrs = centres0 + w.reshape(K, 2)

    # endurance check
    for k, c in enumerate(ctrs):
        d  = np.linalg.norm(locs[1:][labels0 == k] - c, axis=1)
        rt = 2 * d / DRONE_SPEED_KMH
        if (rt > DRONE_END_MIN / 60.).any():
            print(f"[DEBUG][PSO] it {iter_counter} p{particle_idx}: endurance VIOLATION in cl {k}")
            return 1e6

    print(f"[DEBUG][PSO] it {iter_counter} p{particle_idx}: centres OK")
    obj, _, _ = build_and_solve_milp(
        locs, ctrs, labels0,
        tag=f"[PSO it{iter_counter} p{particle_idx}]"
    )
    return 1e6 if np.isinf(obj) else obj 

# -------------------------------------------------------------
# 6.  Route extractor
# -------------------------------------------------------------
def extract_route(r_vars):
    edges = {(i,j) for (i,j),v in r_vars.items() if v.X>0.5}
    route=[0]; nStop=int(np.sqrt(len(r_vars)))
    while len(route)<nStop+1:
        last=route[-1]
        nxt = next(j for (i,j) in edges if i==last)
        route.append(nxt)
        if nxt==0: break
    print(f"[DEBUG] Extracted route: {route}")
    return route

# -------------------------------------------------------------
# 7.  Main solver/plotter
# -------------------------------------------------------------
def solve_and_plot(locs):
    global call_counter, iter_counter
    call_counter = iter_counter = 0

    labels0, centres0 = kmeans_endurance(locs)

    # -------- baseline (clustering only) --------------------
    base_time, base_mdl, base_r = build_and_solve_milp(
        locs, centres0, labels0, tag="[CLUSTER]")
    if np.isinf(base_time):
        raise RuntimeError("Baseline clustering model infeasible — should not happen")

    # -------- optimised (PSO) -------------------------------
    lb = [-2]*2*len(centres0); ub = [2]*2*len(centres0)
    print("[DEBUG] Beginning PSO optimisation...")
    w_best, f_best = pso(pso_fitness, lb, ub,
                         swarmsize=SWARM_SIZE, maxiter=ITERATIONS, debug=False,
                         args=(locs, centres0, labels0))
    print(f"[DEBUG] PSO best objective = {f_best:.3f} h")
    print(f"[DEBUG] PSO best weights =\n{w_best}")
    print(f"[DEBUG] PSO best centres =\n{centres0 + w_best.reshape(len(centres0),2)}")

    centres_opt = centres0 if f_best>=1e6 else centres0 + w_best.reshape(len(centres0),2) # If infeasible, fallback to clustering centre
    opt_time, opt_mdl, opt_r = build_and_solve_milp(locs, centres_opt, labels0, tag="[OPT ]")
    if np.isinf(opt_time):
        # fallback to baseline if somehow infeasible
        centres_opt, opt_time, opt_r = centres0, base_time, base_r

    # -------- improvement ----------------------------------
    improvement = 100*(base_time - opt_time)/base_time
    print(f"\n[RESULT] Clustering   : {base_time:.3f} h")
    print(f"[RESULT] Optimised    : {opt_time:.3f} h")
    print(f"[RESULT] Improvement  : {improvement:.2f} %")

    # -------- plot (optimised) ------------------------------
    route_opt = extract_route(opt_r)
    route_base = extract_route(base_r)
    plt.figure(figsize=(7,7))
    for k in range(len(centres0)):
        pts = locs[1:][labels0==k]
        plt.scatter(pts[:,0],pts[:,1],s=15,alpha=0.6,label=f'Cl {k+1}')
    plt.scatter(centres_opt[:,0],centres_opt[:,1],marker='^',c='k',s=80,label='Optimized Stop')
    plt.scatter(centres0[:,0],centres0[:,1],marker='s',c='orange',s=60,label='Clustering Stop')
    plt.scatter(*DEPOT,marker='*',c='r',s=120,label='Depot')
    # Plot optimized route
    path_xy_opt = np.vstack([DEPOT, centres_opt])[route_opt]
    plt.plot(path_xy_opt[:,0],path_xy_opt[:,1],'k--',lw=1.5,label='Optimized Truck Path')
    # Plot clustering (baseline) route
    path_xy_base = np.vstack([DEPOT, centres0])[route_base]
    plt.plot(path_xy_base[:,0],path_xy_base[:,1],'b-',lw=1.5,label='Clustering Truck Path')
    plt.title(f'Makespan {opt_time:.2f} h  |  Improvement {improvement:.1f}%')
    plt.legend(fontsize=8); plt.axis('equal'); plt.grid(True)

    # Plot the values of the PSO best centers beside each center
    for idx, (x, y) in enumerate(centres_opt):
        plt.text(x, y, f'({x:.2f},{y:.2f})', fontsize=8, color='blue', ha='left', va='bottom')

    plt.show()

    return base_time, opt_time, improvement

# -------------------------------------------------------------
# 8.  Demo run
# -------------------------------------------------------------
if __name__=="__main__":
    locs               = gen_locations()
    base, opt, impr    = solve_and_plot(locs)
    print(f"\nPTD-VRPD finished – baseline {base:.2f} h, "
          f"optimised {opt:.2f} h,  Δ = {impr:.1f}%")
# Out:
# [DEBUG] Gurobi cloud environment initialized.
# [DEBUG] Loaded 96 speed points – example 09:30 ⇒ 66.3 km/h
# [DEBUG] Generated 100 delivery locations.
# [DEBUG] K-means found feasible K=10 clusters.
# [DEBUG][CLUSTER] MILP solved:
#    → Truck   1.092 h | Drone 1.792 h | Service 0.833 h | Total 3.718 h
# [DEBUG] Beginning PSO optimisation...
# [DEBUG][PSO] it 0 p1: centres OK
# [DEBUG][PSO it0 p1] MILP solved:
#    → Truck   1.232 h | Drone 1.697 h | Service 0.833 h | Total 3.762 h
# [DEBUG][PSO] it 0 p2: centres OK
# [DEBUG][PSO it0 p2] MILP solved:
#    → Truck   1.133 h | Drone 1.778 h | Service 0.833 h | Total 3.745 h
# [DEBUG][PSO] it 0 p3: centres OK
# [DEBUG][PSO it0 p3] MILP solved:
#    → Truck   1.244 h | Drone 1.715 h | Service 0.833 h | Total 3.792 h
# [DEBUG][PSO] it 0 p4: centres OK
# [DEBUG][PSO it0 p4] MILP solved:
#    → Truck   1.157 h | Drone 1.504 h | Service 0.833 h | Total 3.495 h
# [DEBUG][PSO] it 0 p5: centres OK
# [DEBUG][PSO it0 p5] MILP solved:
#    → Truck   1.231 h | Drone 1.709 h | Service 0.833 h | Total 3.773 h
# [DEBUG][PSO] it 0 p6: centres OK
# [DEBUG][PSO it0 p6] MILP solved:
#    → Truck   1.048 h | Drone 1.657 h | Service 0.833 h | Total 3.539 h
# [DEBUG][PSO] it 0 p7: centres OK
# [DEBUG][PSO it0 p7] MILP solved:
#    → Truck   1.085 h | Drone 1.745 h | Service 0.833 h | Total 3.663 h
# [DEBUG][PSO] it 0 p8: centres OK
# [DEBUG][PSO it0 p8] MILP solved:
#    → Truck   1.211 h | Drone 1.668 h | Service 0.833 h | Total 3.712 h
# [DEBUG][PSO] it 0 p9: centres OK
# [DEBUG][PSO it0 p9] MILP solved:
#    → Truck   1.089 h | Drone 1.753 h | Service 0.833 h | Total 3.675 h
# [DEBUG][PSO] it 0 p10: centres OK
# [DEBUG][PSO it0 p10] MILP solved:
#    → Truck   1.117 h | Drone 1.519 h | Service 0.833 h | Total 3.469 h
# [DEBUG][PSO] it 0 p11: centres OK
# [DEBUG][PSO it0 p11] MILP solved:
#    → Truck   1.105 h | Drone 1.697 h | Service 0.833 h | Total 3.636 h
# [DEBUG][PSO] it 0 p12: centres OK
# [DEBUG][PSO it0 p12] MILP solved:
#    → Truck   1.166 h | Drone 1.900 h | Service 0.833 h | Total 3.899 h
# [DEBUG][PSO] it 0 p13: endurance VIOLATION in cl 4
# [DEBUG][PSO] it 0 p14: centres OK
# [DEBUG][PSO it0 p14] MILP solved:
#    → Truck   1.127 h | Drone 1.823 h | Service 0.833 h | Total 3.782 h
# [DEBUG][PSO] it 0 p15: centres OK
# [DEBUG][PSO it0 p15] MILP solved:
#    → Truck   1.088 h | Drone 1.648 h | Service 0.833 h | Total 3.569 h
# [DEBUG][PSO] it 0 p16: centres OK
# [DEBUG][PSO it0 p16] MILP solved:
#    → Truck   1.173 h | Drone 1.723 h | Service 0.833 h | Total 3.730 h
# [DEBUG][PSO] it 0 p17: centres OK
# [DEBUG][PSO it0 p17] MILP solved:
#    → Truck   1.110 h | Drone 1.653 h | Service 0.833 h | Total 3.596 h
# [DEBUG][PSO] it 0 p18: centres OK
# [DEBUG][PSO it0 p18] MILP solved:
#    → Truck   1.039 h | Drone 1.647 h | Service 0.833 h | Total 3.519 h
# [DEBUG][PSO] it 0 p19: endurance VIOLATION in cl 0
# [DEBUG][PSO] it 0 p20: centres OK
# [DEBUG][PSO it0 p20] MILP solved:
#    → Truck   1.173 h | Drone 1.921 h | Service 0.833 h | Total 3.928 h
# [DEBUG][PSO] it 0 p21: centres OK
# [DEBUG][PSO it0 p21] MILP solved:
#    → Truck   1.209 h | Drone 1.718 h | Service 0.833 h | Total 3.759 h
# [DEBUG][PSO] it 0 p22: centres OK
# [DEBUG][PSO it0 p22] MILP solved:
#    → Truck   1.152 h | Drone 1.668 h | Service 0.833 h | Total 3.653 h
# [DEBUG][PSO] it 0 p23: centres OK
# [DEBUG][PSO it0 p23] MILP solved:
#    → Truck   1.163 h | Drone 1.571 h | Service 0.833 h | Total 3.567 h
# [DEBUG][PSO] it 0 p24: centres OK
# [DEBUG][PSO it0 p24] MILP solved:
#    → Truck   1.208 h | Drone 1.619 h | Service 0.833 h | Total 3.660 h
# [DEBUG][PSO] it 0 p25: centres OK
# [DEBUG][PSO it0 p25] MILP solved:
#    → Truck   1.081 h | Drone 1.458 h | Service 0.833 h | Total 3.373 h
# [DEBUG][PSO] it 0 p26: centres OK
# [DEBUG][PSO it0 p26] MILP solved:
#    → Truck   1.253 h | Drone 1.588 h | Service 0.833 h | Total 3.674 h
# [DEBUG][PSO] it 0 p27: centres OK
# [DEBUG][PSO it0 p27] MILP solved:
#    → Truck   1.198 h | Drone 1.583 h | Service 0.833 h | Total 3.614 h
# [DEBUG][PSO] it 0 p28: centres OK
# [DEBUG][PSO it0 p28] MILP solved:
#    → Truck   1.240 h | Drone 1.689 h | Service 0.833 h | Total 3.762 h
# [DEBUG][PSO] it 0 p29: centres OK
# [DEBUG][PSO it0 p29] MILP solved:
#    → Truck   1.217 h | Drone 1.597 h | Service 0.833 h | Total 3.648 h
# [DEBUG][PSO] it 0 p30: centres OK
# [DEBUG][PSO it0 p30] MILP solved:
#    → Truck   1.184 h | Drone 1.634 h | Service 0.833 h | Total 3.651 h
# [DEBUG][PSO] it 0 p31: centres OK
# [DEBUG][PSO it0 p31] MILP solved:
#    → Truck   1.059 h | Drone 1.724 h | Service 0.833 h | Total 3.617 h
# [DEBUG][PSO] it 0 p32: centres OK
# [DEBUG][PSO it0 p32] MILP solved:
#    → Truck   1.025 h | Drone 1.623 h | Service 0.833 h | Total 3.481 h
# [DEBUG][PSO] it 0 p33: endurance VIOLATION in cl 0
# [DEBUG][PSO] it 0 p34: centres OK
# [DEBUG][PSO it0 p34] MILP solved:
#    → Truck   1.112 h | Drone 1.762 h | Service 0.833 h | Total 3.707 h
# [DEBUG][PSO] it 0 p35: centres OK
# [DEBUG][PSO it0 p35] MILP solved:
#    → Truck   1.188 h | Drone 1.841 h | Service 0.833 h | Total 3.863 h
# [DEBUG][PSO] it 0 p36: centres OK
# [DEBUG][PSO it0 p36] MILP solved:
#    → Truck   1.293 h | Drone 1.970 h | Service 0.833 h | Total 4.096 h
# [DEBUG][PSO] it 0 p37: endurance VIOLATION in cl 4
# [DEBUG][PSO] it 0 p38: centres OK
# [DEBUG][PSO it0 p38] MILP solved:
#    → Truck   1.241 h | Drone 1.688 h | Service 0.833 h | Total 3.763 h
# [DEBUG][PSO] it 0 p39: centres OK
# [DEBUG][PSO it0 p39] MILP solved:
#    → Truck   1.122 h | Drone 1.337 h | Service 0.833 h | Total 3.292 h
# [DEBUG][PSO] it 0 p40: centres OK
# [DEBUG][PSO it0 p40] MILP solved:
#    → Truck   1.269 h | Drone 1.635 h | Service 0.833 h | Total 3.737 h
# [DEBUG][PSO] it 0 p41: centres OK
# [DEBUG][PSO it0 p41] MILP solved:
#    → Truck   1.070 h | Drone 1.709 h | Service 0.833 h | Total 3.613 h
# [DEBUG][PSO] it 0 p42: centres OK
# [DEBUG][PSO it0 p42] MILP solved:
#    → Truck   1.248 h | Drone 1.714 h | Service 0.833 h | Total 3.795 h
# [DEBUG][PSO] it 0 p43: centres OK
# [DEBUG][PSO it0 p43] MILP solved:
#    → Truck   1.138 h | Drone 1.710 h | Service 0.833 h | Total 3.681 h
# [DEBUG][PSO] it 0 p44: centres OK
# [DEBUG][PSO it0 p44] MILP solved:
#    → Truck   1.165 h | Drone 1.612 h | Service 0.833 h | Total 3.610 h
# [DEBUG][PSO] it 0 p45: centres OK
# [DEBUG][PSO it0 p45] MILP solved:
#    → Truck   1.161 h | Drone 1.778 h | Service 0.833 h | Total 3.773 h
# [DEBUG][PSO] it 0 p46: centres OK
# [DEBUG][PSO it0 p46] MILP solved:
#    → Truck   1.150 h | Drone 1.737 h | Service 0.833 h | Total 3.721 h
# [DEBUG][PSO] it 0 p47: centres OK
# [DEBUG][PSO it0 p47] MILP solved:
#    → Truck   1.196 h | Drone 1.629 h | Service 0.833 h | Total 3.658 h
# [DEBUG][PSO] it 0 p48: centres OK
# [DEBUG][PSO it0 p48] MILP solved:
#    → Truck   1.158 h | Drone 1.754 h | Service 0.833 h | Total 3.746 h
# [DEBUG][PSO] it 0 p49: endurance VIOLATION in cl 1
# [DEBUG][PSO] it 0 p50: centres OK
# [DEBUG][PSO it0 p50] MILP solved:
#    → Truck   1.111 h | Drone 1.719 h | Service 0.833 h | Total 3.663 h
# [DEBUG][PSO] it 0 p51: endurance VIOLATION in cl 4
# [DEBUG][PSO] it 0 p52: centres OK
# [DEBUG][PSO it0 p52] MILP solved:
#    → Truck   1.157 h | Drone 1.732 h | Service 0.833 h | Total 3.722 h
# [DEBUG][PSO] it 0 p53: endurance VIOLATION in cl 4
# [DEBUG][PSO] it 0 p54: centres OK
# [DEBUG][PSO it0 p54] MILP solved:
#    → Truck   1.125 h | Drone 1.449 h | Service 0.833 h | Total 3.407 h
# [DEBUG][PSO] it 0 p55: centres OK
# [DEBUG][PSO it0 p55] MILP solved:
#    → Truck   1.124 h | Drone 1.768 h | Service 0.833 h | Total 3.725 h
# [DEBUG][PSO] it 0 p56: centres OK
# [DEBUG][PSO it0 p56] MILP solved:
#    → Truck   1.090 h | Drone 1.740 h | Service 0.833 h | Total 3.663 h
# [DEBUG][PSO] it 0 p57: centres OK
# [DEBUG][PSO it0 p57] MILP solved:
#    → Truck   1.145 h | Drone 1.789 h | Service 0.833 h | Total 3.768 h
# [DEBUG][PSO] it 0 p58: centres OK
# [DEBUG][PSO it0 p58] MILP solved:
#    → Truck   1.178 h | Drone 1.557 h | Service 0.833 h | Total 3.568 h
# [DEBUG][PSO] it 0 p59: centres OK
# [DEBUG][PSO it0 p59] MILP solved:
#    → Truck   1.220 h | Drone 1.720 h | Service 0.833 h | Total 3.774 h
# [DEBUG][PSO] it 0 p60: centres OK
# [DEBUG][PSO it0 p60] MILP solved:
#    → Truck   1.167 h | Drone 1.745 h | Service 0.833 h | Total 3.745 h
# [DEBUG][PSO] it 0 p61: centres OK
# [DEBUG][PSO it0 p61] MILP solved:
#    → Truck   1.058 h | Drone 1.683 h | Service 0.833 h | Total 3.574 h
# [DEBUG][PSO] it 0 p62: centres OK
# [DEBUG][PSO it0 p62] MILP solved:
#    → Truck   1.034 h | Drone 1.628 h | Service 0.833 h | Total 3.495 h
# [DEBUG][PSO] it 0 p63: endurance VIOLATION in cl 4
# [DEBUG][PSO] it 0 p64: centres OK
# [DEBUG][PSO it0 p64] MILP solved:
#    → Truck   1.237 h | Drone 1.907 h | Service 0.833 h | Total 3.977 h
# [DEBUG][PSO] it 0 p65: centres OK
# [DEBUG][PSO it0 p65] MILP solved:
#    → Truck   1.176 h | Drone 1.565 h | Service 0.833 h | Total 3.575 h
# [DEBUG][PSO] it 0 p66: centres OK
# [DEBUG][PSO it0 p66] MILP solved:
#    → Truck   1.106 h | Drone 1.441 h | Service 0.833 h | Total 3.380 h
# [DEBUG][PSO] it 0 p67: centres OK
# [DEBUG][PSO it0 p67] MILP solved:
#    → Truck   1.176 h | Drone 1.591 h | Service 0.833 h | Total 3.600 h
# [DEBUG][PSO] it 0 p68: centres OK
# [DEBUG][PSO it0 p68] MILP solved:
#    → Truck   1.189 h | Drone 1.682 h | Service 0.833 h | Total 3.704 h
# [DEBUG][PSO] it 0 p69: centres OK
# [DEBUG][PSO it0 p69] MILP solved:
#    → Truck   1.167 h | Drone 1.640 h | Service 0.833 h | Total 3.640 h
# [DEBUG][PSO] it 0 p70: centres OK
# [DEBUG][PSO it0 p70] MILP solved:
#    → Truck   1.177 h | Drone 1.633 h | Service 0.833 h | Total 3.643 h
# [DEBUG][PSO] it 0 p71: centres OK
# [DEBUG][PSO it0 p71] MILP solved:
#    → Truck   1.193 h | Drone 1.644 h | Service 0.833 h | Total 3.670 h
# [DEBUG][PSO] it 0 p72: centres OK
# [DEBUG][PSO it0 p72] MILP solved:
#    → Truck   1.145 h | Drone 1.665 h | Service 0.833 h | Total 3.643 h
# [DEBUG][PSO] it 0 p73: centres OK
# [DEBUG][PSO it0 p73] MILP solved:
#    → Truck   1.121 h | Drone 1.615 h | Service 0.833 h | Total 3.570 h
# [DEBUG][PSO] it 0 p74: centres OK
# [DEBUG][PSO it0 p74] MILP solved:
#    → Truck   1.100 h | Drone 1.843 h | Service 0.833 h | Total 3.776 h
# [DEBUG][PSO] it 0 p75: endurance VIOLATION in cl 0
# [DEBUG][PSO] it 0 p76: centres OK
# [DEBUG][PSO it0 p76] MILP solved:
#    → Truck   1.064 h | Drone 1.671 h | Service 0.833 h | Total 3.568 h
# [DEBUG][PSO] it 0 p77: centres OK
# [DEBUG][PSO it0 p77] MILP solved:
#    → Truck   1.262 h | Drone 1.878 h | Service 0.833 h | Total 3.973 h
# [DEBUG][PSO] it 0 p78: centres OK
# [DEBUG][PSO it0 p78] MILP solved:
#    → Truck   1.052 h | Drone 1.497 h | Service 0.833 h | Total 3.383 h
# [DEBUG][PSO] it 0 p79: centres OK
# [DEBUG][PSO it0 p79] MILP solved:
#    → Truck   1.245 h | Drone 1.728 h | Service 0.833 h | Total 3.806 h
# [DEBUG][PSO] it 0 p80: endurance VIOLATION in cl 0
# [DEBUG][PSO] it 0 p81: centres OK
# [DEBUG][PSO it0 p81] MILP solved:
#    → Truck   1.108 h | Drone 1.719 h | Service 0.833 h | Total 3.660 h
# [DEBUG][PSO] it 0 p82: centres OK
# [DEBUG][PSO it0 p82] MILP solved:
#    → Truck   1.118 h | Drone 1.746 h | Service 0.833 h | Total 3.697 h
# [DEBUG][PSO] it 0 p83: centres OK
# [DEBUG][PSO it0 p83] MILP solved:
#    → Truck   1.199 h | Drone 1.641 h | Service 0.833 h | Total 3.673 h
# [DEBUG][PSO] it 0 p84: centres OK
# [DEBUG][PSO it0 p84] MILP solved:
#    → Truck   1.155 h | Drone 1.735 h | Service 0.833 h | Total 3.723 h
# [DEBUG][PSO] it 0 p85: centres OK
# [DEBUG][PSO it0 p85] MILP solved:
#    → Truck   1.202 h | Drone 1.888 h | Service 0.833 h | Total 3.923 h
# [DEBUG][PSO] it 0 p86: centres OK
# [DEBUG][PSO it0 p86] MILP solved:
#    → Truck   1.138 h | Drone 1.630 h | Service 0.833 h | Total 3.601 h
# [DEBUG][PSO] it 0 p87: centres OK
# [DEBUG][PSO it0 p87] MILP solved:
#    → Truck   1.175 h | Drone 1.726 h | Service 0.833 h | Total 3.735 h
# [DEBUG][PSO] it 0 p88: endurance VIOLATION in cl 4
# [DEBUG][PSO] it 0 p89: centres OK
# [DEBUG][PSO it0 p89] MILP solved:
#    → Truck   1.087 h | Drone 1.659 h | Service 0.833 h | Total 3.579 h
# [DEBUG][PSO] it 0 p90: endurance VIOLATION in cl 1
# [DEBUG][PSO] it 0 p91: endurance VIOLATION in cl 0
# [DEBUG][PSO] it 0 p92: centres OK
# [DEBUG][PSO it0 p92] MILP solved:
#    → Truck   1.106 h | Drone 1.675 h | Service 0.833 h | Total 3.615 h
# [DEBUG][PSO] it 0 p93: centres OK
# [DEBUG][PSO it0 p93] MILP solved:
#    → Truck   1.078 h | Drone 1.626 h | Service 0.833 h | Total 3.537 h
# [DEBUG][PSO] it 0 p94: centres OK
# [DEBUG][PSO it0 p94] MILP solved:
#    → Truck   1.038 h | Drone 1.484 h | Service 0.833 h | Total 3.355 h
# [DEBUG][PSO] it 0 p95: centres OK
# [DEBUG][PSO it0 p95] MILP solved:
#    → Truck   1.186 h | Drone 1.663 h | Service 0.833 h | Total 3.683 h
# [DEBUG][PSO] it 0 p96: centres OK
# [DEBUG][PSO it0 p96] MILP solved:
#    → Truck   1.118 h | Drone 1.744 h | Service 0.833 h | Total 3.695 h
# [DEBUG][PSO] it 0 p97: centres OK
# [DEBUG][PSO it0 p97] MILP solved:
#    → Truck   1.199 h | Drone 1.871 h | Service 0.833 h | Total 3.903 h
# [DEBUG][PSO] it 0 p98: centres OK
# [DEBUG][PSO it0 p98] MILP solved:
#    → Truck   1.137 h | Drone 1.520 h | Service 0.833 h | Total 3.490 h
# [DEBUG][PSO] it 0 p99: centres OK
# [DEBUG][PSO it0 p99] MILP solved:
#    → Truck   1.098 h | Drone 1.555 h | Service 0.833 h | Total 3.487 h
# [DEBUG][PSO] -------------------- iteration 1 ---------------------
# [DEBUG][PSO] it 1 p100: centres OK
# [DEBUG][PSO it1 p100] MILP solved:
#    → Truck   1.197 h | Drone 1.755 h | Service 0.833 h | Total 3.786 h
# [DEBUG][PSO] it 1 p1: centres OK
# [DEBUG][PSO it1 p1] MILP solved:
#    → Truck   1.129 h | Drone 1.602 h | Service 0.833 h | Total 3.564 h
# [DEBUG][PSO] it 1 p2: endurance VIOLATION in cl 1
# [DEBUG][PSO] it 1 p3: centres OK
# [DEBUG][PSO it1 p3] MILP solved:
#    → Truck   1.125 h | Drone 1.635 h | Service 0.833 h | Total 3.593 h
# [DEBUG][PSO] it 1 p4: centres OK
# [DEBUG][PSO it1 p4] MILP solved:
#    → Truck   1.183 h | Drone 1.530 h | Service 0.833 h | Total 3.547 h
# [DEBUG][PSO] it 1 p5: centres OK
# [DEBUG][PSO it1 p5] MILP solved:
#    → Truck   1.143 h | Drone 1.543 h | Service 0.833 h | Total 3.520 h
# [DEBUG][PSO] it 1 p6: centres OK
# [DEBUG][PSO it1 p6] MILP solved:
#    → Truck   1.117 h | Drone 1.702 h | Service 0.833 h | Total 3.653 h
# [DEBUG][PSO] it 1 p7: centres OK
# [DEBUG][PSO it1 p7] MILP solved:
#    → Truck   1.153 h | Drone 1.573 h | Service 0.833 h | Total 3.559 h
# [DEBUG][PSO] it 1 p8: centres OK
# [DEBUG][PSO it1 p8] MILP solved:
#    → Truck   1.161 h | Drone 1.782 h | Service 0.833 h | Total 3.777 h
# [DEBUG][PSO] it 1 p9: centres OK
# [DEBUG][PSO it1 p9] MILP solved:
#    → Truck   1.112 h | Drone 1.456 h | Service 0.833 h | Total 3.401 h
# [DEBUG][PSO] it 1 p10: centres OK
# [DEBUG][PSO it1 p10] MILP solved:
#    → Truck   1.226 h | Drone 1.613 h | Service 0.833 h | Total 3.672 h
# [DEBUG][PSO] it 1 p11: centres OK
# [DEBUG][PSO it1 p11] MILP solved:
#    → Truck   1.279 h | Drone 1.831 h | Service 0.833 h | Total 3.943 h
# [DEBUG][PSO] it 1 p12: centres OK
# [DEBUG][PSO it1 p12] MILP solved:
#    → Truck   1.196 h | Drone 1.635 h | Service 0.833 h | Total 3.664 h
# [DEBUG][PSO] it 1 p13: centres OK
# [DEBUG][PSO it1 p13] MILP solved:
#    → Truck   1.083 h | Drone 1.557 h | Service 0.833 h | Total 3.474 h
# [DEBUG][PSO] it 1 p14: centres OK
# [DEBUG][PSO it1 p14] MILP solved:
#    → Truck   1.094 h | Drone 1.625 h | Service 0.833 h | Total 3.552 h
# [DEBUG][PSO] it 1 p15: endurance VIOLATION in cl 9
# [DEBUG][PSO] it 1 p16: centres OK
# [DEBUG][PSO it1 p16] MILP solved:
#    → Truck   1.066 h | Drone 1.492 h | Service 0.833 h | Total 3.392 h
# [DEBUG][PSO] it 1 p17: centres OK
# [DEBUG][PSO it1 p17] MILP solved:
#    → Truck   1.128 h | Drone 1.673 h | Service 0.833 h | Total 3.634 h
# [DEBUG][PSO] it 1 p18: centres OK
# [DEBUG][PSO it1 p18] MILP solved:
#    → Truck   1.040 h | Drone 1.721 h | Service 0.833 h | Total 3.595 h
# [DEBUG][PSO] it 1 p19: endurance VIOLATION in cl 0
# [DEBUG][PSO] it 1 p20: centres OK
# [DEBUG][PSO it1 p20] MILP solved:
#    → Truck   1.244 h | Drone 1.682 h | Service 0.833 h | Total 3.760 h
# [DEBUG][PSO] it 1 p21: centres OK
# [DEBUG][PSO it1 p21] MILP solved:
#    → Truck   1.181 h | Drone 1.440 h | Service 0.833 h | Total 3.454 h
# [DEBUG][PSO] it 1 p22: centres OK
# [DEBUG][PSO it1 p22] MILP solved:
#    → Truck   1.087 h | Drone 1.551 h | Service 0.833 h | Total 3.471 h
# [DEBUG][PSO] it 1 p23: endurance VIOLATION in cl 4
# [DEBUG][PSO] it 1 p24: endurance VIOLATION in cl 1
# [DEBUG][PSO] it 1 p25: endurance VIOLATION in cl 0
# [DEBUG][PSO] it 1 p26: centres OK
# [DEBUG][PSO it1 p26] MILP solved:
#    → Truck   1.231 h | Drone 1.805 h | Service 0.833 h | Total 3.868 h
# [DEBUG][PSO] it 1 p27: centres OK
# [DEBUG][PSO it1 p27] MILP solved:
#    → Truck   1.115 h | Drone 1.650 h | Service 0.833 h | Total 3.599 h
# [DEBUG][PSO] it 1 p28: centres OK
# [DEBUG][PSO it1 p28] MILP solved:
#    → Truck   1.279 h | Drone 1.633 h | Service 0.833 h | Total 3.745 h
# [DEBUG][PSO] it 1 p29: centres OK
# [DEBUG][PSO it1 p29] MILP solved:
#    → Truck   1.192 h | Drone 1.574 h | Service 0.833 h | Total 3.600 h
# [DEBUG][PSO] it 1 p30: centres OK
# [DEBUG][PSO it1 p30] MILP solved:
#    → Truck   1.217 h | Drone 1.451 h | Service 0.833 h | Total 3.502 h
# [DEBUG][PSO] it 1 p31: centres OK
# [DEBUG][PSO it1 p31] MILP solved:
#    → Truck   0.993 h | Drone 1.726 h | Service 0.833 h | Total 3.552 h
# [DEBUG][PSO] it 1 p32: centres OK
# [DEBUG][PSO it1 p32] MILP solved:
#    → Truck   1.183 h | Drone 1.662 h | Service 0.833 h | Total 3.678 h
# [DEBUG][PSO] it 1 p33: endurance VIOLATION in cl 4
# [DEBUG][PSO] it 1 p34: centres OK
# [DEBUG][PSO it1 p34] MILP solved:
#    → Truck   1.165 h | Drone 1.573 h | Service 0.833 h | Total 3.571 h
# [DEBUG][PSO] it 1 p35: centres OK
# [DEBUG][PSO it1 p35] MILP solved:
#    → Truck   1.234 h | Drone 2.022 h | Service 0.833 h | Total 4.089 h
# [DEBUG][PSO] it 1 p36: centres OK
# [DEBUG][PSO it1 p36] MILP solved:
#    → Truck   1.291 h | Drone 1.657 h | Service 0.833 h | Total 3.781 h
# [DEBUG][PSO] it 1 p37: endurance VIOLATION in cl 4
# [DEBUG][PSO] it 1 p38: centres OK
# [DEBUG][PSO it1 p38] MILP solved:
#    → Truck   1.214 h | Drone 1.782 h | Service 0.833 h | Total 3.829 h
# [DEBUG][PSO] it 1 p39: centres OK
# [DEBUG][PSO it1 p39] MILP solved:
#    → Truck   1.263 h | Drone 1.621 h | Service 0.833 h | Total 3.717 h
# [DEBUG][PSO] it 1 p40: centres OK
# [DEBUG][PSO it1 p40] MILP solved:
#    → Truck   1.122 h | Drone 1.522 h | Service 0.833 h | Total 3.477 h
# [DEBUG][PSO] it 1 p41: centres OK
# [DEBUG][PSO it1 p41] MILP solved:
#    → Truck   1.048 h | Drone 1.650 h | Service 0.833 h | Total 3.531 h
# [DEBUG][PSO] it 1 p42: centres OK
# [DEBUG][PSO it1 p42] MILP solved:
#    → Truck   1.150 h | Drone 1.654 h | Service 0.833 h | Total 3.638 h
# [DEBUG][PSO] it 1 p43: centres OK
# [DEBUG][PSO it1 p43] MILP solved:
#    → Truck   1.090 h | Drone 1.728 h | Service 0.833 h | Total 3.652 h
# [DEBUG][PSO] it 1 p44: centres OK
# [DEBUG][PSO it1 p44] MILP solved:
#    → Truck   1.062 h | Drone 1.660 h | Service 0.833 h | Total 3.556 h
# [DEBUG][PSO] it 1 p45: endurance VIOLATION in cl 1
# [DEBUG][PSO] it 1 p46: endurance VIOLATION in cl 9
# [DEBUG][PSO] it 1 p47: centres OK
# [DEBUG][PSO it1 p47] MILP solved:
#    → Truck   1.224 h | Drone 1.798 h | Service 0.833 h | Total 3.855 h
# [DEBUG][PSO] it 1 p48: centres OK
# [DEBUG][PSO it1 p48] MILP solved:
#    → Truck   1.304 h | Drone 1.700 h | Service 0.833 h | Total 3.838 h
# [DEBUG][PSO] it 1 p49: endurance VIOLATION in cl 0
# [DEBUG][PSO] it 1 p50: endurance VIOLATION in cl 4
# [DEBUG][PSO] it 1 p51: centres OK
# [DEBUG][PSO it1 p51] MILP solved:
#    → Truck   0.994 h | Drone 1.728 h | Service 0.833 h | Total 3.555 h
# [DEBUG][PSO] it 1 p52: endurance VIOLATION in cl 4
# [DEBUG][PSO] it 1 p53: centres OK
# [DEBUG][PSO it1 p53] MILP solved:
#    → Truck   1.168 h | Drone 1.704 h | Service 0.833 h | Total 3.706 h
# [DEBUG][PSO] it 1 p54: endurance VIOLATION in cl 4
# [DEBUG][PSO] it 1 p55: centres OK
# [DEBUG][PSO it1 p55] MILP solved:
#    → Truck   1.183 h | Drone 1.746 h | Service 0.833 h | Total 3.762 h
# [DEBUG][PSO] it 1 p56: centres OK
# [DEBUG][PSO it1 p56] MILP solved:
#    → Truck   1.128 h | Drone 1.760 h | Service 0.833 h | Total 3.721 h
# [DEBUG][PSO] it 1 p57: centres OK
# [DEBUG][PSO it1 p57] MILP solved:
#    → Truck   1.172 h | Drone 1.636 h | Service 0.833 h | Total 3.642 h
# [DEBUG][PSO] it 1 p58: centres OK
# [DEBUG][PSO it1 p58] MILP solved:
#    → Truck   1.308 h | Drone 1.793 h | Service 0.833 h | Total 3.935 h
# [DEBUG][PSO] it 1 p59: centres OK
# [DEBUG][PSO it1 p59] MILP solved:
#    → Truck   1.231 h | Drone 1.516 h | Service 0.833 h | Total 3.580 h
# [DEBUG][PSO] it 1 p60: centres OK
# [DEBUG][PSO it1 p60] MILP solved:
#    → Truck   1.228 h | Drone 1.799 h | Service 0.833 h | Total 3.861 h
# [DEBUG][PSO] it 1 p61: endurance VIOLATION in cl 0
# [DEBUG][PSO] it 1 p62: centres OK
# [DEBUG][PSO it1 p62] MILP solved:
#    → Truck   1.150 h | Drone 1.603 h | Service 0.833 h | Total 3.586 h
# [DEBUG][PSO] it 1 p63: centres OK
# [DEBUG][PSO it1 p63] MILP solved:
#    → Truck   1.003 h | Drone 1.723 h | Service 0.833 h | Total 3.560 h
# [DEBUG][PSO] it 1 p64: centres OK
# [DEBUG][PSO it1 p64] MILP solved:
#    → Truck   1.241 h | Drone 1.655 h | Service 0.833 h | Total 3.729 h
# [DEBUG][PSO] it 1 p65: centres OK
# [DEBUG][PSO it1 p65] MILP solved:
#    → Truck   1.081 h | Drone 1.759 h | Service 0.833 h | Total 3.673 h
# [DEBUG][PSO] it 1 p66: centres OK
# [DEBUG][PSO it1 p66] MILP solved:
#    → Truck   1.055 h | Drone 1.518 h | Service 0.833 h | Total 3.406 h
# [DEBUG][PSO] it 1 p67: centres OK
# [DEBUG][PSO it1 p67] MILP solved:
#    → Truck   1.146 h | Drone 1.518 h | Service 0.833 h | Total 3.497 h
# [DEBUG][PSO] it 1 p68: centres OK
# [DEBUG][PSO it1 p68] MILP solved:
#    → Truck   1.190 h | Drone 1.508 h | Service 0.833 h | Total 3.531 h
# [DEBUG][PSO] it 1 p69: centres OK
# [DEBUG][PSO it1 p69] MILP solved:
#    → Truck   1.065 h | Drone 1.386 h | Service 0.833 h | Total 3.284 h
# [DEBUG][PSO] it 1 p70: endurance VIOLATION in cl 0
# [DEBUG][PSO] it 1 p71: centres OK
# [DEBUG][PSO it1 p71] MILP solved:
#    → Truck   1.161 h | Drone 1.580 h | Service 0.833 h | Total 3.574 h
# [DEBUG][PSO] it 1 p72: endurance VIOLATION in cl 1
# [DEBUG][PSO] it 1 p73: centres OK
# [DEBUG][PSO it1 p73] MILP solved:
#    → Truck   1.074 h | Drone 1.645 h | Service 0.833 h | Total 3.553 h
# [DEBUG][PSO] it 1 p74: centres OK
# [DEBUG][PSO it1 p74] MILP solved:
#    → Truck   1.080 h | Drone 1.499 h | Service 0.833 h | Total 3.413 h
# [DEBUG][PSO] it 1 p75: centres OK
# [DEBUG][PSO it1 p75] MILP solved:
#    → Truck   1.181 h | Drone 1.580 h | Service 0.833 h | Total 3.594 h
# [DEBUG][PSO] it 1 p76: endurance VIOLATION in cl 4
# [DEBUG][PSO] it 1 p77: endurance VIOLATION in cl 4
# [DEBUG][PSO] it 1 p78: centres OK
# [DEBUG][PSO it1 p78] MILP solved:
#    → Truck   1.072 h | Drone 1.655 h | Service 0.833 h | Total 3.560 h
# [DEBUG][PSO] it 1 p79: centres OK
# [DEBUG][PSO it1 p79] MILP solved:
#    → Truck   1.327 h | Drone 1.742 h | Service 0.833 h | Total 3.902 h
# [DEBUG][PSO] it 1 p80: centres OK
# [DEBUG][PSO it1 p80] MILP solved:
#    → Truck   1.144 h | Drone 1.507 h | Service 0.833 h | Total 3.484 h
# [DEBUG][PSO] it 1 p81: endurance VIOLATION in cl 1
# [DEBUG][PSO] it 1 p82: centres OK
# [DEBUG][PSO it1 p82] MILP solved:
#    → Truck   1.116 h | Drone 1.405 h | Service 0.833 h | Total 3.354 h
# [DEBUG][PSO] it 1 p83: centres OK
# [DEBUG][PSO it1 p83] MILP solved:
#    → Truck   1.222 h | Drone 1.772 h | Service 0.833 h | Total 3.827 h
# [DEBUG][PSO] it 1 p84: centres OK
# [DEBUG][PSO it1 p84] MILP solved:
#    → Truck   1.214 h | Drone 1.562 h | Service 0.833 h | Total 3.609 h
# [DEBUG][PSO] it 1 p85: centres OK
# [DEBUG][PSO it1 p85] MILP solved:
#    → Truck   1.174 h | Drone 1.702 h | Service 0.833 h | Total 3.709 h
# [DEBUG][PSO] it 1 p86: centres OK
# [DEBUG][PSO it1 p86] MILP solved:
#    → Truck   1.109 h | Drone 1.739 h | Service 0.833 h | Total 3.682 h
# [DEBUG][PSO] it 1 p87: centres OK
# [DEBUG][PSO it1 p87] MILP solved:
#    → Truck   1.239 h | Drone 1.674 h | Service 0.833 h | Total 3.747 h
# [DEBUG][PSO] it 1 p88: centres OK
# [DEBUG][PSO it1 p88] MILP solved:
#    → Truck   1.263 h | Drone 1.821 h | Service 0.833 h | Total 3.917 h
# [DEBUG][PSO] it 1 p89: centres OK
# [DEBUG][PSO it1 p89] MILP solved:
#    → Truck   1.209 h | Drone 1.826 h | Service 0.833 h | Total 3.868 h
# [DEBUG][PSO] it 1 p90: centres OK
# [DEBUG][PSO it1 p90] MILP solved:
#    → Truck   0.986 h | Drone 1.533 h | Service 0.833 h | Total 3.352 h
# [DEBUG][PSO] it 1 p91: centres OK
# [DEBUG][PSO it1 p91] MILP solved:
#    → Truck   1.314 h | Drone 1.847 h | Service 0.833 h | Total 3.994 h
# [DEBUG][PSO] it 1 p92: centres OK
# [DEBUG][PSO it1 p92] MILP solved:
#    → Truck   1.120 h | Drone 1.627 h | Service 0.833 h | Total 3.581 h
# [DEBUG][PSO] it 1 p93: centres OK
# [DEBUG][PSO it1 p93] MILP solved:
#    → Truck   1.198 h | Drone 1.587 h | Service 0.833 h | Total 3.618 h
# [DEBUG][PSO] it 1 p94: centres OK
# [DEBUG][PSO it1 p94] MILP solved:
#    → Truck   1.125 h | Drone 1.662 h | Service 0.833 h | Total 3.621 h
# [DEBUG][PSO] it 1 p95: centres OK
# [DEBUG][PSO it1 p95] MILP solved:
#    → Truck   1.024 h | Drone 1.688 h | Service 0.833 h | Total 3.546 h
# [DEBUG][PSO] it 1 p96: centres OK
# [DEBUG][PSO it1 p96] MILP solved:
#    → Truck   1.179 h | Drone 1.645 h | Service 0.833 h | Total 3.658 h
# [DEBUG][PSO] it 1 p97: centres OK
# [DEBUG][PSO it1 p97] MILP solved:
#    → Truck   1.291 h | Drone 1.756 h | Service 0.833 h | Total 3.880 h
# [DEBUG][PSO] it 1 p98: centres OK
# [DEBUG][PSO it1 p98] MILP solved:
#    → Truck   1.142 h | Drone 1.634 h | Service 0.833 h | Total 3.610 h
# [DEBUG][PSO] it 1 p99: centres OK
# [DEBUG][PSO it1 p99] MILP solved:
#    → Truck   1.110 h | Drone 1.730 h | Service 0.833 h | Total 3.673 h
# [DEBUG][PSO] -------------------- iteration 2 ---------------------
# [DEBUG][PSO] it 2 p100: centres OK
# [DEBUG][PSO it2 p100] MILP solved:
#    → Truck   1.212 h | Drone 1.819 h | Service 0.833 h | Total 3.864 h
# [DEBUG][PSO] it 2 p1: centres OK
# [DEBUG][PSO it2 p1] MILP solved:
#    → Truck   1.073 h | Drone 1.551 h | Service 0.833 h | Total 3.457 h
# [DEBUG][PSO] it 2 p2: centres OK
# [DEBUG][PSO it2 p2] MILP solved:
#    → Truck   1.110 h | Drone 1.452 h | Service 0.833 h | Total 3.395 h
# [DEBUG][PSO] it 2 p3: centres OK
# [DEBUG][PSO it2 p3] MILP solved:
#    → Truck   1.074 h | Drone 1.633 h | Service 0.833 h | Total 3.540 h
# [DEBUG][PSO] it 2 p4: centres OK
# [DEBUG][PSO it2 p4] MILP solved:
#    → Truck   1.186 h | Drone 1.526 h | Service 0.833 h | Total 3.546 h
# [DEBUG][PSO] it 2 p5: centres OK
# [DEBUG][PSO it2 p5] MILP solved:
#    → Truck   1.093 h | Drone 1.594 h | Service 0.833 h | Total 3.521 h
# [DEBUG][PSO] it 2 p6: centres OK
# [DEBUG][PSO it2 p6] MILP solved:
#    → Truck   1.136 h | Drone 1.620 h | Service 0.833 h | Total 3.590 h
# [DEBUG][PSO] it 2 p7: centres OK
# [DEBUG][PSO it2 p7] MILP solved:
#    → Truck   1.202 h | Drone 1.524 h | Service 0.833 h | Total 3.560 h
# [DEBUG][PSO] it 2 p8: centres OK
# [DEBUG][PSO it2 p8] MILP solved:
#    → Truck   1.136 h | Drone 1.845 h | Service 0.833 h | Total 3.815 h
# [DEBUG][PSO] it 2 p9: centres OK
# [DEBUG][PSO it2 p9] MILP solved:
#    → Truck   1.146 h | Drone 1.468 h | Service 0.833 h | Total 3.447 h
# [DEBUG][PSO] it 2 p10: centres OK
# [DEBUG][PSO it2 p10] MILP solved:
#    → Truck   1.196 h | Drone 1.607 h | Service 0.833 h | Total 3.636 h
# [DEBUG][PSO] it 2 p11: centres OK
# [DEBUG][PSO it2 p11] MILP solved:
#    → Truck   1.272 h | Drone 1.828 h | Service 0.833 h | Total 3.933 h
# [DEBUG][PSO] it 2 p12: centres OK
# [DEBUG][PSO it2 p12] MILP solved:
#    → Truck   1.119 h | Drone 1.643 h | Service 0.833 h | Total 3.595 h
# [DEBUG][PSO] it 2 p13: centres OK
# [DEBUG][PSO it2 p13] MILP solved:
#    → Truck   1.062 h | Drone 1.626 h | Service 0.833 h | Total 3.521 h
# [DEBUG][PSO] it 2 p14: centres OK
# [DEBUG][PSO it2 p14] MILP solved:
#    → Truck   1.120 h | Drone 1.588 h | Service 0.833 h | Total 3.542 h
# [DEBUG][PSO] it 2 p15: centres OK
# [DEBUG][PSO it2 p15] MILP solved:
#    → Truck   1.099 h | Drone 1.660 h | Service 0.833 h | Total 3.592 h
# [DEBUG][PSO] it 2 p16: centres OK
# [DEBUG][PSO it2 p16] MILP solved:
#    → Truck   1.052 h | Drone 1.415 h | Service 0.833 h | Total 3.300 h
# [DEBUG][PSO] it 2 p17: centres OK
# [DEBUG][PSO it2 p17] MILP solved:
#    → Truck   1.116 h | Drone 1.659 h | Service 0.833 h | Total 3.608 h
# [DEBUG][PSO] it 2 p18: centres OK
# [DEBUG][PSO it2 p18] MILP solved:
#    → Truck   1.102 h | Drone 1.847 h | Service 0.833 h | Total 3.781 h
# [DEBUG][PSO] it 2 p19: endurance VIOLATION in cl 3
# [DEBUG][PSO] it 2 p20: centres OK
# [DEBUG][PSO it2 p20] MILP solved:
#    → Truck   1.273 h | Drone 1.744 h | Service 0.833 h | Total 3.850 h
# [DEBUG][PSO] it 2 p21: centres OK
# [DEBUG][PSO it2 p21] MILP solved:
#    → Truck   1.147 h | Drone 1.497 h | Service 0.833 h | Total 3.477 h
# [DEBUG][PSO] it 2 p22: endurance VIOLATION in cl 0
# [DEBUG][PSO] it 2 p23: endurance VIOLATION in cl 4
# [DEBUG][PSO] it 2 p24: endurance VIOLATION in cl 1
# [DEBUG][PSO] it 2 p25: centres OK
# [DEBUG][PSO it2 p25] MILP solved:
#    → Truck   1.093 h | Drone 1.468 h | Service 0.833 h | Total 3.395 h
# [DEBUG][PSO] it 2 p26: centres OK
# [DEBUG][PSO it2 p26] MILP solved:
#    → Truck   1.234 h | Drone 1.817 h | Service 0.833 h | Total 3.884 h
# [DEBUG][PSO] it 2 p27: centres OK
# [DEBUG][PSO it2 p27] MILP solved:
#    → Truck   1.099 h | Drone 1.677 h | Service 0.833 h | Total 3.610 h
# [DEBUG][PSO] it 2 p28: centres OK
# [DEBUG][PSO it2 p28] MILP solved:
#    → Truck   1.242 h | Drone 1.686 h | Service 0.833 h | Total 3.761 h
# [DEBUG][PSO] it 2 p29: centres OK
# [DEBUG][PSO it2 p29] MILP solved:
#    → Truck   1.161 h | Drone 1.576 h | Service 0.833 h | Total 3.571 h
# [DEBUG][PSO] it 2 p30: centres OK
# [DEBUG][PSO it2 p30] MILP solved:
#    → Truck   1.200 h | Drone 1.630 h | Service 0.833 h | Total 3.663 h
# [DEBUG][PSO] it 2 p31: centres OK
# [DEBUG][PSO it2 p31] MILP solved:
#    → Truck   1.000 h | Drone 1.666 h | Service 0.833 h | Total 3.500 h
# [DEBUG][PSO] it 2 p32: centres OK
# [DEBUG][PSO it2 p32] MILP solved:
#    → Truck   1.227 h | Drone 1.608 h | Service 0.833 h | Total 3.668 h
# [DEBUG][PSO] it 2 p33: endurance VIOLATION in cl 4
# [DEBUG][PSO] it 2 p34: centres OK
# [DEBUG][PSO it2 p34] MILP solved:
#    → Truck   1.157 h | Drone 1.571 h | Service 0.833 h | Total 3.561 h
# [DEBUG][PSO] it 2 p35: centres OK
# [DEBUG][PSO it2 p35] MILP solved:
#    → Truck   1.199 h | Drone 1.969 h | Service 0.833 h | Total 4.002 h
# [DEBUG][PSO] it 2 p36: centres OK
# [DEBUG][PSO it2 p36] MILP solved:
#    → Truck   1.245 h | Drone 1.644 h | Service 0.833 h | Total 3.723 h
# [DEBUG][PSO] it 2 p37: centres OK
# [DEBUG][PSO it2 p37] MILP solved:
#    → Truck   1.123 h | Drone 1.799 h | Service 0.833 h | Total 3.755 h
# [DEBUG][PSO] it 2 p38: centres OK
# [DEBUG][PSO it2 p38] MILP solved:
#    → Truck   1.230 h | Drone 1.755 h | Service 0.833 h | Total 3.818 h
# [DEBUG][PSO] it 2 p39: centres OK
# [DEBUG][PSO it2 p39] MILP solved:
#    → Truck   1.291 h | Drone 1.667 h | Service 0.833 h | Total 3.791 h
# [DEBUG][PSO] it 2 p40: centres OK
# [DEBUG][PSO it2 p40] MILP solved:
#    → Truck   1.106 h | Drone 1.538 h | Service 0.833 h | Total 3.478 h
# [DEBUG][PSO] it 2 p41: centres OK
# [DEBUG][PSO it2 p41] MILP solved:
#    → Truck   1.074 h | Drone 1.592 h | Service 0.833 h | Total 3.500 h
# [DEBUG][PSO] it 2 p42: centres OK
# [DEBUG][PSO it2 p42] MILP solved:
#    → Truck   1.092 h | Drone 1.655 h | Service 0.833 h | Total 3.580 h
# [DEBUG][PSO] it 2 p43: centres OK
# [DEBUG][PSO it2 p43] MILP solved:
#    → Truck   1.083 h | Drone 1.578 h | Service 0.833 h | Total 3.494 h
# [DEBUG][PSO] it 2 p44: centres OK
# [DEBUG][PSO it2 p44] MILP solved:
#    → Truck   1.030 h | Drone 1.631 h | Service 0.833 h | Total 3.494 h
# [DEBUG][PSO] it 2 p45: endurance VIOLATION in cl 1
# [DEBUG][PSO] it 2 p46: centres OK
# [DEBUG][PSO it2 p46] MILP solved:
#    → Truck   1.100 h | Drone 1.531 h | Service 0.833 h | Total 3.464 h
# [DEBUG][PSO] it 2 p47: centres OK
# [DEBUG][PSO it2 p47] MILP solved:
#    → Truck   1.174 h | Drone 1.541 h | Service 0.833 h | Total 3.548 h
# [DEBUG][PSO] it 2 p48: centres OK
# [DEBUG][PSO it2 p48] MILP solved:
#    → Truck   1.282 h | Drone 1.754 h | Service 0.833 h | Total 3.869 h
# [DEBUG][PSO] it 2 p49: centres OK
# [DEBUG][PSO it2 p49] MILP solved:
#    → Truck   1.077 h | Drone 1.714 h | Service 0.833 h | Total 3.625 h
# [DEBUG][PSO] it 2 p50: centres OK
# [DEBUG][PSO it2 p50] MILP solved:
#    → Truck   1.123 h | Drone 1.725 h | Service 0.833 h | Total 3.680 h
# [DEBUG][PSO] it 2 p51: centres OK
# [DEBUG][PSO it2 p51] MILP solved:
#    → Truck   0.956 h | Drone 1.637 h | Service 0.833 h | Total 3.427 h
# [DEBUG][PSO] it 2 p52: centres OK
# [DEBUG][PSO it2 p52] MILP solved:
#    → Truck   1.136 h | Drone 1.288 h | Service 0.833 h | Total 3.257 h
# [DEBUG][PSO] it 2 p53: centres OK
# [DEBUG][PSO it2 p53] MILP solved:
#    → Truck   1.152 h | Drone 1.488 h | Service 0.833 h | Total 3.473 h
# [DEBUG][PSO] it 2 p54: endurance VIOLATION in cl 4
# [DEBUG][PSO] it 2 p55: centres OK
# [DEBUG][PSO it2 p55] MILP solved:
#    → Truck   1.161 h | Drone 1.799 h | Service 0.833 h | Total 3.794 h
# [DEBUG][PSO] it 2 p56: centres OK
# [DEBUG][PSO it2 p56] MILP solved:
#    → Truck   1.166 h | Drone 1.731 h | Service 0.833 h | Total 3.730 h
# [DEBUG][PSO] it 2 p57: endurance VIOLATION in cl 9
# [DEBUG][PSO] it 2 p58: centres OK
# [DEBUG][PSO it2 p58] MILP solved:
#    → Truck   1.262 h | Drone 1.651 h | Service 0.833 h | Total 3.747 h
# [DEBUG][PSO] it 2 p59: centres OK
# [DEBUG][PSO it2 p59] MILP solved:
#    → Truck   1.226 h | Drone 1.523 h | Service 0.833 h | Total 3.582 h
# [DEBUG][PSO] it 2 p60: centres OK
# [DEBUG][PSO it2 p60] MILP solved:
#    → Truck   1.205 h | Drone 1.747 h | Service 0.833 h | Total 3.785 h
# [DEBUG][PSO] it 2 p61: endurance VIOLATION in cl 0
# [DEBUG][PSO] it 2 p62: centres OK
# [DEBUG][PSO it2 p62] MILP solved:
#    → Truck   1.225 h | Drone 1.590 h | Service 0.833 h | Total 3.648 h
# [DEBUG][PSO] it 2 p63: centres OK
# [DEBUG][PSO it2 p63] MILP solved:
#    → Truck   1.003 h | Drone 1.707 h | Service 0.833 h | Total 3.544 h
# [DEBUG][PSO] it 2 p64: centres OK
# [DEBUG][PSO it2 p64] MILP solved:
#    → Truck   1.167 h | Drone 1.583 h | Service 0.833 h | Total 3.584 h
# [DEBUG][PSO] it 2 p65: endurance VIOLATION in cl 4
# [DEBUG][PSO] it 2 p66: centres OK
# [DEBUG][PSO it2 p66] MILP solved:
#    → Truck   1.053 h | Drone 1.541 h | Service 0.833 h | Total 3.428 h
# [DEBUG][PSO] it 2 p67: centres OK
# [DEBUG][PSO it2 p67] MILP solved:
#    → Truck   1.140 h | Drone 1.666 h | Service 0.833 h | Total 3.640 h
# [DEBUG][PSO] it 2 p68: centres OK
# [DEBUG][PSO it2 p68] MILP solved:
#    → Truck   1.199 h | Drone 1.437 h | Service 0.833 h | Total 3.470 h
# [DEBUG][PSO] it 2 p69: centres OK
# [DEBUG][PSO it2 p69] MILP solved:
#    → Truck   1.043 h | Drone 1.523 h | Service 0.833 h | Total 3.400 h
# [DEBUG][PSO] it 2 p70: endurance VIOLATION in cl 0
# [DEBUG][PSO] it 2 p71: centres OK
# [DEBUG][PSO it2 p71] MILP solved:
#    → Truck   1.166 h | Drone 1.670 h | Service 0.833 h | Total 3.669 h
# [DEBUG][PSO] it 2 p72: endurance VIOLATION in cl 1
# [DEBUG][PSO] it 2 p73: centres OK
# [DEBUG][PSO it2 p73] MILP solved:
#    → Truck   1.078 h | Drone 1.475 h | Service 0.833 h | Total 3.386 h
# [DEBUG][PSO] it 2 p74: centres OK
# [DEBUG][PSO it2 p74] MILP solved:
#    → Truck   1.120 h | Drone 1.593 h | Service 0.833 h | Total 3.547 h
# [DEBUG][PSO] it 2 p75: centres OK
# [DEBUG][PSO it2 p75] MILP solved:
#    → Truck   1.236 h | Drone 1.606 h | Service 0.833 h | Total 3.675 h
# [DEBUG][PSO] it 2 p76: endurance VIOLATION in cl 4
# [DEBUG][PSO] it 2 p77: endurance VIOLATION in cl 4
# [DEBUG][PSO] it 2 p78: centres OK
# [DEBUG][PSO it2 p78] MILP solved:
#    → Truck   1.092 h | Drone 1.610 h | Service 0.833 h | Total 3.535 h
# [DEBUG][PSO] it 2 p79: centres OK
# [DEBUG][PSO it2 p79] MILP solved:
#    → Truck   1.272 h | Drone 1.703 h | Service 0.833 h | Total 3.808 h
# [DEBUG][PSO] it 2 p80: centres OK
# [DEBUG][PSO it2 p80] MILP solved:
#    → Truck   1.132 h | Drone 1.558 h | Service 0.833 h | Total 3.523 h
# [DEBUG][PSO] it 2 p81: endurance VIOLATION in cl 1
# [DEBUG][PSO] it 2 p82: endurance VIOLATION in cl 4
# [DEBUG][PSO] it 2 p83: centres OK
# [DEBUG][PSO it2 p83] MILP solved:
#    → Truck   1.216 h | Drone 1.729 h | Service 0.833 h | Total 3.778 h
# [DEBUG][PSO] it 2 p84: centres OK
# [DEBUG][PSO it2 p84] MILP solved:
#    → Truck   1.284 h | Drone 1.610 h | Service 0.833 h | Total 3.727 h
# [DEBUG][PSO] it 2 p85: centres OK
# [DEBUG][PSO it2 p85] MILP solved:
#    → Truck   1.160 h | Drone 1.731 h | Service 0.833 h | Total 3.724 h
# [DEBUG][PSO] it 2 p86: centres OK
# [DEBUG][PSO it2 p86] MILP solved:
#    → Truck   1.088 h | Drone 1.657 h | Service 0.833 h | Total 3.578 h
# [DEBUG][PSO] it 2 p87: centres OK
# [DEBUG][PSO it2 p87] MILP solved:
#    → Truck   1.260 h | Drone 1.700 h | Service 0.833 h | Total 3.794 h
# [DEBUG][PSO] it 2 p88: centres OK
# [DEBUG][PSO it2 p88] MILP solved:
#    → Truck   1.268 h | Drone 1.746 h | Service 0.833 h | Total 3.847 h
# [DEBUG][PSO] it 2 p89: centres OK
# [DEBUG][PSO it2 p89] MILP solved:
#    → Truck   1.220 h | Drone 1.887 h | Service 0.833 h | Total 3.940 h
# [DEBUG][PSO] it 2 p90: centres OK
# [DEBUG][PSO it2 p90] MILP solved:
#    → Truck   1.018 h | Drone 1.638 h | Service 0.833 h | Total 3.489 h
# [DEBUG][PSO] it 2 p91: centres OK
# [DEBUG][PSO it2 p91] MILP solved:
#    → Truck   1.285 h | Drone 1.621 h | Service 0.833 h | Total 3.740 h
# [DEBUG][PSO] it 2 p92: centres OK
# [DEBUG][PSO it2 p92] MILP solved:
#    → Truck   1.126 h | Drone 1.684 h | Service 0.833 h | Total 3.643 h
# [DEBUG][PSO] it 2 p93: endurance VIOLATION in cl 0
# [DEBUG][PSO] it 2 p94: centres OK
# [DEBUG][PSO it2 p94] MILP solved:
#    → Truck   1.131 h | Drone 1.717 h | Service 0.833 h | Total 3.681 h
# [DEBUG][PSO] it 2 p95: centres OK
# [DEBUG][PSO it2 p95] MILP solved:
#    → Truck   1.025 h | Drone 1.544 h | Service 0.833 h | Total 3.403 h
# [DEBUG][PSO] it 2 p96: centres OK
# [DEBUG][PSO it2 p96] MILP solved:
#    → Truck   1.221 h | Drone 1.713 h | Service 0.833 h | Total 3.767 h
# [DEBUG][PSO] it 2 p97: centres OK
# [DEBUG][PSO it2 p97] MILP solved:
#    → Truck   1.281 h | Drone 1.767 h | Service 0.833 h | Total 3.882 h
# [DEBUG][PSO] it 2 p98: centres OK
# [DEBUG][PSO it2 p98] MILP solved:
#    → Truck   1.087 h | Drone 1.691 h | Service 0.833 h | Total 3.610 h
# [DEBUG][PSO] it 2 p99: centres OK
# [DEBUG][PSO it2 p99] MILP solved:
#    → Truck   1.080 h | Drone 1.580 h | Service 0.833 h | Total 3.493 h
# [DEBUG][PSO] -------------------- iteration 3 ---------------------
# [DEBUG][PSO] it 3 p100: centres OK
# [DEBUG][PSO it3 p100] MILP solved:
#    → Truck   1.215 h | Drone 1.818 h | Service 0.833 h | Total 3.867 h
# [DEBUG][PSO] it 3 p1: centres OK
# [DEBUG][PSO it3 p1] MILP solved:
#    → Truck   1.094 h | Drone 1.302 h | Service 0.833 h | Total 3.229 h
# [DEBUG][PSO] it 3 p2: centres OK
# [DEBUG][PSO it3 p2] MILP solved:
#    → Truck   1.100 h | Drone 1.578 h | Service 0.833 h | Total 3.512 h
# [DEBUG][PSO] it 3 p3: centres OK
# [DEBUG][PSO it3 p3] MILP solved:
#    → Truck   1.030 h | Drone 1.615 h | Service 0.833 h | Total 3.478 h
# [DEBUG][PSO] it 3 p4: centres OK
# [DEBUG][PSO it3 p4] MILP solved:
#    → Truck   1.135 h | Drone 1.406 h | Service 0.833 h | Total 3.374 h
# [DEBUG][PSO] it 3 p5: centres OK
# [DEBUG][PSO it3 p5] MILP solved:
#    → Truck   1.078 h | Drone 1.479 h | Service 0.833 h | Total 3.390 h
# [DEBUG][PSO] it 3 p6: centres OK
# [DEBUG][PSO it3 p6] MILP solved:
#    → Truck   1.062 h | Drone 1.608 h | Service 0.833 h | Total 3.503 h
# [DEBUG][PSO] it 3 p7: centres OK
# [DEBUG][PSO it3 p7] MILP solved:
#    → Truck   1.174 h | Drone 1.675 h | Service 0.833 h | Total 3.682 h
# [DEBUG][PSO] it 3 p8: centres OK
# [DEBUG][PSO it3 p8] MILP solved:
#    → Truck   1.122 h | Drone 1.676 h | Service 0.833 h | Total 3.631 h
# [DEBUG][PSO] it 3 p9: centres OK
# [DEBUG][PSO it3 p9] MILP solved:
#    → Truck   1.133 h | Drone 1.575 h | Service 0.833 h | Total 3.541 h
# [DEBUG][PSO] it 3 p10: centres OK
# [DEBUG][PSO it3 p10] MILP solved:
#    → Truck   1.101 h | Drone 1.672 h | Service 0.833 h | Total 3.606 h
# [DEBUG][PSO] it 3 p11: centres OK
# [DEBUG][PSO it3 p11] MILP solved:
#    → Truck   1.140 h | Drone 1.614 h | Service 0.833 h | Total 3.587 h
# [DEBUG][PSO] it 3 p12: centres OK
# [DEBUG][PSO it3 p12] MILP solved:
#    → Truck   1.056 h | Drone 1.666 h | Service 0.833 h | Total 3.556 h
# [DEBUG][PSO] it 3 p13: centres OK
# [DEBUG][PSO it3 p13] MILP solved:
#    → Truck   1.031 h | Drone 1.605 h | Service 0.833 h | Total 3.470 h
# [DEBUG][PSO] it 3 p14: centres OK
# [DEBUG][PSO it3 p14] MILP solved:
#    → Truck   1.118 h | Drone 1.522 h | Service 0.833 h | Total 3.473 h
# [DEBUG][PSO] it 3 p15: centres OK
# [DEBUG][PSO it3 p15] MILP solved:
#    → Truck   1.078 h | Drone 1.316 h | Service 0.833 h | Total 3.228 h
# [DEBUG][PSO] it 3 p16: centres OK
# [DEBUG][PSO it3 p16] MILP solved:
#    → Truck   1.049 h | Drone 1.565 h | Service 0.833 h | Total 3.447 h
# [DEBUG][PSO] it 3 p17: centres OK
# [DEBUG][PSO it3 p17] MILP solved:
#    → Truck   1.097 h | Drone 1.659 h | Service 0.833 h | Total 3.590 h
# [DEBUG][PSO] it 3 p18: centres OK
# [DEBUG][PSO it3 p18] MILP solved:
#    → Truck   1.100 h | Drone 1.739 h | Service 0.833 h | Total 3.673 h
# [DEBUG][PSO] it 3 p19: centres OK
# [DEBUG][PSO it3 p19] MILP solved:
#    → Truck   1.089 h | Drone 1.420 h | Service 0.833 h | Total 3.342 h
# [DEBUG][PSO] it 3 p20: centres OK
# [DEBUG][PSO it3 p20] MILP solved:
#    → Truck   1.213 h | Drone 1.734 h | Service 0.833 h | Total 3.781 h
# [DEBUG][PSO] it 3 p21: centres OK
# [DEBUG][PSO it3 p21] MILP solved:
#    → Truck   1.111 h | Drone 1.503 h | Service 0.833 h | Total 3.448 h
# [DEBUG][PSO] it 3 p22: centres OK
# [DEBUG][PSO it3 p22] MILP solved:
#    → Truck   1.060 h | Drone 1.506 h | Service 0.833 h | Total 3.399 h
# [DEBUG][PSO] it 3 p23: centres OK
# [DEBUG][PSO it3 p23] MILP solved:
#    → Truck   1.125 h | Drone 1.405 h | Service 0.833 h | Total 3.363 h
# [DEBUG][PSO] it 3 p24: centres OK
# [DEBUG][PSO it3 p24] MILP solved:
#    → Truck   1.194 h | Drone 1.655 h | Service 0.833 h | Total 3.683 h
# [DEBUG][PSO] it 3 p25: centres OK
# [DEBUG][PSO it3 p25] MILP solved:
#    → Truck   1.039 h | Drone 1.486 h | Service 0.833 h | Total 3.358 h
# [DEBUG][PSO] it 3 p26: centres OK
# [DEBUG][PSO it3 p26] MILP solved:
#    → Truck   1.114 h | Drone 1.673 h | Service 0.833 h | Total 3.620 h
# [DEBUG][PSO] it 3 p27: centres OK
# [DEBUG][PSO it3 p27] MILP solved:
#    → Truck   1.076 h | Drone 1.702 h | Service 0.833 h | Total 3.611 h
# [DEBUG][PSO] it 3 p28: centres OK
# [DEBUG][PSO it3 p28] MILP solved:
#    → Truck   1.182 h | Drone 1.681 h | Service 0.833 h | Total 3.696 h
# [DEBUG][PSO] it 3 p29: centres OK
# [DEBUG][PSO it3 p29] MILP solved:
#    → Truck   1.093 h | Drone 1.582 h | Service 0.833 h | Total 3.508 h
# [DEBUG][PSO] it 3 p30: centres OK
# [DEBUG][PSO it3 p30] MILP solved:
#    → Truck   1.125 h | Drone 1.467 h | Service 0.833 h | Total 3.426 h
# [DEBUG][PSO] it 3 p31: centres OK
# [DEBUG][PSO it3 p31] MILP solved:
#    → Truck   0.983 h | Drone 1.672 h | Service 0.833 h | Total 3.488 h
# [DEBUG][PSO] it 3 p32: centres OK
# [DEBUG][PSO it3 p32] MILP solved:
#    → Truck   1.145 h | Drone 1.550 h | Service 0.833 h | Total 3.528 h
# [DEBUG][PSO] it 3 p33: centres OK
# [DEBUG][PSO it3 p33] MILP solved:
#    → Truck   1.159 h | Drone 1.480 h | Service 0.833 h | Total 3.472 h
# [DEBUG][PSO] it 3 p34: centres OK
# [DEBUG][PSO it3 p34] MILP solved:
#    → Truck   1.087 h | Drone 1.596 h | Service 0.833 h | Total 3.517 h
# [DEBUG][PSO] it 3 p35: centres OK
# [DEBUG][PSO it3 p35] MILP solved:
#    → Truck   1.150 h | Drone 1.859 h | Service 0.833 h | Total 3.843 h
# [DEBUG][PSO] it 3 p36: centres OK
# [DEBUG][PSO it3 p36] MILP solved:
#    → Truck   1.212 h | Drone 1.594 h | Service 0.833 h | Total 3.639 h
# [DEBUG][PSO] it 3 p37: centres OK
# [DEBUG][PSO it3 p37] MILP solved:
#    → Truck   1.094 h | Drone 1.563 h | Service 0.833 h | Total 3.490 h
# [DEBUG][PSO] it 3 p38: centres OK
# [DEBUG][PSO it3 p38] MILP solved:
#    → Truck   1.129 h | Drone 1.649 h | Service 0.833 h | Total 3.612 h
# [DEBUG][PSO] it 3 p39: centres OK
# [DEBUG][PSO it3 p39] MILP solved:
#    → Truck   1.195 h | Drone 1.382 h | Service 0.833 h | Total 3.411 h
# [DEBUG][PSO] it 3 p40: centres OK
# [DEBUG][PSO it3 p40] MILP solved:
#    → Truck   1.118 h | Drone 1.563 h | Service 0.833 h | Total 3.514 h
# [DEBUG][PSO] it 3 p41: centres OK
# [DEBUG][PSO it3 p41] MILP solved:
#    → Truck   1.060 h | Drone 1.598 h | Service 0.833 h | Total 3.491 h
# [DEBUG][PSO] it 3 p42: centres OK
# [DEBUG][PSO it3 p42] MILP solved:
#    → Truck   1.040 h | Drone 1.509 h | Service 0.833 h | Total 3.382 h
# [DEBUG][PSO] it 3 p43: centres OK
# [DEBUG][PSO it3 p43] MILP solved:
#    → Truck   1.059 h | Drone 1.547 h | Service 0.833 h | Total 3.440 h
# [DEBUG][PSO] it 3 p44: centres OK
# [DEBUG][PSO it3 p44] MILP solved:
#    → Truck   0.980 h | Drone 1.671 h | Service 0.833 h | Total 3.484 h
# [DEBUG][PSO] it 3 p45: centres OK
# [DEBUG][PSO it3 p45] MILP solved:
#    → Truck   1.138 h | Drone 1.800 h | Service 0.833 h | Total 3.771 h
# [DEBUG][PSO] it 3 p46: centres OK
# [DEBUG][PSO it3 p46] MILP solved:
#    → Truck   1.086 h | Drone 1.495 h | Service 0.833 h | Total 3.414 h
# [DEBUG][PSO] it 3 p47: centres OK
# [DEBUG][PSO it3 p47] MILP solved:
#    → Truck   1.105 h | Drone 1.554 h | Service 0.833 h | Total 3.492 h
# [DEBUG][PSO] it 3 p48: centres OK
# [DEBUG][PSO it3 p48] MILP solved:
#    → Truck   1.206 h | Drone 1.366 h | Service 0.833 h | Total 3.405 h
# [DEBUG][PSO] it 3 p49: centres OK
# [DEBUG][PSO it3 p49] MILP solved:
#    → Truck   1.068 h | Drone 1.597 h | Service 0.833 h | Total 3.498 h
# [DEBUG][PSO] it 3 p50: centres OK
# [DEBUG][PSO it3 p50] MILP solved:
#    → Truck   1.062 h | Drone 1.545 h | Service 0.833 h | Total 3.440 h
# [DEBUG][PSO] it 3 p51: centres OK
# [DEBUG][PSO it3 p51] MILP solved:
#    → Truck   0.975 h | Drone 1.648 h | Service 0.833 h | Total 3.457 h
# [DEBUG][PSO] it 3 p52: centres OK
# [DEBUG][PSO it3 p52] MILP solved:
#    → Truck   1.135 h | Drone 1.441 h | Service 0.833 h | Total 3.409 h
# [DEBUG][PSO] it 3 p53: centres OK
# [DEBUG][PSO it3 p53] MILP solved:
#    → Truck   1.105 h | Drone 1.530 h | Service 0.833 h | Total 3.468 h
# [DEBUG][PSO] it 3 p54: centres OK
# [DEBUG][PSO it3 p54] MILP solved:
#    → Truck   1.093 h | Drone 1.494 h | Service 0.833 h | Total 3.420 h
# [DEBUG][PSO] it 3 p55: centres OK
# [DEBUG][PSO it3 p55] MILP solved:
#    → Truck   1.103 h | Drone 1.761 h | Service 0.833 h | Total 3.698 h
# [DEBUG][PSO] it 3 p56: centres OK
# [DEBUG][PSO it3 p56] MILP solved:
#    → Truck   1.154 h | Drone 1.599 h | Service 0.833 h | Total 3.587 h
# [DEBUG][PSO] it 3 p57: endurance VIOLATION in cl 9
# [DEBUG][PSO] it 3 p58: centres OK
# [DEBUG][PSO it3 p58] MILP solved:
#    → Truck   1.127 h | Drone 1.548 h | Service 0.833 h | Total 3.508 h
# [DEBUG][PSO] it 3 p59: centres OK
# [DEBUG][PSO it3 p59] MILP solved:
#    → Truck   1.209 h | Drone 1.452 h | Service 0.833 h | Total 3.494 h
# [DEBUG][PSO] it 3 p60: centres OK
# [DEBUG][PSO it3 p60] MILP solved:
#    → Truck   1.150 h | Drone 1.753 h | Service 0.833 h | Total 3.736 h
# [DEBUG][PSO] it 3 p61: centres OK
# [DEBUG][PSO it3 p61] MILP solved:
#    → Truck   1.057 h | Drone 1.721 h | Service 0.833 h | Total 3.612 h
# [DEBUG][PSO] it 3 p62: centres OK
# [DEBUG][PSO it3 p62] MILP solved:
#    → Truck   1.145 h | Drone 1.618 h | Service 0.833 h | Total 3.596 h
# [DEBUG][PSO] it 3 p63: centres OK
# [DEBUG][PSO it3 p63] MILP solved:
#    → Truck   1.026 h | Drone 1.706 h | Service 0.833 h | Total 3.565 h
# [DEBUG][PSO] it 3 p64: centres OK
# [DEBUG][PSO it3 p64] MILP solved:
#    → Truck   1.147 h | Drone 1.601 h | Service 0.833 h | Total 3.582 h
# [DEBUG][PSO] it 3 p65: centres OK
# [DEBUG][PSO it3 p65] MILP solved:
#    → Truck   1.099 h | Drone 1.663 h | Service 0.833 h | Total 3.596 h
# [DEBUG][PSO] it 3 p66: centres OK
# [DEBUG][PSO it3 p66] MILP solved:
#    → Truck   1.075 h | Drone 1.511 h | Service 0.833 h | Total 3.420 h
# [DEBUG][PSO] it 3 p67: centres OK
# [DEBUG][PSO it3 p67] MILP solved:
#    → Truck   1.134 h | Drone 1.719 h | Service 0.833 h | Total 3.687 h
# [DEBUG][PSO] it 3 p68: centres OK
# [DEBUG][PSO it3 p68] MILP solved:
#    → Truck   1.122 h | Drone 1.414 h | Service 0.833 h | Total 3.369 h
# [DEBUG][PSO] it 3 p69: centres OK
# [DEBUG][PSO it3 p69] MILP solved:
#    → Truck   1.014 h | Drone 1.629 h | Service 0.833 h | Total 3.476 h
# [DEBUG][PSO] it 3 p70: endurance VIOLATION in cl 0
# [DEBUG][PSO] it 3 p71: centres OK
# [DEBUG][PSO it3 p71] MILP solved:
#    → Truck   1.157 h | Drone 1.555 h | Service 0.833 h | Total 3.545 h
# [DEBUG][PSO] it 3 p72: centres OK
# [DEBUG][PSO it3 p72] MILP solved:
#    → Truck   1.060 h | Drone 1.562 h | Service 0.833 h | Total 3.456 h
# [DEBUG][PSO] it 3 p73: endurance VIOLATION in cl 4
# [DEBUG][PSO] it 3 p74: centres OK
# [DEBUG][PSO it3 p74] MILP solved:
#    → Truck   1.122 h | Drone 1.337 h | Service 0.833 h | Total 3.293 h
# [DEBUG][PSO] it 3 p75: centres OK
# [DEBUG][PSO it3 p75] MILP solved:
#    → Truck   1.247 h | Drone 1.681 h | Service 0.833 h | Total 3.761 h
# [DEBUG][PSO] it 3 p76: endurance VIOLATION in cl 9
# ...
#    → Truck   0.973 h | Drone 1.194 h | Service 0.833 h | Total 3.001 h
# [DEBUG][PSO] it 14 p96: centres OK
# [DEBUG][PSO it14 p96] MILP solved:
#    → Truck   0.974 h | Drone 1.202 h | Service 0.833 h | Total 3.010 h
# [DEBUG][PSO] it 14 p97: centres OK
# [DEBUG][PSO it14 p97] MILP solved:
#    → Truck   0.976 h | Drone 1.193 h | Service 0.833 h | Total 3.003 h
# [DEBUG][PSO] it 14 p98: centres OK
# [DEBUG][PSO it14 p98] MILP solved:
#    → Truck   0.971 h | Drone 1.197 h | Service 0.833 h | Total 3.001 h
# [DEBUG][PSO] it 14 p99: centres OK
# [DEBUG][PSO it14 p99] MILP solved:
#    → Truck   0.973 h | Drone 1.200 h | Service 0.833 h | Total 3.006 h
# [DEBUG][PSO] -------------------- iteration 15 ---------------------
# [DEBUG][PSO] it 15 p100: centres OK
# [DEBUG][PSO it15 p100] MILP solved:
#    → Truck   0.970 h | Drone 1.196 h | Service 0.833 h | Total 3.000 h
# [DEBUG][PSO] it 15 p1: centres OK
# [DEBUG][PSO it15 p1] MILP solved:
#    → Truck   0.970 h | Drone 1.192 h | Service 0.833 h | Total 2.995 h
# [DEBUG][PSO] it 15 p2: centres OK
# [DEBUG][PSO it15 p2] MILP solved:
#    → Truck   1.060 h | Drone 1.628 h | Service 0.833 h | Total 3.522 h
# [DEBUG][PSO] it 15 p3: centres OK
# [DEBUG][PSO it15 p3] MILP solved:
#    → Truck   0.975 h | Drone 1.192 h | Service 0.833 h | Total 3.001 h
# [DEBUG][PSO] it 15 p4: centres OK
# [DEBUG][PSO it15 p4] MILP solved:
#    → Truck   0.971 h | Drone 1.193 h | Service 0.833 h | Total 2.998 h
# [DEBUG][PSO] it 15 p5: centres OK
# [DEBUG][PSO it15 p5] MILP solved:
#    → Truck   0.967 h | Drone 1.195 h | Service 0.833 h | Total 2.996 h
# [DEBUG][PSO] it 15 p6: centres OK
# [DEBUG][PSO it15 p6] MILP solved:
#    → Truck   0.971 h | Drone 1.199 h | Service 0.833 h | Total 3.004 h
# [DEBUG][PSO] it 15 p7: centres OK
# [DEBUG][PSO it15 p7] MILP solved:
#    → Truck   0.978 h | Drone 1.197 h | Service 0.833 h | Total 3.009 h
# [DEBUG][PSO] it 15 p8: centres OK
# [DEBUG][PSO it15 p8] MILP solved:
#    → Truck   0.971 h | Drone 1.199 h | Service 0.833 h | Total 3.003 h
# [DEBUG][PSO] it 15 p9: centres OK
# [DEBUG][PSO it15 p9] MILP solved:
#    → Truck   0.969 h | Drone 1.196 h | Service 0.833 h | Total 2.999 h
# [DEBUG][PSO] it 15 p10: centres OK
# [DEBUG][PSO it15 p10] MILP solved:
#    → Truck   0.972 h | Drone 1.202 h | Service 0.833 h | Total 3.007 h
# [DEBUG][PSO] it 15 p11: centres OK
# [DEBUG][PSO it15 p11] MILP solved:
#    → Truck   0.970 h | Drone 1.200 h | Service 0.833 h | Total 3.004 h
# [DEBUG][PSO] it 15 p12: centres OK
# [DEBUG][PSO it15 p12] MILP solved:
#    → Truck   0.966 h | Drone 1.198 h | Service 0.833 h | Total 2.998 h
# [DEBUG][PSO] it 15 p13: centres OK
# [DEBUG][PSO it15 p13] MILP solved:
#    → Truck   0.969 h | Drone 1.199 h | Service 0.833 h | Total 3.002 h
# [DEBUG][PSO] it 15 p14: centres OK
# [DEBUG][PSO it15 p14] MILP solved:
#    → Truck   0.974 h | Drone 1.196 h | Service 0.833 h | Total 3.004 h
# [DEBUG][PSO] it 15 p15: centres OK
# [DEBUG][PSO it15 p15] MILP solved:
#    → Truck   0.968 h | Drone 1.197 h | Service 0.833 h | Total 2.998 h
# [DEBUG][PSO] it 15 p16: centres OK
# [DEBUG][PSO it15 p16] MILP solved:
#    → Truck   0.974 h | Drone 1.192 h | Service 0.833 h | Total 2.999 h
# [DEBUG][PSO] it 15 p17: centres OK
# [DEBUG][PSO it15 p17] MILP solved:
#    → Truck   0.966 h | Drone 1.200 h | Service 0.833 h | Total 2.998 h
# [DEBUG][PSO] it 15 p18: centres OK
# [DEBUG][PSO it15 p18] MILP solved:
#    → Truck   0.977 h | Drone 1.195 h | Service 0.833 h | Total 3.006 h
# [DEBUG][PSO] it 15 p19: centres OK
# [DEBUG][PSO it15 p19] MILP solved:
#    → Truck   0.969 h | Drone 1.194 h | Service 0.833 h | Total 2.996 h
# [DEBUG][PSO] it 15 p20: centres OK
# [DEBUG][PSO it15 p20] MILP solved:
#    → Truck   0.972 h | Drone 1.199 h | Service 0.833 h | Total 3.004 h
# [DEBUG][PSO] it 15 p21: centres OK
# [DEBUG][PSO it15 p21] MILP solved:
#    → Truck   0.972 h | Drone 1.195 h | Service 0.833 h | Total 3.001 h
# [DEBUG][PSO] it 15 p22: centres OK
# [DEBUG][PSO it15 p22] MILP solved:
#    → Truck   0.968 h | Drone 1.195 h | Service 0.833 h | Total 2.996 h
# [DEBUG][PSO] it 15 p23: centres OK
# [DEBUG][PSO it15 p23] MILP solved:
#    → Truck   0.969 h | Drone 1.196 h | Service 0.833 h | Total 2.998 h
# [DEBUG][PSO] it 15 p24: centres OK
# [DEBUG][PSO it15 p24] MILP solved:
#    → Truck   0.971 h | Drone 1.193 h | Service 0.833 h | Total 2.997 h
# [DEBUG][PSO] it 15 p25: centres OK
# [DEBUG][PSO it15 p25] MILP solved:
#    → Truck   0.971 h | Drone 1.199 h | Service 0.833 h | Total 3.003 h
# [DEBUG][PSO] it 15 p26: centres OK
# [DEBUG][PSO it15 p26] MILP solved:
#    → Truck   0.972 h | Drone 1.199 h | Service 0.833 h | Total 3.004 h
# [DEBUG][PSO] it 15 p27: centres OK
# [DEBUG][PSO it15 p27] MILP solved:
#    → Truck   0.969 h | Drone 1.202 h | Service 0.833 h | Total 3.004 h
# [DEBUG][PSO] it 15 p28: centres OK
# [DEBUG][PSO it15 p28] MILP solved:
#    → Truck   0.972 h | Drone 1.199 h | Service 0.833 h | Total 3.004 h
# [DEBUG][PSO] it 15 p29: centres OK
# [DEBUG][PSO it15 p29] MILP solved:
#    → Truck   0.979 h | Drone 1.197 h | Service 0.833 h | Total 3.009 h
# [DEBUG][PSO] it 15 p30: centres OK
# [DEBUG][PSO it15 p30] MILP solved:
#    → Truck   0.971 h | Drone 1.193 h | Service 0.833 h | Total 2.998 h
# [DEBUG][PSO] it 15 p31: centres OK
# [DEBUG][PSO it15 p31] MILP solved:
#    → Truck   0.969 h | Drone 1.194 h | Service 0.833 h | Total 2.996 h
# [DEBUG][PSO] it 15 p32: centres OK
# [DEBUG][PSO it15 p32] MILP solved:
#    → Truck   0.972 h | Drone 1.196 h | Service 0.833 h | Total 3.001 h
# [DEBUG][PSO] it 15 p33: centres OK
# [DEBUG][PSO it15 p33] MILP solved:
#    → Truck   0.966 h | Drone 1.203 h | Service 0.833 h | Total 3.003 h
# [DEBUG][PSO] it 15 p34: centres OK
# [DEBUG][PSO it15 p34] MILP solved:
#    → Truck   0.973 h | Drone 1.192 h | Service 0.833 h | Total 2.998 h
# [DEBUG][PSO] it 15 p35: centres OK
# [DEBUG][PSO it15 p35] MILP solved:
#    → Truck   0.970 h | Drone 1.196 h | Service 0.833 h | Total 2.999 h
# [DEBUG][PSO] it 15 p36: centres OK
# [DEBUG][PSO it15 p36] MILP solved:
#    → Truck   0.975 h | Drone 1.195 h | Service 0.833 h | Total 3.003 h
# [DEBUG][PSO] it 15 p37: centres OK
# [DEBUG][PSO it15 p37] MILP solved:
#    → Truck   0.968 h | Drone 1.205 h | Service 0.833 h | Total 3.006 h
# [DEBUG][PSO] it 15 p38: centres OK
# [DEBUG][PSO it15 p38] MILP solved:
#    → Truck   0.975 h | Drone 1.191 h | Service 0.833 h | Total 2.999 h
# [DEBUG][PSO] it 15 p39: centres OK
# [DEBUG][PSO it15 p39] MILP solved:
#    → Truck   0.970 h | Drone 1.193 h | Service 0.833 h | Total 2.996 h
# [DEBUG][PSO] it 15 p40: centres OK
# [DEBUG][PSO it15 p40] MILP solved:
#    → Truck   0.972 h | Drone 1.191 h | Service 0.833 h | Total 2.996 h
# [DEBUG][PSO] it 15 p41: centres OK
# [DEBUG][PSO it15 p41] MILP solved:
#    → Truck   0.969 h | Drone 1.194 h | Service 0.833 h | Total 2.996 h
# [DEBUG][PSO] it 15 p42: centres OK
# [DEBUG][PSO it15 p42] MILP solved:
#    → Truck   0.979 h | Drone 1.189 h | Service 0.833 h | Total 3.001 h
# [DEBUG][PSO] it 15 p43: centres OK
# [DEBUG][PSO it15 p43] MILP solved:
#    → Truck   0.967 h | Drone 1.197 h | Service 0.833 h | Total 2.998 h
# [DEBUG][PSO] it 15 p44: centres OK
# [DEBUG][PSO it15 p44] MILP solved:
#    → Truck   0.976 h | Drone 1.192 h | Service 0.833 h | Total 3.001 h
# [DEBUG][PSO] it 15 p45: centres OK
# [DEBUG][PSO it15 p45] MILP solved:
#    → Truck   0.973 h | Drone 1.197 h | Service 0.833 h | Total 3.004 h
# [DEBUG][PSO] it 15 p46: centres OK
# [DEBUG][PSO it15 p46] MILP solved:
#    → Truck   0.970 h | Drone 1.195 h | Service 0.833 h | Total 2.998 h
# [DEBUG][PSO] it 15 p47: centres OK
# [DEBUG][PSO it15 p47] MILP solved:
#    → Truck   0.974 h | Drone 1.196 h | Service 0.833 h | Total 3.003 h
# [DEBUG][PSO] it 15 p48: centres OK
# [DEBUG][PSO it15 p48] MILP solved:
#    → Truck   0.971 h | Drone 1.191 h | Service 0.833 h | Total 2.995 h
# [DEBUG][PSO] it 15 p49: centres OK
# [DEBUG][PSO it15 p49] MILP solved:
#    → Truck   0.970 h | Drone 1.193 h | Service 0.833 h | Total 2.997 h
# [DEBUG][PSO] it 15 p50: centres OK
# [DEBUG][PSO it15 p50] MILP solved:
#    → Truck   0.969 h | Drone 1.198 h | Service 0.833 h | Total 3.001 h
# [DEBUG][PSO] it 15 p51: centres OK
# [DEBUG][PSO it15 p51] MILP solved:
#    → Truck   0.972 h | Drone 1.194 h | Service 0.833 h | Total 3.000 h
# [DEBUG][PSO] it 15 p52: centres OK
# [DEBUG][PSO it15 p52] MILP solved:
#    → Truck   0.975 h | Drone 1.190 h | Service 0.833 h | Total 2.998 h
# [DEBUG][PSO] it 15 p53: centres OK
# [DEBUG][PSO it15 p53] MILP solved:
#    → Truck   0.969 h | Drone 1.192 h | Service 0.833 h | Total 2.995 h
# [DEBUG][PSO] it 15 p54: centres OK
# [DEBUG][PSO it15 p54] MILP solved:
#    → Truck   0.966 h | Drone 1.197 h | Service 0.833 h | Total 2.996 h
# [DEBUG][PSO] it 15 p55: centres OK
# [DEBUG][PSO it15 p55] MILP solved:
#    → Truck   0.976 h | Drone 1.184 h | Service 0.833 h | Total 2.994 h
# [DEBUG][PSO] it 15 p56: centres OK
# [DEBUG][PSO it15 p56] MILP solved:
#    → Truck   0.973 h | Drone 1.198 h | Service 0.833 h | Total 3.004 h
# [DEBUG][PSO] it 15 p57: centres OK
# [DEBUG][PSO it15 p57] MILP solved:
#    → Truck   0.972 h | Drone 1.199 h | Service 0.833 h | Total 3.005 h
# [DEBUG][PSO] it 15 p58: centres OK
# [DEBUG][PSO it15 p58] MILP solved:
#    → Truck   0.968 h | Drone 1.194 h | Service 0.833 h | Total 2.995 h
# [DEBUG][PSO] it 15 p59: centres OK
# [DEBUG][PSO it15 p59] MILP solved:
#    → Truck   0.972 h | Drone 1.188 h | Service 0.833 h | Total 2.993 h
# [DEBUG][PSO] it 15 p60: centres OK
# [DEBUG][PSO it15 p60] MILP solved:
#    → Truck   0.970 h | Drone 1.194 h | Service 0.833 h | Total 2.998 h
# [DEBUG][PSO] it 15 p61: centres OK
# [DEBUG][PSO it15 p61] MILP solved:
#    → Truck   0.972 h | Drone 1.188 h | Service 0.833 h | Total 2.993 h
# [DEBUG][PSO] it 15 p62: centres OK
# [DEBUG][PSO it15 p62] MILP solved:
#    → Truck   0.972 h | Drone 1.197 h | Service 0.833 h | Total 3.003 h
# [DEBUG][PSO] it 15 p63: centres OK
# [DEBUG][PSO it15 p63] MILP solved:
#    → Truck   0.977 h | Drone 1.194 h | Service 0.833 h | Total 3.004 h
# [DEBUG][PSO] it 15 p64: centres OK
# [DEBUG][PSO it15 p64] MILP solved:
#    → Truck   0.974 h | Drone 1.195 h | Service 0.833 h | Total 3.002 h
# [DEBUG][PSO] it 15 p65: centres OK
# [DEBUG][PSO it15 p65] MILP solved:
#    → Truck   0.972 h | Drone 1.196 h | Service 0.833 h | Total 3.001 h
# [DEBUG][PSO] it 15 p66: centres OK
# [DEBUG][PSO it15 p66] MILP solved:
#    → Truck   0.977 h | Drone 1.196 h | Service 0.833 h | Total 3.007 h
# [DEBUG][PSO] it 15 p67: centres OK
# [DEBUG][PSO it15 p67] MILP solved:
#    → Truck   0.976 h | Drone 1.187 h | Service 0.833 h | Total 2.996 h
# [DEBUG][PSO] it 15 p68: centres OK
# [DEBUG][PSO it15 p68] MILP solved:
#    → Truck   0.975 h | Drone 1.193 h | Service 0.833 h | Total 3.001 h
# [DEBUG][PSO] it 15 p69: centres OK
# [DEBUG][PSO it15 p69] MILP solved:
#    → Truck   0.973 h | Drone 1.194 h | Service 0.833 h | Total 3.001 h
# [DEBUG][PSO] it 15 p70: centres OK
# [DEBUG][PSO it15 p70] MILP solved:
#    → Truck   0.974 h | Drone 1.187 h | Service 0.833 h | Total 2.994 h
# [DEBUG][PSO] it 15 p71: centres OK
# [DEBUG][PSO it15 p71] MILP solved:
#    → Truck   0.972 h | Drone 1.190 h | Service 0.833 h | Total 2.995 h
# [DEBUG][PSO] it 15 p72: centres OK
# [DEBUG][PSO it15 p72] MILP solved:
#    → Truck   0.975 h | Drone 1.191 h | Service 0.833 h | Total 2.998 h
# [DEBUG][PSO] it 15 p73: centres OK
# [DEBUG][PSO it15 p73] MILP solved:
#    → Truck   0.974 h | Drone 1.194 h | Service 0.833 h | Total 3.001 h
# [DEBUG][PSO] it 15 p74: centres OK
# [DEBUG][PSO it15 p74] MILP solved:
#    → Truck   0.971 h | Drone 1.192 h | Service 0.833 h | Total 2.997 h
# [DEBUG][PSO] it 15 p75: centres OK
# [DEBUG][PSO it15 p75] MILP solved:
#    → Truck   0.972 h | Drone 1.197 h | Service 0.833 h | Total 3.002 h
# [DEBUG][PSO] it 15 p76: centres OK
# [DEBUG][PSO it15 p76] MILP solved:
#    → Truck   0.972 h | Drone 1.200 h | Service 0.833 h | Total 3.005 h
# [DEBUG][PSO] it 15 p77: centres OK
# [DEBUG][PSO it15 p77] MILP solved:
#    → Truck   0.975 h | Drone 1.196 h | Service 0.833 h | Total 3.004 h
# [DEBUG][PSO] it 15 p78: centres OK
# [DEBUG][PSO it15 p78] MILP solved:
#    → Truck   0.975 h | Drone 1.195 h | Service 0.833 h | Total 3.004 h
# [DEBUG][PSO] it 15 p79: centres OK
# [DEBUG][PSO it15 p79] MILP solved:
#    → Truck   0.968 h | Drone 1.195 h | Service 0.833 h | Total 2.996 h
# [DEBUG][PSO] it 15 p80: centres OK
# [DEBUG][PSO it15 p80] MILP solved:
#    → Truck   0.970 h | Drone 1.197 h | Service 0.833 h | Total 3.000 h
# [DEBUG][PSO] it 15 p81: centres OK
# [DEBUG][PSO it15 p81] MILP solved:
#    → Truck   0.970 h | Drone 1.193 h | Service 0.833 h | Total 2.996 h
# [DEBUG][PSO] it 15 p82: centres OK
# [DEBUG][PSO it15 p82] MILP solved:
#    → Truck   0.974 h | Drone 1.192 h | Service 0.833 h | Total 3.000 h
# [DEBUG][PSO] it 15 p83: centres OK
# [DEBUG][PSO it15 p83] MILP solved:
#    → Truck   0.970 h | Drone 1.196 h | Service 0.833 h | Total 3.000 h
# [DEBUG][PSO] it 15 p84: centres OK
# [DEBUG][PSO it15 p84] MILP solved:
#    → Truck   0.970 h | Drone 1.195 h | Service 0.833 h | Total 2.999 h
# [DEBUG][PSO] it 15 p85: centres OK
# [DEBUG][PSO it15 p85] MILP solved:
#    → Truck   0.970 h | Drone 1.193 h | Service 0.833 h | Total 2.996 h
# [DEBUG][PSO] it 15 p86: centres OK
# [DEBUG][PSO it15 p86] MILP solved:
#    → Truck   0.970 h | Drone 1.194 h | Service 0.833 h | Total 2.997 h
# [DEBUG][PSO] it 15 p87: centres OK
# [DEBUG][PSO it15 p87] MILP solved:
#    → Truck   0.971 h | Drone 1.189 h | Service 0.833 h | Total 2.993 h
# [DEBUG][PSO] it 15 p88: centres OK
# [DEBUG][PSO it15 p88] MILP solved:
#    → Truck   0.970 h | Drone 1.191 h | Service 0.833 h | Total 2.994 h
# [DEBUG][PSO] it 15 p89: centres OK
# [DEBUG][PSO it15 p89] MILP solved:
#    → Truck   0.972 h | Drone 1.197 h | Service 0.833 h | Total 3.003 h
# [DEBUG][PSO] it 15 p90: centres OK
# [DEBUG][PSO it15 p90] MILP solved:
#    → Truck   0.968 h | Drone 1.192 h | Service 0.833 h | Total 2.994 h
# [DEBUG][PSO] it 15 p91: centres OK
# [DEBUG][PSO it15 p91] MILP solved:
#    → Truck   0.971 h | Drone 1.192 h | Service 0.833 h | Total 2.996 h
# [DEBUG][PSO] it 15 p92: centres OK
# [DEBUG][PSO it15 p92] MILP solved:
#    → Truck   0.971 h | Drone 1.196 h | Service 0.833 h | Total 3.000 h
# [DEBUG][PSO] it 15 p93: centres OK
# [DEBUG][PSO it15 p93] MILP solved:
#    → Truck   0.976 h | Drone 1.195 h | Service 0.833 h | Total 3.004 h
# [DEBUG][PSO] it 15 p94: centres OK
# [DEBUG][PSO it15 p94] MILP solved:
#    → Truck   0.971 h | Drone 1.190 h | Service 0.833 h | Total 2.994 h
# [DEBUG][PSO] it 15 p95: centres OK
# [DEBUG][PSO it15 p95] MILP solved:
#    → Truck   0.971 h | Drone 1.191 h | Service 0.833 h | Total 2.995 h
# [DEBUG][PSO] it 15 p96: centres OK
# [DEBUG][PSO it15 p96] MILP solved:
#    → Truck   0.972 h | Drone 1.195 h | Service 0.833 h | Total 3.000 h
# [DEBUG][PSO] it 15 p97: centres OK
# [DEBUG][PSO it15 p97] MILP solved:
#    → Truck   0.974 h | Drone 1.191 h | Service 0.833 h | Total 2.998 h
# [DEBUG][PSO] it 15 p98: centres OK
# [DEBUG][PSO it15 p98] MILP solved:
#    → Truck   0.970 h | Drone 1.195 h | Service 0.833 h | Total 2.998 h
# [DEBUG][PSO] it 15 p99: centres OK
# [DEBUG][PSO it15 p99] MILP solved:
#    → Truck   0.972 h | Drone 1.192 h | Service 0.833 h | Total 2.997 h
# [DEBUG][PSO] it 15 p100: centres OK
# [DEBUG][PSO it15 p100] MILP solved:
#    → Truck   0.971 h | Drone 1.195 h | Service 0.833 h | Total 2.999 h
# Stopping search: maximum iterations reached --> 15
# [DEBUG] PSO best objective = 2.993 h
# [DEBUG] PSO best weights =
# [-1.8054964  -0.37767186 -1.95916632 -0.9086007   1.73198382  1.02376688
#  -1.05803028 -0.83549459  0.76555774 -1.31663248  1.6141022   1.56725378
#   2.         -0.82477966  1.40494877 -1.40667455 -0.08020464  0.78327212
#   1.96245572 -1.0530975 ]
# [DEBUG] PSO best centres =
# [[ 4.99738115 -6.15228518]
#  [-5.58902217  5.08240591]
#  [-4.15883869 -7.10359201]
#  [ 5.38490656  7.22891675]
#  [-4.6985995  -5.38684812]
#  [ 3.04421451 -7.08618565]
#  [ 3.77311156  5.31016843]
#  [ 9.05386424 -0.48694365]
#  [-0.47596564  1.61400563]
#  [-6.25942264  5.22136007]]
# [DEBUG][OPT ] MILP solved:
#    → Truck   0.972 h | Drone 1.188 h | Service 0.833 h | Total 2.993 h
#
# [RESULT] Clustering   : 3.718 h
# [RESULT] Optimised    : 2.993 h
# [RESULT] Improvement  : 19.51 %
# [DEBUG] Extracted route: [0, 5, 3, 6, 1, 8, 4, 7, 10, 2, 9, 0]
# [DEBUG] Extracted route: [0, 9, 2, 10, 7, 4, 8, 1, 6, 3, 5, 0]
# PTD-VRPD finished – baseline 3.72 h, optimised 2.99 h,  Δ = 19.5%

# %%
# =============================================================
#  PTD-VRPD  ·  time‐dependent speed profile · cloud Gurobi
#            baseline vs. optimized (PSO)
# =============================================================

import numpy as np, pandas as pd, itertools, matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from pyswarm import pso
import gurobipy as gp
from gurobipy import GRB
from scipy.interpolate import interp1d
from scipy.spatial.distance import cdist

# -------------------------------------------------------------
# 0.  Cloud‐license credentials
# -------------------------------------------------------------
WLS_ID     = "95c3994f-513d-4b8c-a42c-0194dad8ec5c"
WLS_SECRET = "3dc0e444-1f74-49f3-96cc-e9abaabb8ce4"
LICENSE_ID = 2551395

def make_env():
    env = gp.Env(empty=True)
    env.setParam("WLSACCESSID", WLS_ID)
    env.setParam("WLSSECRET",   WLS_SECRET)
    env.setParam("LICENSEID",   LICENSE_ID)
    env.setParam("OutputFlag",  0)
    env.start()
    return env

GRB_ENV = make_env()
print("[DEBUG] Gurobi cloud environment initialized.")

# -------------------------------------------------------------
# 1.  Global constants
# -------------------------------------------------------------
RNG_SEED           = 42
np.random.seed(RNG_SEED)

AREA_KM            = 10.0
N_DELIVERIES       = 50
DEPOT              = (0.0, 0.0)

DRONE_SPEED_KMH    = 40.0
DRONE_END_MIN      = 20
SERVICE_MIN_PER_CL = 5.0
BIGM               = 1e6

SWARM_SIZE   = 10
ITERATIONS   = 1
call_counter = 0
iter_counter = 0

BANDS      = np.arange(0, 24 + 0.25, 0.25)
SPEED_BAND = None
START_TIME = 8.0  # Start time for delivery process

# -------------------------------------------------------------
# 2.  Speed lookup + precompute per‐band speeds
# -------------------------------------------------------------
def build_speed_func(csv_path="Predicted Speed/Predicted_Speeds.csv"):
    df = pd.read_csv(csv_path).rename(columns=str.strip)
    if not {"Time of Day","Predicted Speed"}.issubset(df.columns):
        raise ValueError("CSV must contain 'Time of Day' + 'Predicted Speed'")
    df = df.sort_values("Time of Day")
    f = interp1d(df["Time of Day"] % 24,
                  df["Predicted Speed"],
                  kind="linear",
                  fill_value="extrapolate")
    global SPEED_BAND
    SPEED_BAND = f(BANDS)
    print(f"[DEBUG] Loaded {len(df)} speed points – example 09:30 ⇒ {f(9.5):.1f} km/h")
    return lambda t: float(f(t % 24))

speed_func = build_speed_func()

# -------------------------------------------------------------
# 3.  Instance helpers
# -------------------------------------------------------------
def gen_locations(n=N_DELIVERIES, area=AREA_KM):
    locs = np.vstack([DEPOT,
                      np.random.uniform(-area, area, size=(n,2))])
    print(f"[DEBUG] Generated {n} delivery locations.")
    return locs

def kmeans_endurance(locs):
    K = 1
    while True:
        km = KMeans(n_clusters=K,
                    random_state=RNG_SEED,
                    n_init=10).fit(locs[1:])
        ok = True
        for i, ctr in enumerate(km.cluster_centers_):
            dkm = np.linalg.norm(locs[1:][km.labels_==i] - ctr, axis=1)
            rt  = 2*dkm/DRONE_SPEED_KMH + SERVICE_MIN_PER_CL/60.0
            if (rt > DRONE_END_MIN/60.0).any():
                ok = False
                break
        if ok:
            print(f"[DEBUG] K-means found feasible K={K} clusters.")
            return km.labels_, km.cluster_centers_
        K += 1

# -------------------------------------------------------------
# 4.  Build & solve MILP (with PWL + correct endurance)
# -------------------------------------------------------------
def build_and_solve_milp(locs, centres, labels, tag=""):
    """
    Builds and solves the time-dependent truck–drone MILP.
    Enforces:
      • Time‐dependent truck travel via PWL on Tdep → TT
      • Arrival→departure chaining: Tarr→Tdep ≥ Tarr + service + drone‐time
      • Drone‐endurance and dynamic Td = sum of assigned round‐trips
      • Standard MTZ subtour‐elimination for routing
    """
    # Number of stops = depot + each truck‐stop center
    nStop   = len(centres) + 1
    custIdx = np.arange(1, len(locs))  # indices of customer points

    # Precompute distance matrices
    xy   = np.vstack([DEPOT, centres])  # points for routing (depot + stops)
    Dman = cdist(xy, xy, metric="cityblock")
    Deuc = cdist(locs, xy)              # for drone endurance

    # Create Gurobi model
    m = gp.Model(env=GRB_ENV)
    m.Params.OutputFlag = 0

    # === Decision variables ===
    # r[i,j] = 1 if truck goes directly from i to j
    r    = m.addVars(nStop, nStop, vtype=GRB.BINARY, name="r")
    # Tdep[i], Tarr[i] = departure/arrival times at stop i
    Tdep = m.addVars(nStop, lb=0.0, name="Tdep")
    Tarr = m.addVars(nStop, lb=0.0, name="Tarr")
    # TT[i,j] = travel time from i to j (time‐dependent)
    TT   = m.addVars(nStop, nStop, lb=0.0, name="TT")
    # Td[k] = total drone operation time at cluster k (k=0..len(centres)-1)
    Td   = m.addVars(len(centres), lb=0.0, name="Tdrone")
    # y[cIdx,k] = 1 if customer cIdx is served by drone at cluster k
    y    = m.addVars(len(custIdx), len(centres),
                     vtype=GRB.BINARY, name="y")

    # === Objective ===
    # Minimize total makespan = truck travel + drone times + service blocks
    m.setObjective(
        gp.quicksum(TT[i,j] * r[i,j]
                    for i in range(nStop) for j in range(nStop) if i != j)
      + gp.quicksum(Td[k] for k in range(len(centres)))
      + SERVICE_MIN_PER_CL/60.0 * len(centres),
      GRB.MINIMIZE)

    # === Routing & MTZ subtour elimination ===
    for i in range(nStop):
        # exactly one outbound and one inbound per node
        m.addConstr(gp.quicksum(r[i,j] for j in range(nStop) if j!=i) == 1)
        m.addConstr(gp.quicksum(r[j,i] for j in range(nStop) if j!=i) == 1)
    # MTZ variables
    u = m.addVars(nStop, lb=0.0, ub=nStop-1, name="u")
    for i,j in itertools.permutations(range(1,nStop), 2):
        m.addConstr(u[i] - u[j] + (nStop-1)*r[i,j] <= nStop-2)

    # === Time‐dependent travel via PWL + link Tarr ← Tdep + TT ===

    # --- 1. one PWL for invSpeed per stop ---
    inv_min = float(np.min(1/SPEED_BAND))
    inv_max = float(np.max(1/SPEED_BAND))
    invSpd = m.addVars(nStop, lb=inv_min, ub=inv_max, name="invSpd")
    for i in range(nStop):
        inv_vals = (1 / SPEED_BAND).tolist()              # same 96 break-points
        m.addGenConstrPWL(Tdep[i], invSpd[i],
                        BANDS.tolist(), inv_vals,
                        name=f"invPWL_{i}")

    # --- 2. TT[i,j] becomes linear in invSpd[i] ---
    for i in range(nStop):
        for j in range(nStop):
            if i == j: continue
            m.addConstr(
                TT[i,j] == Dman[i,j] * invSpd[i],
                name=f"TTdef_{i}_{j}"
            )
            m.addConstr(
                Tarr[j] >= Tdep[i] + TT[i,j] - BIGM*(1 - r[i,j]),
                name=f"timelink_{i}_{j}"
            )
    # truck starts at time 0
    m.addConstr(Tdep[0] == START_TIME)

    # === Departure chaining: wait for arrival + service + drones ===
    for i in range(1, nStop):
        # Td[i-1] is the drone‐block time for cluster i
        m.addConstr(
            Tdep[i]
            >= Tarr[i]
               + SERVICE_MIN_PER_CL/60.0
               + Td[i-1],
            name=f"wait_after_stop_{i}"
        )

    # === Drone assignment & endurance constraints ===
    for cIdx, cust in enumerate(custIdx):
        # Each customer must be served by exactly one drone/cluster
        m.addConstr(
            gp.quicksum(y[cIdx,k] for k in range(len(centres))) == 1,
            name=f"assignCust_{cIdx}"
        )
        for k in range(len(centres)):
            # round-trip time to that cluster
            rt = 2 * Deuc[cust, k+1] / DRONE_SPEED_KMH
            # endurance big-M: if y=1 then rt <= endurance
            m.addConstr(
                gp.LinExpr(rt - DRONE_END_MIN/60.0)
                <= BIGM * (1 - y[cIdx,k]),
                name=f"endurance_{cIdx}_{k}"
            )
            # accumulate drone times: Td[k] >= sum of all rt * y
            # we generate one constraint per (cust,k),
            # and the solver will push Td to the sum automatically.
            m.addConstr(
                Td[k] >= rt * y[cIdx,k],
                name=f"droneTime_{cIdx}_{k}"
            )

    # === Solve ===
    m.optimize()
    if m.SolCount == 0:
        print(f"[DEBUG]{tag} MILP infeasible.")
        return np.inf, m, r

    # === Extract objective components ===
    truck_time   = sum(TT[i,j].X * r[i,j].X
                       for i in range(nStop) for j in range(nStop) if i!=j)
    drone_time   = sum(Td[k].X for k in range(len(centres)))
    service_time = SERVICE_MIN_PER_CL/60.0 * len(centres)
    total_time   = truck_time + drone_time + service_time

    print(f"[DEBUG]{tag} MILP solved:")
    print(f"   → Truck   {truck_time:.3f} h | "
          f"Drone {drone_time:.3f} h | "
          f"Service {service_time:.3f} h | "
          f"Total  {total_time:.3f} h")
    return total_time, m, r

# -------------------------------------------------------------
# 5.  PSO fitness …
# -------------------------------------------------------------
def pso_fitness(w, locs, centres0, labels0):
    global call_counter, iter_counter
    call_counter += 1
    if call_counter % SWARM_SIZE == 0:
        iteration = call_counter // SWARM_SIZE
        if 1 <= iteration <= ITERATIONS:
            iter_counter = iteration
            print(f"[DEBUG][PSO] -- iter {iter_counter} --")

    particle_idx = ((call_counter - 1) % SWARM_SIZE) + 1
    K = len(centres0)
    ctrs = centres0 + w.reshape(K, 2)

    # endurance check (pre-MILP)
    for k, c in enumerate(ctrs):
        d  = np.linalg.norm(locs[1:][labels0==k] - c, axis=1)
        rt = 2 * d / DRONE_SPEED_KMH
        if (rt > DRONE_END_MIN/60.0).any():
            print(f"[DEBUG][PSO] it{iter_counter} p{particle_idx}: "
                  f"endurance VIOLATION in cl {k}")
            return 1e6

    print(f"[DEBUG][PSO] it{iter_counter} p{particle_idx}: centres OK")
    obj, _, _ = build_and_solve_milp(
        locs, ctrs, labels0,
        tag=f"[PSO it{iter_counter} p{particle_idx}]"
    )
    return 1e6 if np.isinf(obj) else obj

# -------------------------------------------------------------
# 6.  Extract route from r-vars
# -------------------------------------------------------------
def extract_route(r_vars):
    edges = {(i,j) for (i,j),v in r_vars.items() if v.X>0.5}
    route=[0]
    nStop=int(np.sqrt(len(r_vars)))
    while len(route)<nStop+1:
        last=route[-1]
        nxt=next(j for (i,j) in edges if i==last)
        route.append(nxt)
        if nxt==0: break
    print(f"[DEBUG] Extracted route: {route}")
    return route

# -------------------------------------------------------------
# 7.  Main solver + plot
# -------------------------------------------------------------

def solve_and_plot(locs):
    global call_counter, iter_counter
    call_counter = iter_counter = 0

    labels0, centres0 = kmeans_endurance(locs)

    base_time, base_mdl, base_r = build_and_solve_milp(
        locs, centres0, labels0, tag="[CLUSTER]")
    if np.isinf(base_time):
        raise RuntimeError("Baseline infeasible")

    lb = [-2]*2*len(centres0)
    ub = [ 2]*2*len(centres0)
    print("[DEBUG] Starting PSO…")
    w_best, f_best = pso(pso_fitness, lb, ub,
                         swarmsize=SWARM_SIZE,
                         maxiter=ITERATIONS,
                         debug=False,
                         args=(locs, centres0, labels0))
    print(f"[DEBUG] PSO best obj = {f_best:.3f}h")

    centres_opt = (centres0 if f_best>=1e6
                   else centres0 + w_best.reshape(len(centres0),2))
    opt_time, opt_mdl, opt_r = build_and_solve_milp(
        locs, centres_opt, labels0, tag="[OPT   ]")
    if np.isinf(opt_time):
        centres_opt, opt_time, opt_r = centres0, base_time, base_r

    improvement = 100*(base_time - opt_time)/base_time
    print(f"\n[RESULT] Base  {base_time:.3f}h")
    print(f"[RESULT] Opt   {opt_time:.3f}h")
    print(f"[RESULT] Δ={improvement:.2f}%")

    # plot both routes
    route_base = extract_route(base_r)
    route_opt  = extract_route(opt_r)

    plt.figure(figsize=(7,7))
    for k in range(len(centres0)):
        pts = locs[1:][labels0==k]
        plt.scatter(pts[:,0],pts[:,1],s=15,alpha=0.6,label=f'Cl{k+1}')
    plt.scatter(centres0[:,0],centres0[:,1],
                marker='s',c='orange',s=60,label='Clust')
    plt.scatter(centres_opt[:,0],centres_opt[:,1],
                marker='^',c='k',s=80,label='Opt')
    plt.scatter(*DEPOT,marker='*',c='r',s=120,label='Depot')

    path_b = np.vstack([DEPOT,centres0])[route_base]
    plt.plot(path_b[:,0],path_b[:,1],'b-',lw=1.5,label='Base Path')
    path_o = np.vstack([DEPOT,centres_opt])[route_opt]
    plt.plot(path_o[:,0],path_o[:,1],'k--',lw=1.5,label='Opt Path')

    plt.title(f'Makespan {opt_time:.2f}h | Δ={improvement:.1f}%')
    plt.legend(fontsize=8); plt.axis('equal'); plt.grid(True)
    plt.show()

    return base_time, opt_time, improvement


# -------------------------------------------------------------
# 8.  Demo run
# -------------------------------------------------------------
if __name__ == "__main__":
    locs = gen_locations()
    base, opt, impr = solve_and_plot(locs)
    print(f"\nDone – baseline {base:.2f}h, optimized {opt:.2f}h, Δ={impr:.1f}%")
# Out:
# [DEBUG] Gurobi cloud environment initialized.
# [DEBUG] Loaded 96 speed points – example 09:30 ⇒ 66.3 km/h
# [DEBUG] Generated 50 delivery locations.
# [DEBUG] K-means found feasible K=7 clusters.
# [DEBUG][CLUSTER] MILP solved:
#    → Truck   0.980 h | Drone 1.244 h | Service 0.583 h | Total  2.808 h
# [DEBUG] Starting PSO…
# [DEBUG][PSO] it0 p1: centres OK
# [DEBUG][PSO it0 p1] MILP solved:
#    → Truck   1.035 h | Drone 1.360 h | Service 0.583 h | Total  2.978 h
# [DEBUG][PSO] it0 p2: centres OK
# [DEBUG][PSO it0 p2] MILP solved:
#    → Truck   0.946 h | Drone 1.300 h | Service 0.583 h | Total  2.830 h
# [DEBUG][PSO] it0 p3: centres OK
# [DEBUG][PSO it0 p3] MILP solved:
#    → Truck   1.105 h | Drone 1.513 h | Service 0.583 h | Total  3.202 h
# [DEBUG][PSO] it0 p4: centres OK
# [DEBUG][PSO it0 p4] MILP solved:
#    → Truck   1.011 h | Drone 1.471 h | Service 0.583 h | Total  3.066 h
# [DEBUG][PSO] it0 p5: centres OK
# [DEBUG][PSO it0 p5] MILP solved:
#    → Truck   0.941 h | Drone 1.357 h | Service 0.583 h | Total  2.881 h
# [DEBUG][PSO] it0 p6: centres OK
# [DEBUG][PSO it0 p6] MILP solved:
#    → Truck   1.094 h | Drone 1.446 h | Service 0.583 h | Total  3.123 h
# [DEBUG][PSO] it0 p7: centres OK
# [DEBUG][PSO it0 p7] MILP solved:
#    → Truck   0.978 h | Drone 1.369 h | Service 0.583 h | Total  2.931 h
# [DEBUG][PSO] it0 p8: centres OK
# [DEBUG][PSO it0 p8] MILP solved:
#    → Truck   1.105 h | Drone 1.414 h | Service 0.583 h | Total  3.102 h
# [DEBUG][PSO] it0 p9: centres OK
# [DEBUG][PSO it0 p9] MILP solved:
#    → Truck   1.014 h | Drone 1.401 h | Service 0.583 h | Total  2.998 h
# [DEBUG][PSO] -- iter 1 --
# [DEBUG][PSO] it1 p10: centres OK
# [DEBUG][PSO it1 p10] MILP solved:
#    → Truck   0.940 h | Drone 1.457 h | Service 0.583 h | Total  2.979 h
# [DEBUG][PSO] it1 p1: centres OK
# [DEBUG][PSO it1 p1] MILP solved:
#    → Truck   1.001 h | Drone 1.486 h | Service 0.583 h | Total  3.071 h
# [DEBUG][PSO] it1 p2: centres OK
# [DEBUG][PSO it1 p2] MILP solved:
#    → Truck   0.966 h | Drone 1.403 h | Service 0.583 h | Total  2.952 h
# [DEBUG][PSO] it1 p3: centres OK
# [DEBUG][PSO it1 p3] MILP solved:
#    → Truck   1.089 h | Drone 1.544 h | Service 0.583 h | Total  3.216 h
# [DEBUG][PSO] it1 p4: centres OK
# [DEBUG][PSO it1 p4] MILP solved:
#    → Truck   1.055 h | Drone 1.370 h | Service 0.583 h | Total  3.008 h
# [DEBUG][PSO] it1 p5: centres OK
# [DEBUG][PSO it1 p5] MILP solved:
#    → Truck   1.001 h | Drone 1.525 h | Service 0.583 h | Total  3.109 h
# [DEBUG][PSO] it1 p6: centres OK
# [DEBUG][PSO it1 p6] MILP solved:
#    → Truck   1.054 h | Drone 1.449 h | Service 0.583 h | Total  3.086 h
# [DEBUG][PSO] it1 p7: centres OK
# [DEBUG][PSO it1 p7] MILP solved:
#    → Truck   0.914 h | Drone 1.322 h | Service 0.583 h | Total  2.819 h
# [DEBUG][PSO] it1 p8: centres OK
# [DEBUG][PSO it1 p8] MILP solved:
#    → Truck   1.091 h | Drone 1.487 h | Service 0.583 h | Total  3.161 h
# [DEBUG][PSO] it1 p9: centres OK
# [DEBUG][PSO it1 p9] MILP solved:
#    → Truck   1.105 h | Drone 1.494 h | Service 0.583 h | Total  3.183 h
# [DEBUG][PSO] it1 p10: centres OK
# [DEBUG][PSO it1 p10] MILP solved:
#    → Truck   0.923 h | Drone 1.408 h | Service 0.583 h | Total  2.914 h
# Stopping search: maximum iterations reached --> 1
# [DEBUG] PSO best obj = 2.819h
# [DEBUG][OPT   ] MILP solved:
#    → Truck   0.914 h | Drone 1.322 h | Service 0.583 h | Total  2.819 h
#
# [RESULT] Base  2.808h
# [RESULT] Opt   2.819h
# [RESULT] Δ=-0.40%
# [DEBUG] Extracted route: [0, 6, 1, 4, 2, 7, 5, 3, 0]
# [DEBUG] Extracted route: [0, 4, 1, 6, 3, 5, 7, 2, 0]
# Done – baseline 2.81h, optimized 2.82h, Δ=-0.4%

# %%
# =============================================================
#  PTD-VRPD  ·  time‐dependent speed profile · cloud Gurobi
#            baseline vs. optimized (PSO)
# =============================================================

import numpy as np, pandas as pd, itertools, matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from pyswarm import pso
import gurobipy as gp
from gurobipy import GRB
from scipy.interpolate import interp1d
from scipy.spatial.distance import cdist

# -------------------------------------------------------------
# 0.  Cloud‐license credentials
# -------------------------------------------------------------
WLS_ID     = "95c3994f-513d-4b8c-a42c-0194dad8ec5c"
WLS_SECRET = "3dc0e444-1f74-49f3-96cc-e9abaabb8ce4"
LICENSE_ID = 2551395

def make_env():
    env = gp.Env(empty=True)
    env.setParam("WLSACCESSID", WLS_ID)
    env.setParam("WLSSECRET",   WLS_SECRET)
    env.setParam("LICENSEID",   LICENSE_ID)
    env.setParam("OutputFlag",  0)
    env.start()
    return env

GRB_ENV = make_env()
print("[DEBUG] Gurobi cloud environment initialized.")

# -------------------------------------------------------------
# 1.  Global constants
# -------------------------------------------------------------
RNG_SEED           = 42
np.random.seed(RNG_SEED)

AREA_KM            = 10.0
N_DELIVERIES       = 50
DEPOT              = (0.0, 0.0)

DRONE_SPEED_KMH    = 40.0
DRONE_END_MIN      = 20
SERVICE_MIN_PER_CL = 5.0
BIGM               = 1e6

SWARM_SIZE   = 10
ITERATIONS   = 3
call_counter = 0
iter_counter = 0

BANDS      = np.arange(0, 24 + 0.25, 0.25)
SPEED_BAND = None
START_TIME = 8.0  # Start time for delivery process

# -------------------------------------------------------------
# 2.  Speed lookup + precompute per‐band speeds
# -------------------------------------------------------------
def build_speed_func(csv_path="Predicted Speed/Predicted_Speeds.csv"):
    df = pd.read_csv(csv_path).rename(columns=str.strip)
    if not {"Time of Day","Predicted Speed"}.issubset(df.columns):
        raise ValueError("CSV must contain 'Time of Day' + 'Predicted Speed'")
    df = df.sort_values("Time of Day")
    f = interp1d(df["Time of Day"] % 24,
                  df["Predicted Speed"],
                  kind="linear",
                  fill_value="extrapolate")
    global SPEED_BAND
    SPEED_BAND = f(BANDS)
    print(f"[DEBUG] Loaded {len(df)} speed points – example 09:30 ⇒ {f(9.5):.1f} km/h")
    return lambda t: float(f(t % 24))

speed_func = build_speed_func()

# -------------------------------------------------------------
# 3.  Instance helpers
# -------------------------------------------------------------
def gen_locations(n=N_DELIVERIES, area=AREA_KM):
    locs = np.vstack([DEPOT,
                      np.random.uniform(-area, area, size=(n,2))])
    print(f"[DEBUG] Generated {n} delivery locations.")
    return locs

def kmeans_endurance(locs):
    K = 1
    while True:
        km = KMeans(n_clusters=K,
                    random_state=RNG_SEED,
                    n_init=10).fit(locs[1:])
        ok = True
        for i, ctr in enumerate(km.cluster_centers_):
            dkm = np.linalg.norm(locs[1:][km.labels_==i] - ctr, axis=1)
            rt  = 2*dkm/DRONE_SPEED_KMH + SERVICE_MIN_PER_CL/60.0
            if (rt > DRONE_END_MIN/60.0).any():
                ok = False
                break
        if ok:
            print(f"[DEBUG] K-means found feasible K={K} clusters.")
            return km.labels_, km.cluster_centers_
        K += 1

# -------------------------------------------------------------
# 4.  Build & solve MILP (with PWL + correct endurance)
# -------------------------------------------------------------
def build_and_solve_milp(locs, centres, labels, tag=""):
    """
    Builds and solves the time-dependent truck–drone MILP.
    Enforces:
      • Time‐dependent truck travel via PWL on Tdep → TT
      • Arrival→departure chaining: Tarr→Tdep ≥ Tarr + service + drone‐time
      • Drone‐endurance and dynamic Td = sum of assigned round‐trips
      • Standard MTZ subtour‐elimination for routing
    """
    # Number of stops = depot + each truck‐stop center
    nStop   = len(centres) + 1
    custIdx = np.arange(1, len(locs))  # indices of customer points

    # Precompute distance matrices
    xy   = np.vstack([DEPOT, centres])  # points for routing (depot + stops)
    Dman = cdist(xy, xy, metric="cityblock")
    Deuc = cdist(locs, xy)              # for drone endurance

    # Create Gurobi model
    m = gp.Model(env=GRB_ENV)
    m.Params.OutputFlag = 0
    m.Params.Threads = 8           # or however many cores you have
    m.Params.MIPFocus = 1          # (opt.) focus on finding good solutions quickly

    # === Decision variables ===
    # r[i,j] = 1 if truck goes directly from i to j
    r    = m.addVars(nStop, nStop, vtype=GRB.BINARY, name="r")
    # Tdep[i], Tarr[i] = departure/arrival times at stop i
    Tdep = m.addVars(nStop, lb=0.0, name="Tdep")
    Tarr = m.addVars(nStop, lb=0.0, name="Tarr")
    # TT[i,j] = travel time from i to j (time‐dependent)
    TT   = m.addVars(nStop, nStop, lb=0.0, name="TT")
    # Td[k] = total drone operation time at cluster k (k=0..len(centres)-1)
    Td   = m.addVars(len(centres), lb=0.0, name="Tdrone")
    # y[cIdx,k] = 1 if customer cIdx is served by drone at cluster k
    y    = m.addVars(len(custIdx), len(centres),
                     vtype=GRB.BINARY, name="y")

    # === Objective ===
    # Minimize total makespan = truck travel + drone times + service blocks
    m.setObjective(
        gp.quicksum(TT[i,j] * r[i,j]
                    for i in range(nStop) for j in range(nStop) if i != j)
      + gp.quicksum(Td[k] for k in range(len(centres)))
      + SERVICE_MIN_PER_CL/60.0 * len(centres),
      GRB.MINIMIZE)

    # === Routing & MTZ subtour elimination ===
    for i in range(nStop):
        # exactly one outbound and one inbound per node
        m.addConstr(gp.quicksum(r[i,j] for j in range(nStop) if j!=i) == 1)
        m.addConstr(gp.quicksum(r[j,i] for j in range(nStop) if j!=i) == 1)
    # MTZ variables
    u = m.addVars(nStop, lb=0.0, ub=nStop-1, name="u")
    for i,j in itertools.permutations(range(1,nStop), 2):
        m.addConstr(u[i] - u[j] + (nStop-1)*r[i,j] <= nStop-2)

    # === Time‐dependent travel via PWL + link Tarr ← Tdep + TT ===

    # --- 1. one PWL for invSpeed per stop ---
    inv_min = float(np.min(1/SPEED_BAND))
    inv_max = float(np.max(1/SPEED_BAND))
    invSpd = m.addVars(nStop, lb=inv_min, ub=inv_max, name="invSpd")
    for i in range(nStop):
        inv_vals = (1 / SPEED_BAND).tolist()              # same 96 break-points
        m.addGenConstrPWL(Tdep[i], invSpd[i],
                        BANDS.tolist(), inv_vals,
                        name=f"invPWL_{i}")

    # --- 2. TT[i,j] becomes linear in invSpd[i] ---
    for i in range(nStop):
        for j in range(nStop):
            if i == j: continue
            m.addConstr(
                TT[i,j] == Dman[i,j] * invSpd[i],
                name=f"TTdef_{i}_{j}"
            )
            # link arrival at j to departure+travel from i
            
            # lower‐bound (as before)
            m.addConstr(
                Tarr[j] >= Tdep[i] + TT[i, j] - BIGM * (1 - r[i, j]),
                name=f"timelink_lb_{i}_{j}"
            )

            # upper‐bound to force equality when r[i,j] == 1
            m.addConstr(
                Tarr[j] <= Tdep[i] + TT[i, j] + BIGM * (1 - r[i, j]),
                name=f"timelink_ub_{i}_{j}"
            )
    # truck starts at time 0
    m.addConstr(Tdep[0] == START_TIME)

    # === Departure chaining: wait for arrival + service + drones ===
    for i in range(1, nStop):
        # Td[i-1] is the drone‐block time for cluster i
        # DEPART IMMEDIATELY when ready
        m.addConstr(
            Tdep[i]
            == Tarr[i]
            + SERVICE_MIN_PER_CL/60.0
            + Td[i-1],
            name=f"depart_asap_after_{i}"
        )

    # === Drone assignment & endurance constraints ===
    for cIdx, cust in enumerate(custIdx):
        # Each customer must be served by exactly one drone/cluster
        m.addConstr(
            gp.quicksum(y[cIdx,k] for k in range(len(centres))) == 1,
            name=f"assignCust_{cIdx}"
        )
        for k in range(len(centres)):
            # round-trip time to that cluster
            rt = 2 * Deuc[cust, k+1] / DRONE_SPEED_KMH
            # endurance big-M: if y=1 then rt <= endurance
            m.addConstr(
                gp.LinExpr(rt - DRONE_END_MIN/60.0)
                <= BIGM * (1 - y[cIdx,k]),
                name=f"endurance_{cIdx}_{k}"
            )
            # accumulate drone times: Td[k] >= sum of all rt * y
            # we generate one constraint per (cust,k),
            # and the solver will push Td to the sum automatically.
            m.addConstr(
                Td[k] >= rt * y[cIdx,k],
                name=f"droneTime_{cIdx}_{k}"
            )

    # === Solve ===
    m.optimize()
    if m.SolCount == 0:
        print(f"[DEBUG]{tag} MILP infeasible.")
        return np.inf, m, r

    # === Extract objective components ===
    truck_time   = sum(TT[i,j].X * r[i,j].X
                       for i in range(nStop) for j in range(nStop) if i!=j)
    drone_time   = sum(Td[k].X for k in range(len(centres)))
    service_time = SERVICE_MIN_PER_CL/60.0 * len(centres)
    total_time   = truck_time + drone_time + service_time

    print(f"[DEBUG]{tag} MILP solved:")
    print(f"   → Truck   {truck_time:.3f} h | "
          f"Drone {drone_time:.3f} h | "
          f"Service {service_time:.3f} h | "
          f"Total  {total_time:.3f} h")
    return total_time, m, r

# -------------------------------------------------------------
# 5.  PSO fitness …
# -------------------------------------------------------------
def pso_fitness(w, locs, centres0, labels0):
    global call_counter, iter_counter
    call_counter += 1
    if call_counter % SWARM_SIZE == 0:
        iteration = call_counter // SWARM_SIZE
        if 1 <= iteration <= ITERATIONS:
            iter_counter = iteration
            print(f"[DEBUG][PSO] -- iter {iter_counter} --")

    particle_idx = ((call_counter - 1) % SWARM_SIZE) + 1
    K = len(centres0)
    ctrs = centres0 + w.reshape(K, 2)

    # endurance check (pre-MILP)
    for k, c in enumerate(ctrs):
        d  = np.linalg.norm(locs[1:][labels0==k] - c, axis=1)
        rt = 2 * d / DRONE_SPEED_KMH
        if (rt > DRONE_END_MIN/60.0).any():
            print(f"[DEBUG][PSO] it{iter_counter} p{particle_idx}: "
                  f"endurance VIOLATION in cl {k}")
            return 1e6

    print(f"[DEBUG][PSO] it{iter_counter} p{particle_idx}: centres OK")
    obj, _, _ = build_and_solve_milp(
        locs, ctrs, labels0,
        tag=f"[PSO it{iter_counter} p{particle_idx}]"
    )
    return 1e6 if np.isinf(obj) else obj

# -------------------------------------------------------------
# 6.  Extract route from r-vars
# -------------------------------------------------------------
def extract_route(r_vars):
    edges = {(i,j) for (i,j),v in r_vars.items() if v.X>0.5}
    route=[0]
    nStop=int(np.sqrt(len(r_vars)))
    while len(route)<nStop+1:
        last=route[-1]
        nxt=next(j for (i,j) in edges if i==last)
        route.append(nxt)
        if nxt==0: break
    print(f"[DEBUG] Extracted route: {route}")
    return route

# -------------------------------------------------------------
# 7.  Main solver + plot
# -------------------------------------------------------------

def solve_and_plot(locs):
    global call_counter, iter_counter
    call_counter = iter_counter = 0

    # 1) Cluster by endurance
    labels0, centres0 = kmeans_endurance(locs)

    # 2) Baseline MILP
    base_time, base_mdl, base_r = build_and_solve_milp(
        locs, centres0, labels0, tag="[CLUSTER]")
    if np.isinf(base_time):
        raise RuntimeError("Baseline infeasible")

    # 3) PSO optimize
    lb = [-2] * (2 * len(centres0))
    ub = [ 2] * (2 * len(centres0))
    print("[DEBUG] Starting PSO…")
    w_best, f_best = pso(
        pso_fitness,
        lb, ub,
        swarmsize=SWARM_SIZE,
        maxiter=ITERATIONS,
        debug=False,
        args=(locs, centres0, labels0)
    )
    print(f"[DEBUG] PSO best obj = {f_best:.3f}h")

    # 4) Final optimized MILP
    centres_opt = centres0 if f_best >= 1e6 else centres0 + w_best.reshape(-1, 2)
    opt_time, opt_mdl, opt_r = build_and_solve_milp(
        locs, centres_opt, labels0, tag="[OPT   ]")
    if np.isinf(opt_time):
        centres_opt, opt_time, opt_r = centres0, base_time, base_r

    # 5) Summary
    improvement = 100 * (base_time - opt_time) / base_time
    print(f"\n[RESULT] Base  {base_time:.3f}h")
    print(f"[RESULT] Opt   {opt_time:.3f}h")
    print(f"[RESULT] Δ={improvement:.2f}%")

    # 6) Extract actual routes
    route_base = extract_route(base_r)
    route_opt  = extract_route(opt_r)

    # 7) Debug‐print departure times
    print("[DEBUG] Departure times for the *final* optimized route (clock‐time + elapsed):")
    for stop in route_opt[:-1]:   # skip final return‐to‐depot
        tvar = opt_mdl.getVarByName(f"Tdep[{stop}]")
        raw = tvar.X                       # raw = START_TIME + elapsed
        elapsed = raw - START_TIME        # elapsed since START_TIME

        # clock time
        clk = raw
        hh = int(clk) % 24
        mm = int((clk - int(clk)) * 60)

        # elapsed hours/minutes
        eh = int(elapsed)
        em = int((elapsed - int(elapsed)) * 60)

        print(f"   Stop {stop:2d} departs at {hh:02d}:{mm:02d}  (after +{eh:02d}h{em:02d}m)")

    # 8) Plot
    plt.figure(figsize=(7,7))
    # a) customer points
    for k in range(len(centres0)):
        pts = locs[1:][labels0 == k]
        plt.scatter(pts[:,0], pts[:,1], s=15, alpha=0.6, label=f'Cl{k+1}')
    # b) cluster centers & optimized
    plt.scatter(centres0[:,0], centres0[:,1],
                marker='s', c='orange', s=60, label='Clust')
    plt.scatter(centres_opt[:,0], centres_opt[:,1],
                marker='^', c='k', s=80, label='Opt')
    # c) depot
    plt.scatter(*DEPOT, marker='*', c='r', s=120, label='Depot')
    # d) paths
    pb = np.vstack([DEPOT, centres0])[route_base]
    plt.plot(pb[:,0], pb[:,1], 'b-', lw=1.5, label='Base Path')
    po = np.vstack([DEPOT, centres_opt])[route_opt]
    plt.plot(po[:,0], po[:,1], 'k--', lw=1.5, label='Opt Path')
    # e) annotate visited stops
    for (x, y), stop in zip(po[:-1], route_opt[:-1]):
        tvar = opt_mdl.getVarByName(f"Tdep[{stop}]")
        raw = tvar.X
        clk = raw
        hh = int(clk) % 24
        mm = int((clk - int(clk)) * 60)
        plt.text(x + 0.1, y + 0.1, f"{hh:02d}:{mm:02d}", fontsize=8, color='blue')

    plt.title(f'Makespan {opt_time:.2f}h | Δ={improvement:.1f}%')
    plt.legend(fontsize=8)
    plt.axis('equal')
    plt.grid(True)
    plt.show()

    return base_time, opt_time, improvement



# -------------------------------------------------------------
# 8.  Demo run
# -------------------------------------------------------------
if __name__ == "__main__":
    locs = gen_locations()
    base, opt, impr = solve_and_plot(locs)
    print(f"\nDone – baseline {base:.2f}h, optimized {opt:.2f}h, Δ={impr:.1f}%")
# Out:
# [DEBUG] Gurobi cloud environment initialized.
# [DEBUG] Loaded 96 speed points – example 09:30 ⇒ 66.3 km/h
# [DEBUG] Generated 50 delivery locations.
# [DEBUG] K-means found feasible K=7 clusters.
# [DEBUG][CLUSTER] MILP solved:
#    → Truck   1.160 h | Drone 1.244 h | Service 0.583 h | Total  2.987 h
# [DEBUG] Starting PSO…
# [DEBUG][PSO] it0 p1: centres OK
# [DEBUG][PSO it0 p1] MILP solved:
#    → Truck   1.264 h | Drone 1.360 h | Service 0.583 h | Total  3.206 h
# [DEBUG][PSO] it0 p2: centres OK
# [DEBUG][PSO it0 p2] MILP solved:
#    → Truck   1.116 h | Drone 1.300 h | Service 0.583 h | Total  2.999 h
# [DEBUG][PSO] it0 p3: centres OK
# [DEBUG][PSO it0 p3] MILP solved:
#    → Truck   1.280 h | Drone 1.535 h | Service 0.583 h | Total  3.398 h
# [DEBUG][PSO] it0 p4: centres OK
# [DEBUG][PSO it0 p4] MILP solved:
#    → Truck   1.240 h | Drone 1.471 h | Service 0.583 h | Total  3.294 h
# [DEBUG][PSO] it0 p5: centres OK
# [DEBUG][PSO it0 p5] MILP solved:
#    → Truck   1.177 h | Drone 1.357 h | Service 0.583 h | Total  3.117 h
# [DEBUG][PSO] it0 p6: centres OK
# [DEBUG][PSO it0 p6] MILP solved:
#    → Truck   1.291 h | Drone 1.446 h | Service 0.583 h | Total  3.320 h
# [DEBUG][PSO] it0 p7: centres OK
# [DEBUG][PSO it0 p7] MILP solved:
#    → Truck   1.137 h | Drone 1.369 h | Service 0.583 h | Total  3.089 h
# [DEBUG][PSO] it0 p8: centres OK
# [DEBUG][PSO it0 p8] MILP solved:
#    → Truck   1.294 h | Drone 1.414 h | Service 0.583 h | Total  3.291 h
# [DEBUG][PSO] it0 p9: centres OK
# [DEBUG][PSO it0 p9] MILP solved:
#    → Truck   1.165 h | Drone 1.401 h | Service 0.583 h | Total  3.149 h
# [DEBUG][PSO] -- iter 1 --
# [DEBUG][PSO] it1 p10: centres OK
# [DEBUG][PSO it1 p10] MILP solved:
#    → Truck   1.111 h | Drone 1.457 h | Service 0.583 h | Total  3.151 h
# [DEBUG][PSO] it1 p1: centres OK
# [DEBUG][PSO it1 p1] MILP solved:
#    → Truck   1.166 h | Drone 1.486 h | Service 0.583 h | Total  3.236 h
# [DEBUG][PSO] it1 p2: centres OK
# [DEBUG][PSO it1 p2] MILP solved:
#    → Truck   1.166 h | Drone 1.403 h | Service 0.583 h | Total  3.153 h
# [DEBUG][PSO] it1 p3: centres OK
# [DEBUG][PSO it1 p3] MILP solved:
#    → Truck   1.277 h | Drone 1.544 h | Service 0.583 h | Total  3.405 h
# [DEBUG][PSO] it1 p4: centres OK
# [DEBUG][PSO it1 p4] MILP solved:
#    → Truck   1.314 h | Drone 1.370 h | Service 0.583 h | Total  3.267 h
# [DEBUG][PSO] it1 p5: centres OK
# [DEBUG][PSO it1 p5] MILP solved:
#    → Truck   1.176 h | Drone 1.525 h | Service 0.583 h | Total  3.284 h
# [DEBUG][PSO] it1 p6: centres OK
# [DEBUG][PSO it1 p6] MILP solved:
#    → Truck   1.259 h | Drone 1.449 h | Service 0.583 h | Total  3.291 h
# [DEBUG][PSO] it1 p7: centres OK
# [DEBUG][PSO it1 p7] MILP solved:
#    → Truck   1.134 h | Drone 1.322 h | Service 0.583 h | Total  3.040 h
# [DEBUG][PSO] it1 p8: centres OK
# [DEBUG][PSO it1 p8] MILP solved:
#    → Truck   1.285 h | Drone 1.470 h | Service 0.583 h | Total  3.338 h
# [DEBUG][PSO] it1 p9: centres OK
# [DEBUG][PSO it1 p9] MILP solved:
#    → Truck   1.295 h | Drone 1.505 h | Service 0.583 h | Total  3.383 h
# [DEBUG][PSO] -- iter 2 --
# [DEBUG][PSO] it2 p10: centres OK
# [DEBUG][PSO it2 p10] MILP solved:
#    → Truck   1.060 h | Drone 1.375 h | Service 0.583 h | Total  3.018 h
# [DEBUG][PSO] it2 p1: centres OK
# [DEBUG][PSO it2 p1] MILP solved:
#    → Truck   1.231 h | Drone 1.526 h | Service 0.583 h | Total  3.340 h
# [DEBUG][PSO] it2 p2: centres OK
# [DEBUG][PSO it2 p2] MILP solved:
#    → Truck   1.112 h | Drone 1.418 h | Service 0.583 h | Total  3.114 h
# [DEBUG][PSO] it2 p3: centres OK
# [DEBUG][PSO it2 p3] MILP solved:
#    → Truck   1.211 h | Drone 1.485 h | Service 0.583 h | Total  3.279 h
# [DEBUG][PSO] it2 p4: centres OK
# [DEBUG][PSO it2 p4] MILP solved:
#    → Truck   1.174 h | Drone 1.410 h | Service 0.583 h | Total  3.168 h
# [DEBUG][PSO] it2 p5: centres OK
# [DEBUG][PSO it2 p5] MILP solved:
#    → Truck   1.167 h | Drone 1.507 h | Service 0.583 h | Total  3.258 h
# [DEBUG][PSO] it2 p6: centres OK
# [DEBUG][PSO it2 p6] MILP solved:
#    → Truck   1.291 h | Drone 1.477 h | Service 0.583 h | Total  3.352 h
# [DEBUG][PSO] it2 p7: centres OK
# [DEBUG][PSO it2 p7] MILP solved:
#    → Truck   1.137 h | Drone 1.302 h | Service 0.583 h | Total  3.023 h
# [DEBUG][PSO] it2 p8: centres OK
# [DEBUG][PSO it2 p8] MILP solved:
#    → Truck   1.349 h | Drone 1.439 h | Service 0.583 h | Total  3.371 h
# [DEBUG][PSO] it2 p9: centres OK
# [DEBUG][PSO it2 p9] MILP solved:
#    → Truck   1.350 h | Drone 1.498 h | Service 0.583 h | Total  3.431 h
# [DEBUG][PSO] -- iter 3 --
# [DEBUG][PSO] it3 p10: centres OK
# [DEBUG][PSO it3 p10] MILP solved:
#    → Truck   1.070 h | Drone 1.371 h | Service 0.583 h | Total  3.025 h
# [DEBUG][PSO] it3 p1: centres OK
# [DEBUG][PSO it3 p1] MILP solved:
#    → Truck   1.190 h | Drone 1.415 h | Service 0.583 h | Total  3.188 h
# [DEBUG][PSO] it3 p2: centres OK
# [DEBUG][PSO it3 p2] MILP solved:
#    → Truck   1.196 h | Drone 1.320 h | Service 0.583 h | Total  3.099 h
# [DEBUG][PSO] it3 p3: centres OK
# [DEBUG][PSO it3 p3] MILP solved:
#    → Truck   1.223 h | Drone 1.406 h | Service 0.583 h | Total  3.212 h
# [DEBUG][PSO] it3 p4: centres OK
# [DEBUG][PSO it3 p4] MILP solved:
#    → Truck   1.141 h | Drone 1.298 h | Service 0.583 h | Total  3.023 h
# [DEBUG][PSO] it3 p5: centres OK
# [DEBUG][PSO it3 p5] MILP solved:
#    → Truck   1.170 h | Drone 1.397 h | Service 0.583 h | Total  3.151 h
# [DEBUG][PSO] it3 p6: centres OK
# [DEBUG][PSO it3 p6] MILP solved:
#    → Truck   1.202 h | Drone 1.396 h | Service 0.583 h | Total  3.181 h
# [DEBUG][PSO] it3 p7: centres OK
# [DEBUG][PSO it3 p7] MILP solved:
#    → Truck   1.159 h | Drone 1.294 h | Service 0.583 h | Total  3.037 h
# [DEBUG][PSO] it3 p8: centres OK
# [DEBUG][PSO it3 p8] MILP solved:
#    → Truck   1.234 h | Drone 1.363 h | Service 0.583 h | Total  3.180 h
# [DEBUG][PSO] it3 p9: centres OK
# [DEBUG][PSO it3 p9] MILP solved:
#    → Truck   1.112 h | Drone 1.405 h | Service 0.583 h | Total  3.100 h
# [DEBUG][PSO] it3 p10: centres OK
# [DEBUG][PSO it3 p10] MILP solved:
#    → Truck   1.070 h | Drone 1.331 h | Service 0.583 h | Total  2.985 h
# Stopping search: maximum iterations reached --> 3
# [DEBUG] PSO best obj = 2.985h
# [DEBUG][OPT   ] MILP solved:
#    → Truck   1.070 h | Drone 1.331 h | Service 0.583 h | Total  2.985 h
#
# [RESULT] Base  2.987h
# [RESULT] Opt   2.985h
# [RESULT] Δ=0.09%
# [DEBUG] Extracted route: [0, 6, 1, 4, 2, 7, 5, 3, 0]
# [DEBUG] Extracted route: [0, 6, 1, 4, 2, 7, 5, 3, 0]
# [DEBUG] Departure times for the *final* optimized route (clock‐time + elapsed):
#    Stop  0 departs at 08:00  (after +00h00m)
#    Stop  6 departs at 08:10  (after +00h10m)
#    Stop  1 departs at 08:39  (after +00h39m)
#    Stop  4 departs at 09:02  (after +01h02m)
#    Stop  2 departs at 09:25  (after +01h25m)
#    Stop  7 departs at 09:49  (after +01h49m)
#    Stop  5 departs at 10:22  (after +02h22m)
#    Stop  3 departs at 10:46  (after +02h46m)
# Done – baseline 2.99h, optimized 2.98h, Δ=0.1%

# %%
# =============================================================
#  PTD-VRPD  ·  time‐dependent speed profile · cloud Gurobi
#            baseline vs. optimized (PSO)
# =============================================================

import numpy as np, pandas as pd, itertools, matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from pyswarm import pso
import gurobipy as gp
from gurobipy import GRB
from scipy.interpolate import interp1d
from scipy.spatial.distance import cdist

# -------------------------------------------------------------
# 0.  Cloud‐license credentials
# -------------------------------------------------------------
WLS_ID     = "95c3994f-513d-4b8c-a42c-0194dad8ec5c"
WLS_SECRET = "3dc0e444-1f74-49f3-96cc-e9abaabb8ce4"
LICENSE_ID = 2551395

def make_env():
    env = gp.Env(empty=True)
    env.setParam("WLSACCESSID", WLS_ID)
    env.setParam("WLSSECRET",   WLS_SECRET)
    env.setParam("LICENSEID",   LICENSE_ID)
    env.setParam("OutputFlag",  0)
    env.start()
    return env

GRB_ENV = make_env()
print("[DEBUG] Gurobi cloud environment initialized.")

# -------------------------------------------------------------
# 1.  Global constants
# -------------------------------------------------------------
RNG_SEED           = 42
np.random.seed(RNG_SEED)

AREA_KM            = 10.0
N_DELIVERIES       = 50
DEPOT              = (0.0, 0.0)

DRONE_SPEED_KMH    = 40.0
N_DRONES           = 10
DRONE_END_MIN      = 20
SERVICE_MIN_PER_CL = 5.0
BIGM               = 1e6

SWARM_SIZE   = 10
ITERATIONS   = 3
call_counter = 0
iter_counter = 0

BANDS      = np.arange(0, 24 + 0.25, 0.25)
SPEED_BAND = None
START_TIME = 8.0  # Start time for delivery process

# -------------------------------------------------------------
# 2.  Speed lookup + precompute per‐band speeds
# -------------------------------------------------------------
def build_speed_func(csv_path="Predicted_Speeds.csv"):
    df = pd.read_csv(csv_path).rename(columns=str.strip)
    if not {"Time of Day","Predicted Speed"}.issubset(df.columns):
        raise ValueError("CSV must contain 'Time of Day' + 'Predicted Speed'")
    df = df.sort_values("Time of Day")
    f = interp1d(df["Time of Day"] % 24,
                  df["Predicted Speed"],
                  kind="linear",
                  fill_value="extrapolate")
    global SPEED_BAND
    SPEED_BAND = f(BANDS)
    print(f"[DEBUG] Loaded {len(df)} speed points – example 09:30 ⇒ {f(9.5):.1f} km/h")
    return lambda t: float(f(t % 24))

speed_func = build_speed_func()

# -------------------------------------------------------------
# 3.  Instance helpers
# -------------------------------------------------------------
def gen_locations(n=N_DELIVERIES, area=AREA_KM):
    locs = np.vstack([DEPOT,
                      np.random.uniform(-area, area, size=(n,2))])
    print(f"[DEBUG] Generated {n} delivery locations.")
    return locs

def kmeans_endurance(locs):
    K = 1
    while True:
        km = KMeans(n_clusters=K,
                    random_state=RNG_SEED,
                    n_init=10).fit(locs[1:])
        ok = True
        for i, ctr in enumerate(km.cluster_centers_):
            dkm = np.linalg.norm(locs[1:][km.labels_==i] - ctr, axis=1)
            rt  = 2*dkm/DRONE_SPEED_KMH
            if (rt > DRONE_END_MIN/60.0).any():
                ok = False
                break
        if ok:
            print(f"[DEBUG] K-means found feasible K={K} clusters.")
            return km.labels_, km.cluster_centers_
        K += 1

# -------------------------------------------------------------
# 4.  Build & solve MILP (with PWL + correct endurance)
# -------------------------------------------------------------
def build_and_solve_milp(locs, centres, labels, tag=""):
    """
    Builds and solves the time-dependent truck–drone MILP.
    Enforces:
      • Time‐dependent truck travel via PWL on Tdep → TT
      • Arrival→departure chaining: Tarr→Tdep ≥ Tarr + service + drone‐time
      • Drone‐endurance and dynamic Tdrone = max accumulated sorties per drone
      • Standard MTZ subtour‐elimination for routing
    """
    # Number of stops = depot + each truck‐stop center
    nStop   = len(centres) + 1
    custIdx = np.arange(1, len(locs))  # indices of customer points

    # Precompute distance matrices
    xy   = np.vstack([DEPOT, centres])  # points for routing (depot + stops)
    Dman = cdist(xy, xy, metric="cityblock")
    Deuc = cdist(locs, xy)              # for drone endurance

    # Create Gurobi model
    m = gp.Model(env=GRB_ENV)
    m.Params.OutputFlag = 0
    m.Params.Threads = 8
    m.Params.MIPFocus = 1

    # === Decision variables ===
    # r[i,j] = 1 if truck goes directly from i to j
    r    = m.addVars(nStop, nStop, vtype=GRB.BINARY, name="r")
    # Tdep[i], Tarr[i] = departure/arrival times at stop i
    Tdep = m.addVars(nStop, lb=0.0, name="Tdep")
    Tarr = m.addVars(nStop, lb=0.0, name="Tarr")
    # TT[i,j] = travel time from i to j (time-dependent)
    TT   = m.addVars(nStop, nStop, lb=0.0, name="TT")
    # y[cIdx,i,k] = 1 if customer cIdx is served by drone k at cluster i
    y      = m.addVars(len(custIdx), len(centres), N_DRONES,
                       vtype=GRB.BINARY, name="y")
    # Accumulated flight time per cluster i and drone k
    Td_acc = m.addVars(len(centres), N_DRONES, lb=0.0, name="Td_acc")
    # Cluster-wide drone-phase makespan
    Tdrone = m.addVars(len(centres), lb=0.0, name="Tdrone")
    
    
    # ── FIX: force each customer into its original K-means cluster ──
    for cIdx in range(len(custIdx)):
        for i in range(len(centres)):
            if labels[cIdx] != i:
                for k in range(N_DRONES):
                    y[cIdx, i, k].ub = 0
                    

    # === Objective ===
    # Minimize total makespan = truck travel + drone times + service blocks
    m.setObjective(
        gp.quicksum(TT[i,j] * r[i,j]
                    for i in range(nStop) for j in range(nStop) if i != j)
      + gp.quicksum(Tdrone[i] for i in range(len(centres)))
      + SERVICE_MIN_PER_CL/60.0 * len(centres),
      GRB.MINIMIZE)

    # === Routing & MTZ subtour elimination ===
    for i in range(nStop):
        m.addConstr(gp.quicksum(r[i,j] for j in range(nStop) if j!=i) == 1)
        m.addConstr(gp.quicksum(r[j,i] for j in range(nStop) if j!=i) == 1)
    u = m.addVars(nStop, lb=0.0, ub=nStop-1, name="u")
    for i,j in itertools.permutations(range(1,nStop), 2):
        m.addConstr(u[i] - u[j] + (nStop-1)*r[i,j] <= nStop-2)

    # === Time-dependent travel via PWL + link Tarr ← Tdep + TT ===
    inv_min = float(np.min(1/SPEED_BAND))
    inv_max = float(np.max(1/SPEED_BAND))
    invSpd = m.addVars(nStop, lb=inv_min, ub=inv_max, name="invSpd")
    for i in range(nStop):
        inv_vals = (1 / SPEED_BAND).tolist()
        m.addGenConstrPWL(Tdep[i], invSpd[i],
                          BANDS.tolist(), inv_vals,
                          name=f"invPWL_{i}")
    for i in range(nStop):
        for j in range(nStop):
            if i==j: continue
            m.addConstr(TT[i,j] == Dman[i,j] * invSpd[i], name=f"TTdef_{i}_{j}")
            m.addConstr(
                Tarr[j] >= Tdep[i] + TT[i,j] - BIGM*(1 - r[i,j]),
                name=f"timelink_lb_{i}_{j}")
            m.addConstr(
                Tarr[j] <= Tdep[i] + TT[i,j] + BIGM*(1 - r[i,j]),
                name=f"timelink_ub_{i}_{j}")
    m.addConstr(Tdep[0] == START_TIME)

    # === Departure chaining ===
    for i in range(1, nStop):
        m.addConstr(
            Tdep[i] == Tarr[i]
                     + SERVICE_MIN_PER_CL/60.0
                     + Tdrone[i-1],
            name=f"depart_asap_after_{i}"
        )

    # === Drone assignment, finite fleet & accumulation ===
    for cIdx, cust in enumerate(custIdx):
        m.addConstr(
            gp.quicksum(y[cIdx,i,k]
                        for i in range(len(centres))
                        for k in range(N_DRONES)) == 1,
            name=f"assignCust_{cIdx}"
        )
        for i in range(len(centres)):
            rt = 2 * Deuc[cust, i+1] / DRONE_SPEED_KMH
            for k in range(N_DRONES):
                m.addConstr(
                    gp.LinExpr(rt) <= DRONE_END_MIN/60.0 + BIGM*(1 - y[cIdx,i,k]),
                    name=f"endurance_{cIdx}_{i}_{k}"
                )
    
    for i in range(len(centres)):
        for k in range(N_DRONES):
            m.addConstr(
                Td_acc[i, k] == gp.quicksum(
                    (2 * Deuc[cust, i+1] / DRONE_SPEED_KMH) *
                        y[cIdx, i, k]
                    for cIdx, cust in enumerate(custIdx)
                ),
                name=f"accum_sum_{i}_{k}"
            )
    for i in range(len(centres)):
        for k in range(N_DRONES):
            m.addConstr(
                Tdrone[i] >= Td_acc[i,k],
                name=f"makespan_{i}_{k}"
            )

    # === Solve ===
    m.optimize()
    if m.SolCount == 0:
        print(f"[DEBUG]{tag} MILP infeasible.")
        return np.inf, m, r

    # === Extract objective components ===
    truck_time   = sum(TT[i,j].X * r[i,j].X
                       for i in range(nStop) for j in range(nStop) if i!=j)
    drone_time   = sum(Tdrone[i].X for i in range(len(centres)))
    service_time = SERVICE_MIN_PER_CL/60.0 * len(centres)
    total_time   = truck_time + drone_time + service_time

    print(f"[DEBUG]{tag} MILP solved:")
    print(f"   → Truck   {truck_time:.3f} h | "
          f"Drone {drone_time:.3f} h | "
          f"Service {service_time:.3f} h | "
          f"Total  {total_time:.3f} h")
    return total_time, m, r


# -------------------------------------------------------------
# 5.  PSO fitness …
# -------------------------------------------------------------
def pso_fitness(w, locs, centres0, labels0):
    global call_counter, iter_counter
    call_counter += 1
    if call_counter % SWARM_SIZE == 0:
        iteration = call_counter // SWARM_SIZE
        if 1 <= iteration <= ITERATIONS:
            iter_counter = iteration
            print(f"[DEBUG][PSO] -- iter {iter_counter} --")

    particle_idx = ((call_counter - 1) % SWARM_SIZE) + 1
    K = len(centres0)
    ctrs = centres0 + w.reshape(K, 2)

    # endurance check (pre-MILP)
    for k, c in enumerate(ctrs):
        d  = np.linalg.norm(locs[1:][labels0==k] - c, axis=1)
        rt = 2 * d / DRONE_SPEED_KMH
        if (rt > DRONE_END_MIN/60.0).any():
            print(f"[DEBUG][PSO] it{iter_counter} p{particle_idx}: "
                  f"endurance VIOLATION in cl {k}")
            return 1e6

    print(f"[DEBUG][PSO] it{iter_counter} p{particle_idx}: centres OK")
    obj, _, _ = build_and_solve_milp(
        locs, ctrs, labels0,
        tag=f"[PSO it{iter_counter} p{particle_idx}]"
    )
    return 1e6 if np.isinf(obj) else obj

# -------------------------------------------------------------
# 6.  Extract route from r-vars
# -------------------------------------------------------------
def extract_route(r_vars):
    edges = {(i,j) for (i,j),v in r_vars.items() if v.X>0.5}
    route=[0]
    nStop=int(np.sqrt(len(r_vars)))
    while len(route)<nStop+1:
        last=route[-1]
        nxt=next(j for (i,j) in edges if i==last)
        route.append(nxt)
        if nxt==0: break
    print(f"[DEBUG] Extracted route: {route}")
    return route

# -------------------------------------------------------------
# 7.  Main solver + plot
# -------------------------------------------------------------

def solve_and_plot(locs):
    global call_counter, iter_counter
    call_counter = iter_counter = 0

    # 1) Cluster by endurance
    labels0, centres0 = kmeans_endurance(locs)

    # 2) Baseline MILP
    base_time, base_mdl, base_r = build_and_solve_milp(
        locs, centres0, labels0, tag="[CLUSTER]")
    if np.isinf(base_time):
        raise RuntimeError("Baseline infeasible")

    # 3) PSO optimize
    lb = [-2] * (2 * len(centres0))
    ub = [ 2] * (2 * len(centres0))
    print("[DEBUG] Starting PSO…")
    w_best, f_best = pso(
        pso_fitness,
        lb, ub,
        swarmsize=SWARM_SIZE,
        maxiter=ITERATIONS,
        debug=False,
        args=(locs, centres0, labels0)
    )
    print(f"[DEBUG] PSO best obj = {f_best:.3f}h")

    # 4) Final optimized MILP
    centres_opt = centres0 if f_best >= 1e6 else centres0 + w_best.reshape(-1, 2)
    opt_time, opt_mdl, opt_r = build_and_solve_milp(
        locs, centres_opt, labels0, tag="[OPT   ]")
    if np.isinf(opt_time):
        centres_opt, opt_time, opt_r = centres0, base_time, base_r

    # 5) Summary
    improvement = 100 * (base_time - opt_time) / base_time
    print(f"\n[RESULT] Base  {base_time:.3f}h")
    print(f"[RESULT] Opt   {opt_time:.3f}h")
    print(f"[RESULT] Δ={improvement:.2f}%")

    # 6) Extract actual routes
    route_base = extract_route(base_r)
    route_opt  = extract_route(opt_r)

    # 7) Debug‐print departure times
    print("[DEBUG] Departure times for the *final* optimized route (clock‐time + elapsed):")
    for stop in route_opt[:-1]:   # skip final return‐to‐depot
        tvar = opt_mdl.getVarByName(f"Tdep[{stop}]")
        raw = tvar.X                       # raw = START_TIME + elapsed
        elapsed = raw - START_TIME        # elapsed since START_TIME

        # clock time
        clk = raw
        hh = int(clk) % 24
        mm = int((clk - int(clk)) * 60)

        # elapsed hours/minutes
        eh = int(elapsed)
        em = int((elapsed - int(elapsed)) * 60)

        print(f"   Stop {stop:2d} departs at {hh:02d}:{mm:02d}  (after +{eh:02d}h{em:02d}m)")

    # 8) Plot
    plt.figure(figsize=(7,7))
    # a) customer points
    for k in range(len(centres0)):
        pts = locs[1:][labels0 == k]
        plt.scatter(pts[:,0], pts[:,1], s=15, alpha=0.6, label=f'Cl{k+1}')
    # b) cluster centers & optimized
    plt.scatter(centres0[:,0], centres0[:,1],
                marker='s', c='orange', s=60, label='Clust')
    plt.scatter(centres_opt[:,0], centres_opt[:,1],
                marker='^', c='k', s=80, label='Opt')
    # c) depot
    plt.scatter(*DEPOT, marker='*', c='r', s=120, label='Depot')
    # d) paths
    pb = np.vstack([DEPOT, centres0])[route_base]
    plt.plot(pb[:,0], pb[:,1], 'b-', lw=1.5, label='Base Path')
    po = np.vstack([DEPOT, centres_opt])[route_opt]
    plt.plot(po[:,0], po[:,1], 'k--', lw=1.5, label='Opt Path')
    # e) annotate visited stops
    for (x, y), stop in zip(po[:-1], route_opt[:-1]):
        tvar = opt_mdl.getVarByName(f"Tdep[{stop}]")
        raw = tvar.X
        clk = raw
        hh = int(clk) % 24
        mm = int((clk - int(clk)) * 60)
        plt.text(x + 0.1, y + 0.1, f"{hh:02d}:{mm:02d}", fontsize=8, color='blue')

    plt.title(f'Makespan {opt_time:.2f}h | Δ={improvement:.1f}%')
    plt.legend(fontsize=8)
    plt.axis('equal')
    plt.grid(True)
    plt.show()

    return base_time, opt_time, improvement



# -------------------------------------------------------------
# 8.  Demo run
# -------------------------------------------------------------
if __name__ == "__main__":
    locs = gen_locations()
    base, opt, impr = solve_and_plot(locs)
    print(f"\nDone – baseline {base:.2f}h, optimized {opt:.2f}h, Δ={impr:.1f}%")
# Out:
# [DEBUG] Gurobi cloud environment initialized.
# [DEBUG] Loaded 96 speed points – example 09:30 ⇒ 66.3 km/h
# [DEBUG] Generated 50 delivery locations.
# [DEBUG] K-means found feasible K=4 clusters.
# [DEBUG][CLUSTER] MILP solved:
#    → Truck   0.939 h | Drone 1.277 h | Service 0.333 h | Total  2.549 h
# [DEBUG] Starting PSO…
# [DEBUG][PSO] it0 p1: endurance VIOLATION in cl 1
# [DEBUG][PSO] it0 p2: endurance VIOLATION in cl 1
# [DEBUG][PSO] it0 p3: endurance VIOLATION in cl 0
# [DEBUG][PSO] it0 p4: centres OK
# [DEBUG][PSO it0 p4] MILP solved:
#    → Truck   0.761 h | Drone 1.251 h | Service 0.333 h | Total  2.345 h
# [DEBUG][PSO] it0 p5: endurance VIOLATION in cl 3
# [DEBUG][PSO] it0 p6: endurance VIOLATION in cl 0
# [DEBUG][PSO] it0 p7: endurance VIOLATION in cl 3
# [DEBUG][PSO] it0 p8: endurance VIOLATION in cl 1
# [DEBUG][PSO] it0 p9: endurance VIOLATION in cl 1
# [DEBUG][PSO] -- iter 1 --
# [DEBUG][PSO] it1 p10: endurance VIOLATION in cl 2
# [DEBUG][PSO] it1 p1: endurance VIOLATION in cl 3
# [DEBUG][PSO] it1 p2: endurance VIOLATION in cl 1
# [DEBUG][PSO] it1 p3: endurance VIOLATION in cl 2
# [DEBUG][PSO] it1 p4: endurance VIOLATION in cl 1
# [DEBUG][PSO] it1 p5: endurance VIOLATION in cl 2
# [DEBUG][PSO] it1 p6: endurance VIOLATION in cl 0
# [DEBUG][PSO] it1 p7: centres OK
# [DEBUG][PSO it1 p7] MILP solved:
#    → Truck   0.750 h | Drone 1.227 h | Service 0.333 h | Total  2.310 h
# [DEBUG][PSO] it1 p8: endurance VIOLATION in cl 3
# [DEBUG][PSO] it1 p9: endurance VIOLATION in cl 1
# [DEBUG][PSO] -- iter 2 --
# [DEBUG][PSO] it2 p10: endurance VIOLATION in cl 0
# [DEBUG][PSO] it2 p1: endurance VIOLATION in cl 3
# [DEBUG][PSO] it2 p2: endurance VIOLATION in cl 1
# [DEBUG][PSO] it2 p3: endurance VIOLATION in cl 2
# [DEBUG][PSO] it2 p4: endurance VIOLATION in cl 1
# [DEBUG][PSO] it2 p5: endurance VIOLATION in cl 2
# [DEBUG][PSO] it2 p6: endurance VIOLATION in cl 1
# [DEBUG][PSO] it2 p7: centres OK
# [DEBUG][PSO it2 p7] MILP solved:
#    → Truck   0.773 h | Drone 1.247 h | Service 0.333 h | Total  2.353 h
# [DEBUG][PSO] it2 p8: endurance VIOLATION in cl 3
# [DEBUG][PSO] it2 p9: centres OK
# [DEBUG][PSO it2 p9] MILP solved:
#    → Truck   0.833 h | Drone 1.323 h | Service 0.333 h | Total  2.490 h
# [DEBUG][PSO] -- iter 3 --
# [DEBUG][PSO] it3 p10: endurance VIOLATION in cl 0
# [DEBUG][PSO] it3 p1: endurance VIOLATION in cl 3
# [DEBUG][PSO] it3 p2: endurance VIOLATION in cl 1
# [DEBUG][PSO] it3 p3: centres OK
# [DEBUG][PSO it3 p3] MILP solved:
#    → Truck   0.765 h | Drone 1.285 h | Service 0.333 h | Total  2.384 h
# [DEBUG][PSO] it3 p4: endurance VIOLATION in cl 2
# [DEBUG][PSO] it3 p5: endurance VIOLATION in cl 3
# [DEBUG][PSO] it3 p6: endurance VIOLATION in cl 3
# [DEBUG][PSO] it3 p7: centres OK
# [DEBUG][PSO it3 p7] MILP solved:
#    → Truck   0.759 h | Drone 1.262 h | Service 0.333 h | Total  2.355 h
# [DEBUG][PSO] it3 p8: endurance VIOLATION in cl 3
# [DEBUG][PSO] it3 p9: centres OK
# [DEBUG][PSO it3 p9] MILP solved:
#    → Truck   0.771 h | Drone 1.249 h | Service 0.333 h | Total  2.354 h
# [DEBUG][PSO] it3 p10: endurance VIOLATION in cl 2
# Stopping search: maximum iterations reached --> 3
# [DEBUG] PSO best obj = 2.310h
# [DEBUG][OPT   ] MILP solved:
#    → Truck   0.750 h | Drone 1.227 h | Service 0.333 h | Total  2.310 h
#
# [RESULT] Base  2.549h
# [RESULT] Opt   2.310h
# [RESULT] Δ=9.40%
# [DEBUG] Extracted route: [0, 1, 4, 2, 3, 0]
# [DEBUG] Extracted route: [0, 3, 1, 4, 2, 0]
# [DEBUG] Departure times for the *final* optimized route (clock‐time + elapsed):
#    Stop  0 departs at 08:00  (after +00h00m)
#    Stop  3 departs at 08:32  (after +00h32m)
#    Stop  1 departs at 09:00  (after +01h00m)
#    Stop  4 departs at 09:37  (after +01h37m)
#    Stop  2 departs at 10:09  (after +02h09m)
# Done – baseline 2.55h, optimized 2.31h, Δ=9.4%

# %%
# =============================================================
#  PTD-VRPD  ·  time‐dependent speed profile · cloud Gurobi
#            baseline vs. optimized (PSO)
# =============================================================

import numpy as np, pandas as pd, itertools, matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from pyswarm import pso
import gurobipy as gp
from gurobipy import GRB
from scipy.interpolate import interp1d
from scipy.spatial.distance import cdist

# -------------------------------------------------------------
# 0.  Cloud‐license credentials
# -------------------------------------------------------------
WLS_ID     = "95c3994f-513d-4b8c-a42c-0194dad8ec5c"
WLS_SECRET = "3dc0e444-1f74-49f3-96cc-e9abaabb8ce4"
LICENSE_ID = 2551395

def make_env():
    env = gp.Env(empty=True)
    env.setParam("WLSACCESSID", WLS_ID)
    env.setParam("WLSSECRET",   WLS_SECRET)
    env.setParam("LICENSEID",   LICENSE_ID)
    env.setParam("OutputFlag",  0)
    env.start()
    return env

GRB_ENV = make_env()
print("[DEBUG] Gurobi cloud environment initialized.")

# -------------------------------------------------------------
# 1.  Global constants
# -------------------------------------------------------------
RNG_SEED           = 42
np.random.seed(RNG_SEED)

AREA_KM            = 10.0
N_DELIVERIES       = 50
DEPOT              = (0.0, 0.0)

DRONE_SPEED_KMH    = 40.0
N_DRONES           = 10
DRONE_END_MIN      = 20
SERVICE_MIN_PER_CL = 5.0
BIGM               = 1e6

SWARM_SIZE   = 3
ITERATIONS   = 3
call_counter = 0
iter_counter = 0

BANDS      = np.arange(0, 24 + 0.25, 0.25)
SPEED_BAND = None
START_TIME = 8.0  # Start time for delivery process

# -------------------------------------------------------------
# 2.  Speed lookup + precompute per‐band speeds
# -------------------------------------------------------------
def build_speed_func(csv_path="Predicted_Speeds.csv"):
    df = pd.read_csv(csv_path).rename(columns=str.strip)
    if not {"Time of Day","Predicted Speed"}.issubset(df.columns):
        raise ValueError("CSV must contain 'Time of Day' + 'Predicted Speed'")
    df = df.sort_values("Time of Day")
    f = interp1d(df["Time of Day"] % 24,
                  df["Predicted Speed"],
                  kind="linear",
                  fill_value="extrapolate")
    global SPEED_BAND
    SPEED_BAND = f(BANDS)
    print(f"[DEBUG] Loaded {len(df)} speed points – example 09:30 ⇒ {f(9.5):.1f} km/h")
    return lambda t: float(f(t % 24))

speed_func = build_speed_func()

# -------------------------------------------------------------
# 3.  Instance helpers
# -------------------------------------------------------------
def gen_locations(n=N_DELIVERIES, area=AREA_KM):
    locs = np.vstack([DEPOT,
                      np.random.uniform(-area, area, size=(n,2))])
    print(f"[DEBUG] Generated {n} delivery locations.")
    return locs

def kmeans_endurance(locs):
    K = 1
    while True:
        km = KMeans(n_clusters=K,
                    random_state=RNG_SEED,
                    n_init=10).fit(locs[1:])
        ok = True
        for i, ctr in enumerate(km.cluster_centers_):
            dkm = np.linalg.norm(locs[1:][km.labels_==i] - ctr, axis=1)
            rt  = 2*dkm/DRONE_SPEED_KMH
            if (rt > DRONE_END_MIN/60.0).any():
                ok = False
                break
        if ok:
            print(f"[DEBUG] K-means found feasible K={K} clusters.")
            return km.labels_, km.cluster_centers_
        K += 1

# -------------------------------------------------------------
# 4.  Build & solve MILP (with PWL + correct endurance)
# -------------------------------------------------------------
def build_and_solve_milp(locs, centres, labels, tag=""):
    """
    Builds and solves the time-dependent truck–drone MILP.
    Enforces:
      • Time‐dependent truck travel via PWL on Tdep → TT
      • Arrival→departure chaining: Tarr→Tdep ≥ Tarr + service + drone‐time
      • Drone‐endurance and dynamic Tdrone = max accumulated sorties per drone
      • Standard MTZ subtour‐elimination for routing
    """
    # Number of stops = depot + each truck‐stop center
    nStop   = len(centres) + 1
    custIdx = np.arange(1, len(locs))  # indices of customer points

    # Precompute distance matrices
    xy   = np.vstack([DEPOT, centres])  # points for routing (depot + stops)
    Dman = cdist(xy, xy, metric="cityblock")
    Deuc = cdist(locs, xy)              # for drone endurance

    # Create Gurobi model
    m = gp.Model(env=GRB_ENV)
    m.Params.OutputFlag = 0
    m.Params.Threads = 8
    m.Params.MIPFocus = 1

    # === Decision variables ===
    # r[i,j] = 1 if truck goes directly from i to j
    r    = m.addVars(nStop, nStop, vtype=GRB.BINARY, name="r")
    # Tdep[i], Tarr[i] = departure/arrival times at stop i
    Tdep = m.addVars(nStop, lb=0.0, name="Tdep")
    Tarr = m.addVars(nStop, lb=0.0, name="Tarr")
    # TT[i,j] = travel time from i to j (time-dependent)
    TT   = m.addVars(nStop, nStop, lb=0.0, name="TT")
    # y[cIdx,i,k] = 1 if customer cIdx is served by drone k at cluster i
    y      = m.addVars(len(custIdx), len(centres), N_DRONES,
                       vtype=GRB.BINARY, name="y")
    # Accumulated flight time per cluster i and drone k
    Td_acc = m.addVars(len(centres), N_DRONES, lb=0.0, name="Td_acc")
    # Cluster-wide drone-phase makespan
    Tdrone = m.addVars(len(centres), lb=0.0, name="Tdrone")
    
    
    # ── FIX: force each customer into its original K-means cluster ──
    for cIdx in range(len(custIdx)):
        for i in range(len(centres)):
            if labels[cIdx] != i:
                for k in range(N_DRONES):
                    y[cIdx, i, k].ub = 0
                    

    # === Objective ===
    # Minimize total makespan = truck travel + drone times + service blocks
    m.setObjective(
        gp.quicksum(TT[i,j] * r[i,j]
                    for i in range(nStop) for j in range(nStop) if i != j)
      + gp.quicksum(Tdrone[i] for i in range(len(centres)))
      + SERVICE_MIN_PER_CL/60.0 * len(centres),
      GRB.MINIMIZE)

    # === Routing & MTZ subtour elimination ===
    for i in range(nStop):
        m.addConstr(gp.quicksum(r[i,j] for j in range(nStop) if j!=i) == 1)
        m.addConstr(gp.quicksum(r[j,i] for j in range(nStop) if j!=i) == 1)
    u = m.addVars(nStop, lb=0.0, ub=nStop-1, name="u")
    for i,j in itertools.permutations(range(1,nStop), 2):
        m.addConstr(u[i] - u[j] + (nStop-1)*r[i,j] <= nStop-2)

    # === Time-dependent travel via PWL + link Tarr ← Tdep + TT ===
    inv_min = float(np.min(1/SPEED_BAND))
    inv_max = float(np.max(1/SPEED_BAND))
    invSpd = m.addVars(nStop, lb=inv_min, ub=inv_max, name="invSpd")
    for i in range(nStop):
        inv_vals = (1 / SPEED_BAND).tolist()
        m.addGenConstrPWL(Tdep[i], invSpd[i],
                          BANDS.tolist(), inv_vals,
                          name=f"invPWL_{i}")
    for i in range(nStop):
        for j in range(nStop):
            if i==j: continue
            m.addConstr(TT[i,j] == Dman[i,j] * invSpd[i], name=f"TTdef_{i}_{j}")
            m.addConstr(
                Tarr[j] >= Tdep[i] + TT[i,j] - BIGM*(1 - r[i,j]),
                name=f"timelink_lb_{i}_{j}")
            m.addConstr(
                Tarr[j] <= Tdep[i] + TT[i,j] + BIGM*(1 - r[i,j]),
                name=f"timelink_ub_{i}_{j}")
    m.addConstr(Tdep[0] == START_TIME)

    # === Departure chaining ===
    for i in range(1, nStop):
        m.addConstr(
            Tdep[i] == Tarr[i]
                     + SERVICE_MIN_PER_CL/60.0
                     + Tdrone[i-1],
            name=f"depart_asap_after_{i}"
        )

    # === Drone assignment, finite fleet & accumulation ===
    for cIdx, cust in enumerate(custIdx):
        m.addConstr(
            gp.quicksum(y[cIdx,i,k]
                        for i in range(len(centres))
                        for k in range(N_DRONES)) == 1,
            name=f"assignCust_{cIdx}"
        )
        for i in range(len(centres)):
            rt = 2 * Deuc[cust, i+1] / DRONE_SPEED_KMH
            for k in range(N_DRONES):
                m.addConstr(
                    gp.LinExpr(rt) <= DRONE_END_MIN/60.0 + BIGM*(1 - y[cIdx,i,k]),
                    name=f"endurance_{cIdx}_{i}_{k}"
                )
    
    for i in range(len(centres)):
        for k in range(N_DRONES):
            m.addConstr(
                Td_acc[i, k] == gp.quicksum(
                    (2 * Deuc[cust, i+1] / DRONE_SPEED_KMH) *
                        y[cIdx, i, k]
                    for cIdx, cust in enumerate(custIdx)
                ),
                name=f"accum_sum_{i}_{k}"
            )
    for i in range(len(centres)):
        for k in range(N_DRONES):
            m.addConstr(
                Tdrone[i] >= Td_acc[i,k],
                name=f"makespan_{i}_{k}"
            )

    # === Solve ===
    m.optimize()
    if m.SolCount == 0:
        print(f"[DEBUG]{tag} MILP infeasible.")
        return np.inf, m, r

    # === Extract objective components ===
    truck_time   = sum(TT[i,j].X * r[i,j].X
                       for i in range(nStop) for j in range(nStop) if i!=j)
    drone_time   = sum(Tdrone[i].X for i in range(len(centres)))
    service_time = SERVICE_MIN_PER_CL/60.0 * len(centres)
    total_time   = truck_time + drone_time + service_time

    print(f"[DEBUG]{tag} MILP solved:")
    print(f"   → Truck   {truck_time:.3f} h | "
          f"Drone {drone_time:.3f} h | "
          f"Service {service_time:.3f} h | "
          f"Total  {total_time:.3f} h")
    return total_time, m, r

# -------------------------------------------------------------
# 4b. Build & solve pure-truck TSP
# -------------------------------------------------------------
def build_and_solve_tsp(locs):
    n=len(locs)
    Dman=cdist(locs,locs,metric="cityblock")
    m=gp.Model(env=GRB_ENV)
    m.Params.OutputFlag=0
    r=m.addVars(n,n,vtype=GRB.BINARY,name="r_tsp")
    u=m.addVars(n,lb=0,ub=n-1,name="u_tsp")

    m.setObjective(gp.quicksum(Dman[i,j]*r[i,j] for i in range(n) for j in range(n) if i!=j),GRB.MINIMIZE)
    for i in range(n):
        m.addConstr(gp.quicksum(r[i,j] for j in range(n) if j!=i)==1)
        m.addConstr(gp.quicksum(r[j,i] for j in range(n) if j!=i)==1)
    for i,j in itertools.permutations(range(1,n),2):
        m.addConstr(u[i]-u[j]+(n-1)*r[i,j] <= n-2)

    m.optimize()
    if m.SolCount==0: raise RuntimeError("TSP infeasible")
    edges={(i,j) for (i,j),v in r.items() if v.X>0.5}
    route=[0]
    while len(route)<n+1:
        last=route[-1]; nxt=next(j for (i,j) in edges if i==last)
        route.append(nxt)
    print(f"[DEBUG] Extracted TSP route: {route}")
    return route


# -------------------------------------------------------------
# 5.  PSO fitness …
# -------------------------------------------------------------
def pso_fitness(w, locs, centres0, labels0):
    global call_counter, iter_counter
    call_counter += 1
    if call_counter % SWARM_SIZE == 0:
        iteration = call_counter // SWARM_SIZE
        if 1 <= iteration <= ITERATIONS:
            iter_counter = iteration
            print(f"[DEBUG][PSO] -- iter {iter_counter} --")

    particle_idx = ((call_counter - 1) % SWARM_SIZE) + 1
    K = len(centres0)
    ctrs = centres0 + w.reshape(K, 2)

    # endurance check (pre-MILP)
    for k, c in enumerate(ctrs):
        d  = np.linalg.norm(locs[1:][labels0==k] - c, axis=1)
        rt = 2 * d / DRONE_SPEED_KMH
        if (rt > DRONE_END_MIN/60.0).any():
            print(f"[DEBUG][PSO] it{iter_counter} p{particle_idx}: "
                  f"endurance VIOLATION in cl {k}")
            return 1e6

    print(f"[DEBUG][PSO] it{iter_counter} p{particle_idx}: centres OK")
    obj, _, _ = build_and_solve_milp(
        locs, ctrs, labels0,
        tag=f"[PSO it{iter_counter} p{particle_idx}]"
    )
    return 1e6 if np.isinf(obj) else obj

# -------------------------------------------------------------
# 6.  Extract route from r-vars
# -------------------------------------------------------------
def extract_route(r_vars):
    edges = {(i,j) for (i,j),v in r_vars.items() if v.X>0.5}
    route=[0]
    nStop=int(np.sqrt(len(r_vars)))
    while len(route)<nStop+1:
        last=route[-1]
        nxt=next(j for (i,j) in edges if i==last)
        route.append(nxt)
        if nxt==0: break
    print(f"[DEBUG] Extracted route: {route}")
    return route

# -------------------------------------------------------------
# 3.1 Universal plot dispatcher
# -------------------------------------------------------------
def plot(kind, *args, **kwargs):
    if kind == 'clustering': return plot_clustering(*args, **kwargs)
    if kind == 'routes':     return plot_routes(*args, **kwargs)
    raise ValueError(f"Unknown plot kind: {kind}")

# -------------------------------------------------------------
# 3.2 Plot clustering
# -------------------------------------------------------------
def plot_clustering(locations, labels, cluster_centers, depot):
    fig, ax = plt.subplots(figsize=(10, 6), dpi=300)
    points = locations[1:]; lbls = labels
    unique_labels = np.unique(lbls)
    centers = np.array([[points[lbls==lbl][:,0].mean(), points[lbls==lbl][:,1].mean()] for lbl in unique_labels])
    colors = plt.cm.viridis(np.linspace(0,1,len(unique_labels)))
    for i,(lbl,color) in enumerate(zip(unique_labels,colors)):
        pts = points[lbls==lbl]
        ax.scatter(pts[:,0],pts[:,1],color=color,marker='o',s=80,label=f'Cluster {i+1}')
        center=centers[i]
        for pt in pts: ax.plot([center[0],pt[0]],[center[1],pt[1]],color='gray',linestyle='--',linewidth=1.5)
    ax.scatter(centers[:,0],centers[:,1],color='red',marker='^',s=150,label='Cluster Centers')
    ax.scatter(depot[0],depot[1],color='red',marker='*',s=200,label='Depot')
    ax.set_xlabel('X Coordinate (km)',fontsize=12,labelpad=10)
    ax.set_ylabel('Y Coordinate (km)',fontsize=12,labelpad=10)
    ax.grid(True,linestyle=':',linewidth=0.5,color='gray')
    ax.spines['right'].set_visible(False); ax.spines['top'].set_visible(False)
    legend_elems=[plt.Line2D([0],[0],marker='o',color='w',label='Delivery Locations',markerfacecolor='black',markersize=8),
                  plt.Line2D([0],[0],marker='^',color='w',label='Cluster Centers',markerfacecolor='red',markersize=8),
                  plt.Line2D([0],[0],marker='*',color='w',label='Depot',markerfacecolor='red',markersize=12)]
    ax.legend(handles=legend_elems,loc='upper left',bbox_to_anchor=(1,1),fontsize=10)
    plt.tight_layout(); plt.show()

# -------------------------------------------------------------
# 3.3 Plot routes
# -------------------------------------------------------------
def plot_routes(locations, labels, cluster_centers, tsp_route=None, initial_tsp_route=None, optimized_centers=None):
    """Enhanced route plotting that closes paths through the depot."""
    depot = locations[0]
    plt.figure(figsize=(12,6), dpi=300)

    # Delivery points (exclude depot)
    plt.scatter(locations[1:,0], locations[1:,1], c=labels, cmap='tab10', s=20, label='Delivery Locations')

    # Initial full‑point TSP route (red)
    if initial_tsp_route is not None and len(initial_tsp_route)>1:
        init_coords = np.array([locations[i] for i in initial_tsp_route] + [locations[initial_tsp_route[0]]])
        plt.plot(init_coords[:,0], init_coords[:,1], 'r-', label='Initial TSP Route')

    # Cluster centres
    plt.scatter(cluster_centers[:,0], cluster_centers[:,1], c='green', marker='x', s=80, label='Cluster Centers')

    # Route through cluster centres (green dashed) starting/ending at depot
    if tsp_route is not None and len(tsp_route)>0:
        clust_coords = np.vstack([
            depot,
            np.array([cluster_centers[i] for i in tsp_route]),
            depot
        ])
        plt.plot(clust_coords[:,0], clust_coords[:,1], 'g--', label='Clustered Route')

    # Optimized centres & route (magenta dashed)
    if optimized_centers is not None:
        plt.scatter(optimized_centers[:,0], optimized_centers[:,1], c='purple', marker='s', s=80, label='Optimized Centers')
        if tsp_route is not None and len(tsp_route)>0:
            opt_coords = np.vstack([
                depot,
                np.array([optimized_centers[i] for i in tsp_route]),
                depot
            ])
            plt.plot(opt_coords[:,0], opt_coords[:,1], 'm--', label='Optimized Route')

    # Depot
    plt.scatter(depot[0], depot[1], c='red', marker='*', s=200, label='Depot')

    plt.xlabel('X Coordinate (km)'); plt.ylabel('Y Coordinate (km)')
    plt.gca().spines['top'].set_visible(False); plt.gca().spines['right'].set_visible(False)
    plt.legend(loc='upper left', bbox_to_anchor=(1,1), fontsize=9)
    plt.grid(True); plt.tight_layout(); plt.show()

# -------------------------------------------------------------
# 7. Main solver + plot
# -------------------------------------------------------------
def solve_and_plot(locs):
    global call_counter, iter_counter
    call_counter = iter_counter = 0

    # initial clustering plot
    labels0, centres0 = kmeans_endurance(locs)
    plot('clustering', locs, labels0, centres0, DEPOT)

    # TSP baseline
    route_tsp = build_and_solve_tsp(locs)

    # truck+drone baseline
    base_time, base_mdl, base_r = build_and_solve_milp(locs, centres0, labels0, tag="[CLUSTER]")
    if np.isinf(base_time): raise RuntimeError("Baseline infeasible")

    # PSO optimization
    print("[DEBUG] Starting PSO…")
    w_best, f_best = pso(pso_fitness, [-2]*(2*len(centres0)), [2]*(2*len(centres0)),
                         swarmsize=SWARM_SIZE, maxiter=ITERATIONS, debug=False,
                         args=(locs, centres0, labels0))
    print(f"[DEBUG] PSO best obj = {f_best:.3f}h")
    centres_opt = centres0 if f_best>=1e6 else centres0 + w_best.reshape(-1,2)
    opt_time, opt_mdl, opt_r = build_and_solve_milp(locs, centres_opt, labels0, tag="[OPT   ]")
    if np.isinf(opt_time): centres_opt, opt_time, opt_r = centres0, base_time, base_r

    improvement = 100*(base_time-opt_time)/base_time
    route_base = extract_route(base_r)
    route_opt  = extract_route(opt_r)

    # routes plot
        # Build cluster-level route indices (exclude depot and shift by −1)
    tsp_route_cent = [idx-1 for idx in route_base if idx != 0]

    # routes plot
    plot('routes', locs, labels0, centres0,
         tsp_route=tsp_route_cent,
         initial_tsp_route=route_tsp,
         optimized_centers=centres_opt)

    return base_time, opt_time, improvement

# -------------------------------------------------------------
# 8. Demo run
# -------------------------------------------------------------
if __name__ == "__main__":
    locs = gen_locations()
    base, opt, impr = solve_and_plot(locs)
    print(f"\nDone – cluster {base:.2f}h, opt {opt:.2f}h, Δ={impr:.1f}%")
# Out:
# [DEBUG] Gurobi cloud environment initialized.
# [DEBUG] Loaded 96 speed points – example 09:30 ⇒ 66.3 km/h
# [DEBUG] Generated 50 delivery locations.
# [DEBUG] K-means found feasible K=4 clusters.
# [DEBUG] Extracted TSP route: [0, 49, 20, 48, 47, 2, 44, 38, 5, 28, 27, 18, 26, 41, 45, 32, 7, 36, 39, 15, 11, 16, 25, 10, 31, 12, 43, 40, 42, 19, 3, 8, 29, 50, 30, 21, 14, 24, 9, 33, 23, 46, 34, 37, 4, 22, 6, 35, 17, 1, 13, 0]
# [DEBUG][CLUSTER] MILP solved:
#    → Truck   0.939 h | Drone 1.277 h | Service 0.333 h | Total  2.549 h
# [DEBUG] Starting PSO…
# [DEBUG][PSO] it0 p1: endurance VIOLATION in cl 1
# [DEBUG][PSO] it0 p2: endurance VIOLATION in cl 1
# [DEBUG][PSO] -- iter 1 --
# [DEBUG][PSO] it1 p3: endurance VIOLATION in cl 0
# [DEBUG][PSO] it1 p1: endurance VIOLATION in cl 2
# [DEBUG][PSO] it1 p2: endurance VIOLATION in cl 0
# [DEBUG][PSO] -- iter 2 --
# [DEBUG][PSO] it2 p3: endurance VIOLATION in cl 0
# [DEBUG][PSO] it2 p1: centres OK
# [DEBUG][PSO it2 p1] MILP solved:
#    → Truck   0.764 h | Drone 1.375 h | Service 0.333 h | Total  2.472 h
# [DEBUG][PSO] it2 p2: endurance VIOLATION in cl 3
# [DEBUG][PSO] -- iter 3 --
# [DEBUG][PSO] it3 p3: endurance VIOLATION in cl 0
# [DEBUG][PSO] it3 p1: centres OK
# [DEBUG][PSO it3 p1] MILP solved:
#    → Truck   0.781 h | Drone 1.332 h | Service 0.333 h | Total  2.446 h
# [DEBUG][PSO] it3 p2: endurance VIOLATION in cl 3
# [DEBUG][PSO] it3 p3: endurance VIOLATION in cl 0
# Stopping search: maximum iterations reached --> 3
# [DEBUG] PSO best obj = 2.446h
# [DEBUG][OPT   ] MILP solved:
#    → Truck   0.781 h | Drone 1.332 h | Service 0.333 h | Total  2.446 h
# [DEBUG] Extracted route: [0, 1, 4, 2, 3, 0]
# [DEBUG] Extracted route: [0, 1, 4, 2, 3, 0]
# Done – cluster 2.55h, opt 2.45h, Δ=4.0%
